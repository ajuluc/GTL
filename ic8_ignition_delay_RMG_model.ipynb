# %% [markdown]
# # Trying to model ignition delay from RMG for Iso-octane

# %%
import cantera as ct
import numpy as np
# %matplotlib inline

from matplotlib import pyplot as plt

# %%
gas = ct.Solution('/Users/ebubeajulu/Code/GTL/ic8/chemkin/chem_annotated.cti')
# Out:
# **** WARNING ****
# For species HOCHO(60), discontinuity in h/RT detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  -40.3604
# 	Value computed using high-temperature polynomial: -38.1678

# %%
sorted(gas.species_names)
# Out:
# ['Ar',
#  'C(36)',
#  'C2(54)',
#  'C2H(4)',
#  'C2H2(27)',
#  'C2H3(24)',
#  'C2H3O2(48)',
#  'C2H3O2(69)',
#  'C2H3O3(61)',
#  'C2H4(11)',
#  'C2H4(700)',
#  'C2H4O(44)',
#  'C2H4O2(65)',
#  'C2H4O3(68)',
#  'C2H5(35)',
#  'C2H5O(41)',
#  'C2H5O(45)',
#  'C2H5O(57)',
#  'C2H5O2(42)',
#  'C2H5O2(47)',
#  'C2H5O2(64)',
#  'C2H5O3(58)',
#  'C2H6(39)',
#  'C2H6O(56)',
#  'C2H6O2(63)',
#  'C2O(55)',
#  'C3H4(175)',
#  'C3H4O(84)',
#  'C3H5(104)',
#  'C3H5(110)',
#  'C3H5O(138)',
#  'C3H5O(140)',
#  'C3H5O(80)',
#  'C3H5O3(82)',
#  'C3H6(12)',
#  'C3H6O(79)',
#  'C3H6O3(83)',
#  'C4H5O(421)',
#  'C4H6O(305)',
#  'C4H7O(289)',
#  'C4H8O(291)',
#  'C4H8O(292)',
#  'C5H10(401)',
#  'C5H11(543)',
#  'C5H11(670)',
#  'C7H13(836)',
#  'C7H13(882)',
#  'C7H14(721)',
#  'C7H14(722)',
#  'C7H14(736)',
#  'C7H15(683)',
#  'C7H15(684)',
#  'C8H16(749)',
#  'C8H17(685)',
#  'C8H17(686)',
#  'C8H17(687)',
#  'C8H17(688)',
#  'CH(3)',
#  'CH2(25)',
#  'CH2(S)(30)',
#  'CH2CHO(23)',
#  'CH2CO(26)',
#  'CH2O(9)',
#  'CH2OH(31)',
#  'CH2OOH(38)',
#  'CH3(20)',
#  'CH3CHO(40)',
#  'CH3CO(22)',
#  'CH3O(32)',
#  'CH3OH(29)',
#  'CH3OO(34)',
#  'CH3OOH(37)',
#  'CH4(10)',
#  'CHCHO(49)',
#  'CHCHOH(53)',
#  'CO(6)',
#  'CO2(7)',
#  'H(15)',
#  'H2(13)',
#  'H2CC(43)',
#  'H2O(8)',
#  'H2O2(19)',
#  'HCCO(51)',
#  'HCCOH(52)',
#  'HCO(21)',
#  'HCOH(33)',
#  'HO2(18)',
#  'HOCH2O(66)',
#  'HOCHO(60)',
#  'HOCO(28)',
#  'He(17)',
#  'IC3H7(103)',
#  'IC4H7(288)',
#  'IC4H9(281)',
#  'N2',
#  'Ne',
#  'O(5)',
#  'O2(2)',
#  'OCHCHO(50)',
#  'OCHCO(62)',
#  'OCHO(67)',
#  'OH(16)',
#  'S(10137)',
#  'S(10148)',
#  'S(10382)',
#  'S(10385)',
#  'S(10405)',
#  'S(10486)',
#  'S(1052)',
#  'S(107)',
#  'S(11095)',
#  'S(1129)',
#  'S(1133)',
#  'S(1151)',
#  'S(1154)',
#  'S(1155)',
#  'S(1173)',
#  'S(1179)',
#  'S(1233)',
#  'S(12886)',
#  'S(12890)',
#  'S(1292)',
#  'S(1305)',
#  'S(13124)',
#  'S(1407)',
#  'S(1474)',
#  'S(1505)',
#  'S(1520)',
#  'S(1547)',
#  'S(1564)',
#  'S(15683)',
#  'S(15714)',
#  'S(1575)',
#  'S(15803)',
#  'S(1597)',
#  'S(16388)',
#  'S(1798)',
#  'S(1821)',
#  'S(1825)',
#  'S(1898)',
#  'S(1899)',
#  'S(1903)',
#  'S(1911)',
#  'S(1916)',
#  'S(1941)',
#  'S(1959)',
#  'S(1962)',
#  'S(1963)',
#  'S(1972)',
#  'S(1973)',
#  'S(1991)',
#  'S(1994)',
#  'S(1995)',
#  'S(20277)',
#  'S(2036)',
#  'S(2056)',
#  'S(2059)',
#  'S(20609)',
#  'S(2089)',
#  'S(2091)',
#  'S(2098)',
#  'S(2106)',
#  'S(2108)',
#  'S(2115)',
#  'S(2122)',
#  'S(2128)',
#  'S(2137)',
#  'S(2170)',
#  'S(2184)',
#  'S(2222)',
#  'S(2226)',
#  'S(2232)',
#  'S(2260)',
#  'S(2287)',
#  'S(2291)',
#  'S(2327)',
#  'S(23344)',
#  'S(2345)',
#  'S(23535)',
#  'S(23574)',
#  'S(23838)',
#  'S(23849)',
#  'S(2390)',
#  'S(2401)',
#  'S(2417)',
#  'S(2426)',
#  'S(2432)',
#  'S(2499)',
#  'S(25524)',
#  'S(2571)',
#  'S(2625)',
#  'S(2633)',
#  'S(2660)',
#  'S(2672)',
#  'S(2685)',
#  'S(2689)',
#  'S(282)',
#  'S(284)',
#  'S(2841)',
#  'S(2850)',
#  'S(299)',
#  'S(3109)',
#  'S(3111)',
#  'S(3296)',
#  'S(3311)',
#  'S(3312)',
#  'S(351)',
#  'S(376)',
#  'S(390)',
#  'S(391)',
#  'S(4092)',
#  'S(4105)',
#  'S(4192)',
#  'S(4215)',
#  'S(4251)',
#  'S(4463)',
#  'S(4468)',
#  'S(4496)',
#  'S(4507)',
#  'S(4510)',
#  'S(5409)',
#  'S(5424)',
#  'S(5451)',
#  'S(5479)',
#  'S(5488)',
#  'S(5525)',
#  'S(555)',
#  'S(5553)',
#  'S(5573)',
#  'S(5601)',
#  'S(5603)',
#  'S(5622)',
#  'S(6236)',
#  'S(672)',
#  'S(674)',
#  'S(675)',
#  'S(6750)',
#  'S(6753)',
#  'S(6754)',
#  'S(6855)',
#  'S(6897)',
#  'S(6922)',
#  'S(6923)',
#  'S(6932)',
#  'S(6935)',
#  'S(6957)',
#  'S(6968)',
#  'S(6969)',
#  'S(7008)',
#  'S(7014)',
#  'S(7057)',
#  'S(7058)',
#  'S(7105)',
#  'S(7118)',
#  'S(7127)',
#  'S(7169)',
#  'S(7216)',
#  'S(7217)',
#  'S(7290)',
#  'S(733)',
#  'S(747)',
#  'S(754)',
#  'S(7597)',
#  'S(7713)',
#  'S(7714)',
#  'S(776)',
#  'S(7962)',
#  'S(812)',
#  'S(8141)',
#  'S(815)',
#  'S(8159)',
#  'S(816)',
#  'S(9006)',
#  'S(903)',
#  'S(904)',
#  'S(905)',
#  'S(917)',
#  'S(9184)',
#  'S(920)',
#  'S(9207)',
#  'S(9208)',
#  'S(934)',
#  'S(944)',
#  'S(945)',
#  'S(953)',
#  'S(957)',
#  'S(9846)',
#  'TC4H9(280)',
#  'cC2H3O(59)',
#  'cC2H4O(46)',
#  'iC4H8(14)',
#  'iC8H18(1)']

# %%
gas.TP = 900, 10e6
gas.set_equivalence_ratio(phi=1.0, fuel='iC8H18(1)', oxidizer='O2(2):0.2, N2:0.8' )
gas()
# Out:
#   gas:
#
#        temperature             900  K
#           pressure           1e+07  Pa
#            density         40.2989  kg/m^3
#   mean mol. weight         30.1557  amu
#
#                           1 kg            1 kmol
#                        -----------      ------------
#           enthalpy       5.867e+05        1.769e+07     J
#    internal energy      3.3856e+05        1.021e+07     J
#            entropy          6719.6        2.026e+05     J/K
#     Gibbs function     -5.4609e+06       -1.647e+08     J
#  heat capacity c_p          1280.5        3.861e+04     J/K
#  heat capacity c_v          1004.8         3.03e+04     J/K
#
#                            X                 Y          Chem. Pot. / RT
#                      -------------     ------------     ------------
#                 N2       0.787402         0.731465         -20.2342
#          iC8H18(1)       0.015748         0.059654         -94.4155
#              O2(2)        0.19685         0.208881         -23.3054
#      [ +289 minor]              0                0

# %%
def set_gas_concentrations(gas, phi):
    """
    Set the concentrations in the gas according to the description
    in the paper by 
    """
    # Set it to desired stoichiometry with synthetic air (20% O2 : 80% N2)
    gas.set_equivalence_ratio(phi=1.0, fuel='iC8H18(1)', oxidizer='O2(2):0.2, N2:0.8' )
    # Then dilute the whole thing 1:2 with extra N2
    gas.X = gas.X / 3.0 
    gas.X[gas.species_index('N2')] += 2./3.

set_gas_concentrations(gas, 1.0)
gas()
# Out:
#   gas:
#
#        temperature             900  K
#           pressure           1e+07  Pa
#            density         40.2989  kg/m^3
#   mean mol. weight         30.1557  amu
#
#                           1 kg            1 kmol
#                        -----------      ------------
#           enthalpy       5.867e+05        1.769e+07     J
#    internal energy      3.3856e+05        1.021e+07     J
#            entropy          6719.6        2.026e+05     J/K
#     Gibbs function     -5.4609e+06       -1.647e+08     J
#  heat capacity c_p          1280.5        3.861e+04     J/K
#  heat capacity c_v          1004.8         3.03e+04     J/K
#
#                            X                 Y          Chem. Pot. / RT
#                      -------------     ------------     ------------
#                 N2       0.787402         0.731465         -20.2342
#          iC8H18(1)       0.015748         0.059654         -94.4155
#              O2(2)        0.19685         0.208881         -23.3054
#      [ +289 minor]              0                0

# %%
def get_ignition_delay(gas, temperature, pressure_bar, mole_fractions, plot=False):
    """
    A general function to find the igniton delay.
    Using C2H + O --> CH* as the indication of ignition
    
    gas is a cantera Solution object
    temperature in K
    pressure_bar is in bar
    mole_fractions is a dict
    """
    gas.TPX = temperature, pressure_bar*1e5, mole_fractions

    reactor = ct.IdealGasReactor(gas)
    reactor_network = ct.ReactorNet([reactor])
    
    time = 0.0
    end_time = 10e-3
    
    times = []
    concentrations = []
    pressures = []
    temperatures = []
    
    print_data = True
    while time < end_time:
        time = reactor_network.time
        times.append(time)
        temperatures.append(reactor.T)
        pressures.append(reactor.thermo.P)
        concentrations.append(reactor.thermo.concentrations)
        # take a timestep
        # the size of the step will be determined by the ODE solver
        # depending on how quickly things are changing.
        reactor_network.step()
    
    print("Reached end time {0:.2f} ms in {1} steps".format(times[-1]*1e3, len(times)))
    # convert the lists into arrays
    concentrations = np.array(concentrations)
    times = np.array(times)
    pressures = np.array(pressures)
    temperatures = np.array(temperatures)

    if plot:
        plt.subplot(2,1,1)
        plt.plot(times*1e3, pressures/1e5)
        plt.ylabel("Pressure (bar)", color='b')
        ax2 = plt.gca().twinx()
        ax2.set_ylabel('Temperature (K)', color='r')
        ax2.plot(times*1e3, temperatures, 'r')
    # Using C2H + O --> CH* as the indication of ignition
    i_c2h = gas.species_index('C2H(4)')   
    i_o = gas.species_index('O(5)')
    excited_ch_generation = concentrations[:,i_o] * concentrations[:,i_c2h]
    if plot:
        plt.subplot(2,1,2)
        plt.plot(times*1e3, excited_ch_generation, 'g')
        plt.ylabel("CH* emission")
        plt.ylim(0,max(1e-13,1.1*max(excited_ch_generation)))
        plt.xlabel("Time (ms)")
        plt.tight_layout()
        plt.show()
    step_with_highest_ch_gen = excited_ch_generation.argmax()
    if step_with_highest_ch_gen > 1 and excited_ch_generation.max()>1e-20:
        ignition_time_ms = 1e3 * times[step_with_highest_ch_gen]
        print("At {0} K {1} bar, ignition delay time is {2} ms".format(temperature, pressure_bar, ignition_time_ms))
        return ignition_time_ms
    else:
        print("At {0} K {1} bar, no ignition detected".format(temperature, pressure_bar))
        return np.infty

# %%
def get_ignition_delay_air(temperature, pressure_bar=10, phi=1.0, plot=False):
    """
    For figure 14
    
    temperature in K
    pressure in bar
    phi is equivalence ratio
    burns DME in air
    """
    set_gas_concentrations(gas,phi)
    mole_fractions = gas.X

    time = get_ignition_delay(gas, temperature, pressure_bar, mole_fractions, plot=plot)
    return time

# %%
get_ignition_delay_air(1000, 16, 1, plot=True)
plt.rcParams['figure.figsize'] = [10, 8]
# Out:
# Reached end time 10.05 ms in 6327 steps
# At 1000 K 16 bar, ignition delay time is 5.085509742502259 ms

# %%
RMG_temperatures = 1000/np.linspace(0.70,1.55,25)
pressures_bar = 16
phi = 1

RMG_results = dict()
times = []
for T in RMG_temperatures:
    t = get_ignition_delay_air(T,pressures_bar, phi, plot=False)
    times.append(t)
    RMG_results[pressures_bar]=times
# Out:
# Reached end time 10.34 ms in 4404 steps
# At 1428.5714285714287 K 16 bar, ignition delay time is 0.03267071301102034 ms
# Reached end time 10.05 ms in 5189 steps
# At 1359.773371104816 K 16 bar, ignition delay time is 0.05785562835837665 ms
# Reached end time 10.12 ms in 5459 steps
# At 1297.2972972972975 K 16 bar, ignition delay time is 0.10126323800853373 ms
# Reached end time 10.20 ms in 5494 steps
# At 1240.31007751938 K 16 bar, ignition delay time is 0.18146948630234322 ms
# Reached end time 10.21 ms in 5250 steps
# At 1188.118811881188 K 16 bar, ignition delay time is 0.33916803334691553 ms
# Reached end time 10.04 ms in 5494 steps
# At 1140.142517814727 K 16 bar, ignition delay time is 0.6569487245860215 ms
# Reached end time 10.02 ms in 5739 steps
# At 1095.890410958904 K 16 bar, ignition delay time is 1.2769494037561704 ms
# Reached end time 10.06 ms in 5988 steps
# At 1054.945054945055 K 16 bar, ignition delay time is 2.373996435097811 ms
# Reached end time 10.05 ms in 6218 steps
# At 1016.9491525423729 K 16 bar, ignition delay time is 4.064246400242343 ms
# Reached end time 10.03 ms in 6209 steps
# At 981.5950920245398 K 16 bar, ignition delay time is 6.440565004094673 ms
# Reached end time 10.01 ms in 5975 steps
# At 948.6166007905138 K 16 bar, ignition delay time is 9.823064946074375 ms
# Reached end time 10.01 ms in 531 steps
# At 917.7820267686425 K 16 bar, no ignition detected
# Reached end time 10.00 ms in 413 steps
# At 888.8888888888889 K 16 bar, no ignition detected
# Reached end time 10.07 ms in 336 steps
# At 861.7594254937163 K 16 bar, no ignition detected
# Reached end time 10.03 ms in 314 steps
# At 836.2369337979094 K 16 bar, no ignition detected
# Reached end time 10.03 ms in 282 steps
# At 812.1827411167511 K 16 bar, no ignition detected
# Reached end time 10.00 ms in 303 steps
# At 789.4736842105264 K 16 bar, no ignition detected
# Reached end time 10.00 ms in 378 steps
# At 767.9999999999999 K 16 bar, no ignition detected
# Reached end time 10.01 ms in 410 steps
# At 747.6635514018692 K 16 bar, no ignition detected
# Reached end time 10.01 ms in 332 steps
# At 728.3763277693474 K 16 bar, no ignition detected
# Reached end time 10.01 ms in 182 steps
# At 710.059171597633 K 16 bar, no ignition detected
# Reached end time 10.03 ms in 120 steps
# At 692.6406926406926 K 16 bar, no ignition detected
# Reached end time 10.00 ms in 67 steps
# At 676.056338028169 K 16 bar, no ignition detected
# Reached end time 10.01 ms in 52 steps
# At 660.2475928473177 K 16 bar, no ignition detected
# Reached end time 10.46 ms in 38 steps
# At 645.1612903225806 K 16 bar, no ignition detected

# %%
plt.semilogy(1000/RMG_temperatures,times,label='{}bar'.format(pressures_bar))
plt.legend(loc='best')
plt.xlabel('1000 K / $T$')
plt.ylabel('$\\tau_{ign} = t([CH^*]_{max})/ms$')
plt.rcParams['figure.figsize'] = [10, 8]

# %%
import pickle
with open('ic8-RMG.pkl','wb') as fp:
    pickle.dump((RMG_temperatures, RMG_results[pressures_bar]), fp)
