# %% [markdown]
# # Figure 14 ignition delay times from LLNL for iso-octane in N2 as bath gas comparing to the Dagaut et al 2014

# %%
import cantera as ct
import numpy as np
# %matplotlib inline

from matplotlib import pyplot as plt

# %%
ct.__version__
# Out:
# '2.4.0'

# %% [markdown]
# # Importing the GTL mechanism from Dagaut for Iso-octane and comparing to LLNL and RMG model

# %%
gas = ct.Solution('/Users/ebubeajulu/Code/GTL/ic8/Dagaut_DKM.cti')
# Out:
# **** WARNING ****
# For species Lc6h6, discontinuity in h/RT detected at Tmid = 1399
# 	Value computed using low-temperature polynomial:  48.1571
# 	Value computed using high-temperature polynomial: 48.2049
#
#
# **** WARNING ****
# For species Lc6h4, discontinuity in h/RT detected at Tmid = 1399
# 	Value computed using low-temperature polynomial:  61.4309
# 	Value computed using high-temperature polynomial: 61.4712
#
#
# **** WARNING ****
# For species pbzohAqjB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.1357
# 	Value computed using high-temperature polynomial: 50.2973
#
#
# **** WARNING ****
# For species pbzohAqjB, discontinuity in h/RT detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  16.0876
# 	Value computed using high-temperature polynomial: 15.9218
#
#
# **** WARNING ****
# For species pbzohBqjA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.1357
# 	Value computed using high-temperature polynomial: 50.2973
#
#
# **** WARNING ****
# For species pbzohBqjA, discontinuity in h/RT detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  16.0876
# 	Value computed using high-temperature polynomial: 15.9218
#
#
# **** WARNING ****
# For species c4h7o, discontinuity in cp/R detected at Tmid = 1390
# 	Value computed using low-temperature polynomial:  29.7898
# 	Value computed using high-temperature polynomial: 30.7835
#
#
# **** WARNING ****
# For species c4h7o, discontinuity in h/RT detected at Tmid = 1390
# 	Value computed using low-temperature polynomial:  21.9716
# 	Value computed using high-temperature polynomial: 22.2718
#
#
# **** WARNING ****
# For species c4h7o, discontinuity in s/R detected at Tmid = 1390
# 	Value computed using low-temperature polynomial:  69.7669
# 	Value computed using high-temperature polynomial: 70.11
#
#
# **** WARNING ****
# For species nc3h7coch2o2, discontinuity in cp/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  40.6753
# 	Value computed using high-temperature polynomial: 41.2646
#
#
# **** WARNING ****
# For species nc3h7coch2o2, discontinuity in h/RT detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  8.29766
# 	Value computed using high-temperature polynomial: 8.46498
#
#
# **** WARNING ****
# For species nc3h7coch2o2, discontinuity in s/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  98.2808
# 	Value computed using high-temperature polynomial: 98.4716
#
#
# **** WARNING ****
# For species nc3h7coch2o2h, discontinuity in h/RT detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  -3.21938
# 	Value computed using high-temperature polynomial: -3.05602
#
#
# **** WARNING ****
# For species nc3h7coch2o2h, discontinuity in s/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  102.517
# 	Value computed using high-temperature polynomial: 102.705
#
#
# **** WARNING ****
# For species nc3h7coch2o, discontinuity in cp/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  38.0512
# 	Value computed using high-temperature polynomial: 38.63
#
#
# **** WARNING ****
# For species nc3h7coch2o, discontinuity in h/RT detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  6.42283
# 	Value computed using high-temperature polynomial: 6.5736
#
#
# **** WARNING ****
# For species nc3h7coch2o, discontinuity in s/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  90.2443
# 	Value computed using high-temperature polynomial: 90.4159
#
#
# **** WARNING ****
# For species c2h5coc2h4o2, discontinuity in cp/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  41.4146
# 	Value computed using high-temperature polynomial: 42.2063
#
#
# **** WARNING ****
# For species c2h5coc2h4o2, discontinuity in h/RT detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  7.92517
# 	Value computed using high-temperature polynomial: 8.17676
#
#
# **** WARNING ****
# For species c2h5coc2h4o2, discontinuity in s/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  98.5755
# 	Value computed using high-temperature polynomial: 98.8633
#
#
# **** WARNING ****
# For species c2h5coc2h4o2h, discontinuity in cp/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  43.4457
# 	Value computed using high-temperature polynomial: 44.0603
#
#
# **** WARNING ****
# For species c2h5coc2h4o2h, discontinuity in h/RT detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  -3.5967
# 	Value computed using high-temperature polynomial: -3.34459
#
#
# **** WARNING ****
# For species c2h5coc2h4o2h, discontinuity in s/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  102.808
# 	Value computed using high-temperature polynomial: 103.098
#
#
# **** WARNING ****
# For species c2h5coc2h4o, discontinuity in cp/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  38.7018
# 	Value computed using high-temperature polynomial: 39.5691
#
#
# **** WARNING ****
# For species c2h5coc2h4o, discontinuity in h/RT detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  6.04394
# 	Value computed using high-temperature polynomial: 6.28548
#
#
# **** WARNING ****
# For species c2h5coc2h4o, discontinuity in s/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  90.5318
# 	Value computed using high-temperature polynomial: 90.8074
#
#
# **** WARNING ****
# For species c8h16o-AC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  52.8395
# 	Value computed using high-temperature polynomial: 53.6798
#
#
# **** WARNING ****
# For species c8h16o-BD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  52.8395
# 	Value computed using high-temperature polynomial: 53.6798
#
#
# **** WARNING ****
# For species c8h16o-CE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  52.8395
# 	Value computed using high-temperature polynomial: 53.6798
#
#
# **** WARNING ****
# For species c9h18o-BD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  59.3013
# 	Value computed using high-temperature polynomial: 60.1533
#
#
# **** WARNING ****
# For species c9h18o-CE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  59.3049
# 	Value computed using high-temperature polynomial: 60.1494
#
#
# **** WARNING ****
# For species c9h18o-DF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  59.3049
# 	Value computed using high-temperature polynomial: 60.1494
#
#
# **** WARNING ****
# For species c10h20o-BD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  65.5106
# 	Value computed using high-temperature polynomial: 66.2886
#
#
# **** WARNING ****
# For species c10h20o-CE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  65.5106
# 	Value computed using high-temperature polynomial: 66.2886
#
#
# **** WARNING ****
# For species c10h20o-DF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  65.5106
# 	Value computed using high-temperature polynomial: 66.2886
#
#
# **** WARNING ****
# For species hxolcy3o1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.1052
# 	Value computed using high-temperature polynomial: 42.7493

# %%
sorted(gas.species_names)
# Out:
# ['A1c2h3AC',
#  'A1c2hAC',
#  'A2-X',
#  'A2O',
#  'A2oh',
#  'ASTYRYL',
#  'Ac10h21',
#  'Ac4h7-1',
#  'Ac5e1oC',
#  'Ac5e4oB',
#  'Ac5h11',
#  'Ac5h9-1',
#  'Ac5oB',
#  'Ac5oBoC',
#  'Ac5oBoD',
#  'Ac6e3e5oB',
#  'Ac6e5oB',
#  'Ac6e5oC',
#  'Ac6h11-3',
#  'Ac6h13',
#  'Ac6h9-15',
#  'Ac6oC',
#  'Ac7e1oD',
#  'Ac7e3oB',
#  'Ac7e4oB',
#  'Ac7e4oC',
#  'Ac7e6oB',
#  'Ac7h13-3',
#  'Ac7h15',
#  'Ac7oBoD',
#  'Ac7oBoG',
#  'Ac7oD',
#  'Ac8e5oC',
#  'Ac8h15-4',
#  'Ac8h17',
#  'Ac9e2oF',
#  'Ac9e3oF',
#  'Ac9e5oB',
#  'Ac9e5oC',
#  'Ac9e5oD',
#  'Ac9e6oB',
#  'Ac9e6oC',
#  'Ac9e6oD',
#  'Ac9h19',
#  'Ac9oBoF',
#  'Ac9oCoF',
#  'Ac9oDoF',
#  'AchxqBqD',
#  'Aeche1',
#  'AechoB',
#  'AechoD',
#  'AechoE',
#  'Amche1',
#  'Amche3',
#  'AmchoC',
#  'AmchoD',
#  'AmchqBqD',
#  'Ao2pchohB',
#  'Aophc3h4-2',
#  'Apche2',
#  'ApchoB',
#  'ApchoC',
#  'ApchoE',
#  'ApchoF',
#  'ApchohB',
#  'ApchqA',
#  'ApchqB',
#  'ApchqC',
#  'ApchqD',
#  'ApchqDqF',
#  'ApchqE',
#  'ApchqF',
#  'ApchqG',
#  'Aphc2h4',
#  'Aphc3h5ohB',
#  'BPHPROPY',
#  'BSTYRYL',
#  'Bc10h21',
#  'Bc5e1oC',
#  'Bc5h11',
#  'Bc5h9-1',
#  'Bc5oA',
#  'Bc5oAoC',
#  'Bc5oAoD',
#  'Bc5oAqE',
#  'Bc6e5oA',
#  'Bc6h11-3',
#  'Bc6h13',
#  'Bc6oAoF',
#  'Bc7e6oA',
#  'Bc7h15',
#  'Bc8h17',
#  'Bc9h19',
#  'BchxoAoC',
#  'BchxoAoD',
#  'Bchxone',
#  'BchxqAqC',
#  'BchxqAqD',
#  'BmchohA',
#  'Bo2pchohA',
#  'Bo2pchohC',
#  'BpchoA',
#  'BpchoC',
#  'BpchoE',
#  'BpchoF',
#  'BpchoG',
#  'BpchohA',
#  'BpchohC',
#  'BpchqA',
#  'BpchqB',
#  'BpchqC',
#  'BpchqD',
#  'BpchqDqF',
#  'BpchqE',
#  'BpchqEqG',
#  'BpchqEqH',
#  'BpchqEqI',
#  'BpchqF',
#  'BpchqG',
#  'Bphc2h4',
#  'Bphc3h5ohA',
#  'Bphc3h5ohC',
#  'C',
#  'CEtDc7oEoIqA',
#  'CEtDc7oIqA',
#  'CMeEc8oIqA',
#  'CPD',
#  'Cc10h19-1',
#  'Cc10h21',
#  'Cc4h7-1',
#  'Cc5e4oA',
#  'Cc5e4oB',
#  'Cc5h11',
#  'Cc5h9-1',
#  'Cc5oAqE',
#  'Cc6e5oA',
#  'Cc6h11-1',
#  'Cc6h13',
#  'Cc6oA',
#  'Cc6oAoD',
#  'Cc7e1oD',
#  'Cc7h11-16',
#  'Cc7h13-1',
#  'Cc7h15',
#  'Cc7oBoGqA',
#  'Cc8h15-1',
#  'Cc8h17',
#  'Cc9h17-1',
#  'Cc9h19',
#  'Cc9oAqF',
#  'Cc9oDoFqA',
#  'Cchxone',
#  'Ceche1',
#  'Cmche1',
#  'Co2pchohB',
#  'Co2pchohD',
#  'Cophc3h4-1',
#  'Cpche4',
#  'CpchoA',
#  'CpchoB',
#  'CpchoBqE',
#  'CpchoE',
#  'CpchoF',
#  'CpchoG',
#  'CpchohB',
#  'CpchohD',
#  'CpchqA',
#  'CpchqB',
#  'CpchqC',
#  'CpchqD',
#  'CpchqDqF',
#  'CpchqE',
#  'CpchqEqG',
#  'CpchqEqH',
#  'CpchqEqI',
#  'CpchqF',
#  'CpchqFqH',
#  'CpchqG',
#  'Cphc3h5ohB',
#  'DEtDc7oAqI',
#  'DEtDc7oEoIqA',
#  'DEtDc7oIqA',
#  'DMeEc8oAoCqI',
#  'DMeEc8oAqI',
#  'DMeEc8oIqA',
#  'Dc10h19-2',
#  'Dc10h21',
#  'Dc4e1oA',
#  'Dc4h7-1',
#  'Dc4oAqC',
#  'Dc5e4oA',
#  'Dc5e4oB',
#  'Dc5h9-1',
#  'Dc5h9-2',
#  'Dc5oBohE',
#  'Dc6e5oA',
#  'Dc6e5oAoC',
#  'Dc7e1oC',
#  'Dc7e1oE',
#  'Dc7e6oA',
#  'Dc7e6oB',
#  'Dc7h13-1',
#  'Dc7h13-2',
#  'Dc7h15',
#  'Dc7oA',
#  'Dc7oAoC',
#  'Dc7oBoGqA',
#  'Dc8h15-2',
#  'Dc8h17',
#  'Dc9e8oA',
#  'Dc9e8oB',
#  'Dc9e8oC',
#  'Dc9h17-2',
#  'Dc9h19',
#  'Dc9oAoCqF',
#  'Dc9oAqF',
#  'Dchxe2oA',
#  'DchxoAoC',
#  'Dchxone',
#  'DchxoqB',
#  'Dmche1',
#  'Do2pchohC',
#  'Do2pchohE',
#  'Dpche2',
#  'Dpche5',
#  'Dpche5e7',
#  'DpchoA',
#  'DpchoB',
#  'DpchoC',
#  'DpchoE',
#  'DpchoEqB',
#  'DpchoF',
#  'DpchoG',
#  'DpchohC',
#  'DpchohE',
#  'DpchqA',
#  'DpchqB',
#  'DpchqBqE',
#  'DpchqC',
#  'DpchqCqE',
#  'DpchqCqF',
#  'DpchqE',
#  'DpchqEqG',
#  'DpchqEqH',
#  'DpchqF',
#  'DpchqFqH',
#  'DpchqG',
#  'Ec10h19-3',
#  'Ec10h21',
#  'Ec5e1oC',
#  'Ec5e4oA',
#  'Ec5e4oB',
#  'Ec5h9-1',
#  'Ec5h9-2',
#  'Ec5oA',
#  'Ec5oAoB',
#  'Ec5oAoC',
#  'Ec5oAoD',
#  'Ec6e5oA',
#  'Ec6h9-13',
#  'Ec7e6oA',
#  'Ec7e6oAoB',
#  'Ec7h13-3',
#  'Ec8h15-1',
#  'Ec8h15-3',
#  'Ec8oA',
#  'Ec9h17-3',
#  'Ec9h19',
#  'Echxe1qC',
#  'Echxe2oAoD',
#  'Emche13',
#  'Eo2pchohD',
#  'Eo2pchohF',
#  'Epche6',
#  'EpchoA',
#  'EpchoB',
#  'EpchoC',
#  'EpchoF',
#  'EpchoG',
#  'EpchoH',
#  'EpchohD',
#  'EpchohF',
#  'EpchqA',
#  'EpchqB',
#  'EpchqC',
#  'EpchqCqF',
#  'EpchqD',
#  'EpchqDqB',
#  'EpchqE',
#  'EpchqF',
#  'EpchqFqH',
#  'EpchqG',
#  'EtBc5e7oyA',
#  'EtCc6e1rH',
#  'EtCc6oArH',
#  'EtDc7e1e8ojE',
#  'EtDc7e1e8qE',
#  'EtDc7e1oCrI',
#  'EtDc7e1oHrI',
#  'EtDc7e1oIojD',
#  'EtDc7e1oIojE',
#  'EtDc7e1oIqD',
#  'EtDc7e1oIqE',
#  'EtDc7e1oIrC',
#  'EtDc7e1oyI',
#  'EtDc7e1qEqHrI',
#  'EtDc7e3oIrG',
#  'EtDc7e4oIrA',
#  'EtDc7e6oArI',
#  'EtDc7e6oBrI',
#  'EtDc7e6oCrI',
#  'EtDc7e9oAojC',
#  'EtDc7e9oAqC',
#  'EtDc7e9oArG',
#  'EtDc7e9oBrA',
#  'EtDc7e9oBrG',
#  'EtDc7e9oCrA',
#  'EtDc7e9oCrH',
#  'EtDc7e9oyA',
#  'EtDc7oAoCrI',
#  'EtDc7oAoEoIqC',
#  'EtDc7oAoEoIqD',
#  'EtDc7oAoHrI',
#  'EtDc7oAoI',
#  'EtDc7oAoIqC',
#  'EtDc7oAoIqD',
#  'EtDc7oAoyI',
#  'EtDc7oAqIqjD',
#  'EtDc7oAqjI',
#  'EtDc7oArI',
#  'EtDc7oBoIrA',
#  'EtDc7oCoIrA',
#  'EtDc7oEoIqAqjC',
#  'EtDc7oEoIqAqjD',
#  'EtDc7oEoIqjA',
#  'EtDc7oEoIrA',
#  'EtDc7oIqAqjC',
#  'EtDc7oIqAqjD',
#  'EtDc7oIqjA',
#  'EtDc7oIrA',
#  'EtDc7oyAoI',
#  'Etall',
#  'FMeEc8oAqI',
#  'Fc10h19-4',
#  'Fc10h19oB',
#  'Fc6e1e4',
#  'Fc6e1oA',
#  'Fc6e1oC',
#  'Fc6e1oCoE',
#  'Fc6e2oA',
#  'Fc6e3oAoE',
#  'Fc6e5oA',
#  'Fc6h11-1',
#  'Fc6h9-13',
#  'Fc6oAoC',
#  'Fc6oAoCoD',
#  'Fc6oAoDoE',
#  'Fc6oAoE',
#  'Fc9e1oC',
#  'Fc9e1oD',
#  'Fc9e1oE',
#  'Fc9e1qAqH',
#  'Fc9e1qDqF',
#  'Fc9e1qEqG',
#  'Fc9e1qEqH',
#  'Fc9e4oA',
#  'Fc9h17-4',
#  'Fc9oA',
#  'Fc9oAoC',
#  'Fc9oAoD',
#  'Fc9oAoE',
#  'Fc9oAoG',
#  'Fc9oAoH',
#  'Fmche14',
#  'Fo2pchohE',
#  'Fo2pchohG',
#  'Fpche7',
#  'FpchoA',
#  'FpchoB',
#  'FpchoC',
#  'FpchoE',
#  'FpchoG',
#  'FpchohE',
#  'FpchohG',
#  'FpchqA',
#  'FpchqB',
#  'FpchqBqE',
#  'FpchqC',
#  'FpchqCqE',
#  'FpchqD',
#  'FpchqDqE',
#  'FpchqE',
#  'FpchqEqG',
#  'FpchqEqH',
#  'FpchqF',
#  'FpchqG',
#  'GMeEc8oAoCqI',
#  'Gc10h19oC',
#  'Gc7e1e3',
#  'Gc7e1oC',
#  'Gc7e1oD',
#  'Gc7e1oE',
#  'Gc7e1oF',
#  'Gc7e3oA',
#  'Gc7e3oB',
#  'Gc7e4oA',
#  'Gc7e4oB',
#  'Gc7e4oC',
#  'Gc7h13-1',
#  'Gc7h13-3',
#  'Gc7oAoD',
#  'Gc7oBoD',
#  'Gc7oCoD',
#  'Gic7al',
#  'Gmche13',
#  'Gmche14',
#  'Go2pchohF',
#  'Gpc7al',
#  'GpchoB',
#  'GpchoC',
#  'GpchoE',
#  'GpchoF',
#  'GpchohF',
#  'GpchqA',
#  'GpchqB',
#  'GpchqBqE',
#  'GpchqC',
#  'GpchqCqE',
#  'GpchqCqF',
#  'GpchqD',
#  'GpchqDqF',
#  'GpchqE',
#  'GpchqEqH',
#  'GpchqEqI',
#  'GpchqF',
#  'GpchqG',
#  'Hc8h15-1',
#  'Hc8h15-3',
#  'Hc8oD',
#  'Hc9oAoGqF',
#  'Hc9oAqF',
#  'HpchoE',
#  'HpchoF',
#  'HpchqBqE',
#  'HpchqCqE',
#  'HpchqCqF',
#  'HpchqDqF',
#  'HpchqE',
#  'HpchqEqG',
#  'HpchqF',
#  'Ic9e3oA',
#  'Ic9e3oB',
#  'Ic9e3oE',
#  'Ic9e3qFqH',
#  'Ic9e4oA',
#  'Ic9e4oB',
#  'Ic9e4oC',
#  'Ic9oAoD',
#  'Ic9oBoD',
#  'Ic9oCoD',
#  'Iic9e1qDqI',
#  'Ipc9oAoB',
#  'Ipche4e6',
#  'Ipche5e7',
#  'IpchoE',
#  'IpchqBqE',
#  'IpchqCqE',
#  'IpchqCqF',
#  'IpchqE',
#  'IpchqEqG',
#  'IpchqEqH',
#  'IpchqF',
#  'Lc6h4',
#  'Lc6h6',
#  'Lc6h7',
#  'MeBc4e1oErD',
#  'MeBc5e1e4rF',
#  'MeBc5e1rF',
#  'MeBc5e4oArF',
#  'MeBc5e6oArE',
#  'MeBc5oAoCrF',
#  'MeBc5oAoF',
#  'MeBc5oArF',
#  'MeBc5oyAoF',
#  'MeBc6e7oAoF',
#  'MeBc6e7oAoyF',
#  'MeBc6e7oyAoF',
#  'MeCc4e3oArE',
#  'MeCc5e4e5oA',
#  'MeCc5e4e5oyA',
#  'MeCc6e1e7rF',
#  'MeCc6e1oDrG',
#  'MeCc6e1oG',
#  'MeCc6e1oyG',
#  'MeCc6e1rG',
#  'MeCc6e3oArG',
#  'MeCc6e5e7oA',
#  'MeCc6e5e7oyA',
#  'MeCc6e5oAoG',
#  'MeCc6e5oAoyG',
#  'MeCc6e5oyAoG',
#  'MeCc6e7oA',
#  'MeCc6e7oAqErF',
#  'MeCc6e7oArF',
#  'MeCc6e7oBrA',
#  'MeCc6e7oDrA',
#  'MeCc6e7oyA',
#  'MeCc6oAoDoG',
#  'MeCc6oAoDoyG',
#  'MeCc6oAoDrG',
#  'MeCc6oAoG',
#  'MeCc6oAoyG',
#  'MeCc6oBoGrA',
#  'MeCc6oyAoDoG',
#  'MeCc6oyAoG',
#  'MeDc6e5oArG',
#  'MeDc6e5oBrG',
#  'MeDc6e7oArF',
#  'MeDc6e7oBrF',
#  'MeDc6oBoGrF',
#  'MeDc6oCoGrF',
#  'MeDc7e1rH',
#  'MeDc7e8rA',
#  'MeDc7oArH',
#  'MeDc7oHrA',
#  'MeDc8e7oBrI',
#  'MeDc8e7oCrI',
#  'MeDc8e9oArH',
#  'MeDc8e9oBrH',
#  'MeDc8e9oCrH',
#  'MeDc8oBoIrH',
#  'MeDc8oCoIrH',
#  'MeEc6e1oGrF',
#  'MeEc6e5oAqCrG',
#  'MeEc6e5oArG',
#  'MeEc6e5oBrG',
#  'MeEc7e6e8oA',
#  'MeEc7e6e8oyA',
#  'MeEc8e1oCrI',
#  'MeEc8e1oDrI',
#  'MeEc8e1oIojD',
#  'MeEc8e1oIojF',
#  'MeEc8e1oIojG',
#  'MeEc8e1oIqD',
#  'MeEc8e1oIqF',
#  'MeEc8e1oIqG',
#  'MeEc8e1oIrC',
#  'MeEc8e1oyI',
#  'MeEc8e5oArI',
#  'MeEc8e8oAojF',
#  'MeEc8e8oAqF',
#  'MeEc8e9oAojC',
#  'MeEc8e9oAqC',
#  'MeEc8e9oArD',
#  'MeEc8e9oBrH',
#  'MeEc8e9oCrA',
#  'MeEc8e9oDrA',
#  'MeEc8e9oyA',
#  'MeEc8oAoCoIqD',
#  'MeEc8oAoCoIqG',
#  'MeEc8oAoCqIqjD',
#  'MeEc8oAoCqIqjG',
#  'MeEc8oAoCqjI',
#  'MeEc8oAoCrI',
#  'MeEc8oAoDrI',
#  'MeEc8oAoFrI',
#  'MeEc8oAoI',
#  'MeEc8oAoIqC',
#  'MeEc8oAoIqD',
#  'MeEc8oAoIqF',
#  'MeEc8oAoyI',
#  'MeEc8oAqIqjD',
#  'MeEc8oAqIqjF',
#  'MeEc8oAqjI',
#  'MeEc8oArI',
#  'MeEc8oBoIrA',
#  'MeEc8oCoIrA',
#  'MeEc8oDoIrA',
#  'MeEc8oIqAqjC',
#  'MeEc8oIqAqjD',
#  'MeEc8oIqjA',
#  'MeEc8oIrA',
#  'MeEc8oyAoI',
#  'Mec8oor',
#  'P2c4h4134',
#  'U-c6h5',
#  'ac3h4',
#  'ac3h4hco1',
#  'ac3h5',
#  'ac3h5co',
#  'ac3h5hco',
#  'aceton',
#  'acrol',
#  'ar',
#  'b1*o4ol',
#  'b1j*o4ol',
#  'b1jol3e',
#  'b1ol',
#  'b1ol1j',
#  'b1ol2e4j',
#  'b1ol2j',
#  'b1ol3e',
#  'b1ol3j',
#  'b1ol4j',
#  'bbdtmpe1',
#  'bbdtmpe3',
#  'bddm1pe',
#  'bddm1pe1',
#  'bddm1pe3',
#  'bddm2pe',
#  'bddm2pe1',
#  'bddm2pe3',
#  'bddm3pe2',
#  'bddmpe2',
#  'bddtmpe1',
#  'bddtmpe2',
#  'biphenyl',
#  'bme1bu',
#  'bme2b1',
#  'bme2bu',
#  'bme2pe4',
#  'bmepral',
#  'bmepryl',
#  'butanone',
#  'butyn2',
#  'butyne',
#  'c10h10',
#  'c10h19oAqB',
#  'c10h19oAqC',
#  'c10h19oAqD',
#  'c10h19oAqE',
#  'c10h19oBqA',
#  'c10h19oBqC',
#  'c10h19oBqD',
#  'c10h19oBqE',
#  'c10h19oBqF',
#  'c10h19oCqA',
#  'c10h19oCqB',
#  'c10h19oCqD',
#  'c10h19oCqE',
#  'c10h19oCqF',
#  'c10h19oCqG',
#  'c10h19oDqA',
#  'c10h19oDqB',
#  'c10h19oDqC',
#  'c10h19oDqE',
#  'c10h19oDqF',
#  'c10h19oDqG',
#  'c10h19oDqH',
#  'c10h19oEqA',
#  'c10h19oEqB',
#  'c10h19oEqC',
#  'c10h19oEqD',
#  'c10h19oEqF',
#  'c10h19oEqG',
#  'c10h19oEqH',
#  'c10h19oEqI',
#  'c10h20-1',
#  'c10h20-2',
#  'c10h20-3',
#  'c10h20-4',
#  'c10h20-5',
#  'c10h20o-AB',
#  'c10h20o-AC',
#  'c10h20o-AD',
#  'c10h20o-AE',
#  'c10h20o-BC',
#  'c10h20o-BD',
#  'c10h20o-BE',
#  'c10h20o-BF',
#  'c10h20o-CD',
#  'c10h20o-CE',
#  'c10h20o-CF',
#  'c10h20o-CG',
#  'c10h20o-DE',
#  'c10h20o-DF',
#  'c10h20o-DG',
#  'c10h20o-EF',
#  'c10h20qjAqB',
#  'c10h20qjAqC',
#  'c10h20qjAqD',
#  'c10h20qjAqE',
#  'c10h20qjBqA',
#  'c10h20qjBqC',
#  'c10h20qjBqD',
#  'c10h20qjBqE',
#  'c10h20qjCqA',
#  'c10h20qjCqB',
#  'c10h20qjCqD',
#  'c10h20qjCqE',
#  'c10h20qjDqA',
#  'c10h20qjDqB',
#  'c10h20qjDqC',
#  'c10h20qjDqE',
#  'c10h20qjEqA',
#  'c10h20qjEqB',
#  'c10h20qjEqC',
#  'c10h20qjEqD',
#  'c10h20qjFqB',
#  'c10h20qjFqC',
#  'c10h20qjFqD',
#  'c10h20qjFqE',
#  'c10h20qjGqC',
#  'c10h20qjGqD',
#  'c10h20qjGqE',
#  'c10h20qjHqD',
#  'c10h20qjHqE',
#  'c10h20qjIqE',
#  'c10h20qjohAB',
#  'c10h20qjohBC',
#  'c10h20qjohCD',
#  'c10h20qjohDE',
#  'c10h20qjohEF',
#  'c10h20rAqB',
#  'c10h20rAqC',
#  'c10h20rAqD',
#  'c10h20rAqE',
#  'c10h20rBqA',
#  'c10h20rBqC',
#  'c10h20rBqD',
#  'c10h20rBqE',
#  'c10h20rCqA',
#  'c10h20rCqB',
#  'c10h20rCqD',
#  'c10h20rCqE',
#  'c10h20rDqA',
#  'c10h20rDqB',
#  'c10h20rDqC',
#  'c10h20rDqE',
#  'c10h20rEqA',
#  'c10h20rEqB',
#  'c10h20rEqC',
#  'c10h20rEqD',
#  'c10h20rFqB',
#  'c10h20rFqC',
#  'c10h20rFqD',
#  'c10h20rFqE',
#  'c10h20rGqC',
#  'c10h20rGqD',
#  'c10h20rGqE',
#  'c10h20rHqD',
#  'c10h20rHqE',
#  'c10h20rIqE',
#  'c10h20rohAB',
#  'c10h20rohBC',
#  'c10h20rohCD',
#  'c10h20rohDE',
#  'c10h20rohEF',
#  'c10h21ojA',
#  'c10h21ojB',
#  'c10h21ojC',
#  'c10h21ojD',
#  'c10h21ojE',
#  'c10h21qA',
#  'c10h21qB',
#  'c10h21qC',
#  'c10h21qD',
#  'c10h21qE',
#  'c10h21qjA',
#  'c10h21qjB',
#  'c10h21qjC',
#  'c10h21qjD',
#  'c10h21qjE',
#  'c10h9',
#  'c14h14',
#  'c2',
#  'c2c4h8',
#  'c2c5h10',
#  'c2h',
#  'c2h2',
#  'c2h2oh',
#  'c2h3',
#  'c2h3ch2oh',
#  'c2h3chcho',
#  'c2h3choh',
#  'c2h3co',
#  'c2h3coc2h4',
#  'c2h3coc3h6-2',
#  'c2h3coc3h6-3',
#  'c2h3coc3h7',
#  'c2h3coc4h8-3',
#  'c2h3coc4h8-4',
#  'c2h3coc4h9',
#  'c2h3coc5h10-4',
#  'c2h3coc5h10-5',
#  'c2h3coc5h11',
#  'c2h3coc6h12-5',
#  'c2h3coc6h12-6',
#  'c2h3coc6h13',
#  'c2h3coch2co',
#  'c2h3coch2hco',
#  'c2h3coch2oh',
#  'c2h3cochoh',
#  'c2h3coco',
#  'c2h3cohco',
#  'c2h3cooh',
#  'c2h3o',
#  'c2h4',
#  'c2h4cohco',
#  'c2h4o',
#  'c2h4o2h',
#  'c2h5',
#  'c2h5co',
#  'c2h5coc2h3',
#  'c2h5coc2h4o',
#  'c2h5coc2h4o2',
#  'c2h5coc2h4o2h',
#  'c2h5coc2h4p',
#  'c2h5coc2h4s',
#  'c2h5coc2h5',
#  'c2h5coc3h4',
#  'c2h5coc3h5-1',
#  'c2h5coc3h6-1',
#  'c2h5coc3h6o-1',
#  'c2h5coc3h6o2-1',
#  'c2h5coc3h6o2h-1',
#  'c2h5coc5h8-13',
#  'c2h5coc5h8-15',
#  'c2h5coc5h9-1',
#  'c2h5coch2',
#  'c2h5coch2o',
#  'c2h5coch2o2',
#  'c2h5coch2o2h',
#  'c2h5o',
#  'c2h5o2',
#  'c2h5o2h',
#  'c2h5oh',
#  'c2h6',
#  'c2hco',
#  'c2o',
#  'c3h2',
#  'c3h3',
#  'c3h3co',
#  'c3h3hco',
#  'c3h3o',
#  'c3h4hco',
#  'c3h4o',
#  'c3h4o2h',
#  'c3h4oh',
#  'c3h5co',
#  'c3h5e1q2',
#  'c3h5o',
#  'c3h5o2h',
#  'c3h5oh',
#  'c3h6',
#  'c3h6cho-1',
#  'c3h6coc2h3-1',
#  'c3h6coc2h3-2',
#  'c3h6coc2h3-3',
#  'c3h6coch3-1',
#  'c3h6coch3-2',
#  'c3h6coch3-3',
#  'c3h6o',
#  'c3h6o1-3',
#  'c3h6oh',
#  'c3h6ooh1-1',
#  'c3h6ooh1-1o2',
#  'c3h6ooh1-2',
#  'c3h6ooh1-2o2',
#  'c3h6ooh1-3',
#  'c3h6ooh1-3o2',
#  'c3h6ooh2-1',
#  'c3h6ooh2-1o2',
#  'c3h7chco',
#  'c3h7co',
#  'c3h7coc2h3',
#  'c3h7coch3',
#  'c3h8',
#  'c3ket12',
#  'c3ket13',
#  'c3ket21',
#  'c4h',
#  'c4h10',
#  'c4h2',
#  'c4h4',
#  'c4h4o',
#  'c4h5co',
#  'c4h5hco',
#  'c4h6',
#  'c4h6o2h',
#  'c4h7co-1',
#  'c4h7co-2',
#  'c4h7hco-1',
#  'c4h7hco-2',
#  'c4h7o',
#  'c4h7o2h',
#  'c4h7oAqB',
#  'c4h7oAqC',
#  'c4h7oAqD',
#  'c4h7oBqA',
#  'c4h7oBqC',
#  'c4h7oBqD',
#  'c4h7oh',
#  'c4h8',
#  'c4h8hco-2',
#  'c4h8o',
#  'c4h8o#3',
#  'c4h8o#4',
#  'c4h8o#5',
#  'c4h8o2',
#  'c4h8qjAqA',
#  'c4h8qjAqB',
#  'c4h8qjBqA',
#  'c4h8qjCqA',
#  'c4h8qjCqB',
#  'c4h8qjDqA',
#  'c4h8qjDqB',
#  'c4h8rAqA',
#  'c4h8rAqB',
#  'c4h8rBqA',
#  'c4h8rCqA',
#  'c4h8rCqB',
#  'c4h8rDqA',
#  'c4h8rDqB',
#  'c4h9coco',
#  'c4h9cohco',
#  'c4h9o',
#  'c4h9qjA',
#  'c4h9qjB',
#  'c4oAoC',
#  'c4oyAoC',
#  'c5e2oA',
#  'c5e2oyA',
#  'c5e4oAoC',
#  'c5e4oB',
#  'c5e4oyAoC',
#  'c5h10',
#  'c5h10o-AB',
#  'c5h10o-AC',
#  'c5h10o-AD',
#  'c5h10o-AE',
#  'c5h10o-BC',
#  'c5h10o-BD',
#  'c5h10qjAqA',
#  'c5h10qjAqB',
#  'c5h10qjAqC',
#  'c5h10qjBqA',
#  'c5h10qjBqB',
#  'c5h10qjBqC',
#  'c5h10qjCqA',
#  'c5h10qjCqB',
#  'c5h10qjDqA',
#  'c5h10qjDqB',
#  'c5h10qjEqA',
#  'c5h10qjEqB',
#  'c5h10rAqA',
#  'c5h10rAqB',
#  'c5h10rAqC',
#  'c5h10rBqA',
#  'c5h10rBqB',
#  'c5h10rBqC',
#  'c5h10rCqA',
#  'c5h10rCqB',
#  'c5h10rDqA',
#  'c5h10rDqB',
#  'c5h10rEqA',
#  'c5h10rEqB',
#  'c5h11co',
#  'c5h11hco',
#  'c5h11qjA',
#  'c5h11qjB',
#  'c5h11qjC',
#  'c5h3',
#  'c5h4',
#  'c5h4o',
#  'c5h4oh',
#  'c5h5',
#  'c5h5o',
#  'c5h7',
#  'c5h8-12',
#  'c5h8-13',
#  'c5h8-14',
#  'c5h9co-1',
#  'c5h9co-2',
#  'c5h9co-3',
#  'c5h9hco-1',
#  'c5h9hco-2',
#  'c5h9hco-3',
#  'c5h9oAqA',
#  'c5h9oAqB',
#  'c5h9oAqC',
#  'c5h9oAqD',
#  'c5h9oAqE',
#  'c5h9oBqA',
#  'c5h9oBqC',
#  'c5h9oBqD',
#  'c5h9oBqE',
#  'c5h9oCqA',
#  'c5h9oCqB',
#  'c5h9oh',
#  'c5oAoE',
#  'c5oAoEqB',
#  'c5oAoEqC',
#  'c5oAqEqjB',
#  'c5oAqEqjC',
#  'c5oAqjE',
#  'c5oBqjDohE',
#  'c5oyAoE',
#  'c6alCco',
#  'c6e1e5oC',
#  ...]

# %%
for species in gas.species():
    if species.composition == {'C':8, 'H':18}:
        print(species.name)
# Out:
# nc8h18
# ic8h18

# %%
gas.TP = 900, 16e5
gas.set_equivalence_ratio(phi=1.0, fuel='ic8h18', oxidizer='o2:0.2, n2:0.8' )
gas()
# Out:
#   gas:
#
#        temperature             900  K
#           pressure         1.6e+06  Pa
#            density         6.44783  kg/m^3
#   mean mol. weight         30.1557  amu
#
#                           1 kg            1 kmol
#                        -----------      ------------
#           enthalpy      5.8703e+05         1.77e+07     J
#    internal energy      3.3889e+05        1.022e+07     J
#            entropy          7226.1        2.179e+05     J/K
#     Gibbs function     -5.9164e+06       -1.784e+08     J
#  heat capacity c_p          1287.9        3.884e+04     J/K
#  heat capacity c_v          1012.2        3.052e+04     J/K
#
#                            X                 Y          Chem. Pot. / RT
#                      -------------     ------------     ------------
#                 o2        0.19685         0.208881         -25.1522
#                 n2       0.787402         0.731465         -22.0654
#             ic8h18       0.015748         0.059654         -96.3342
#      [+2179 minor]              0                0

# %%
def set_gas_concentrations(gas, phi):
    """
    Set the concentrations in the gas according to the description
    in the paper by 
    """
    # Set it to desired stoichiometry with synthetic air (20% O2 : 80% N2)
    gas.set_equivalence_ratio(phi=phi, fuel='ic8h18', oxidizer='o2:0.2, n2:0.8' )
    # Then dilute the whole thing 1:2 with extra N2
    X = gas.X / 3.0 
    X[gas.species_index('n2')] += 2./3.
    gas.X = X

set_gas_concentrations(gas, 1.0)
gas()
# Out:
#   gas:
#
#        temperature             900  K
#           pressure     1.67954e+06  Pa
#            density         6.44783  kg/m^3
#   mean mol. weight         28.7276  amu
#
#                           1 kg            1 kmol
#                        -----------      ------------
#           enthalpy      6.2831e+05        1.805e+07     J
#    internal energy      3.6783e+05        1.057e+07     J
#            entropy          7219.8        2.074e+05     J/K
#     Gibbs function     -5.8695e+06       -1.686e+08     J
#  heat capacity c_p          1196.3        3.437e+04     J/K
#  heat capacity c_v          906.86        2.605e+04     J/K
#
#                            X                 Y          Chem. Pot. / RT
#                      -------------     ------------     ------------
#                 o2      0.0656168        0.0730886         -26.2022
#                 n2       0.929134         0.906038         -21.8513
#             ic8h18     0.00524934        0.0208732         -97.3843
#      [+2179 minor]              0                0

# %%
# time in microseconds          relative pressure
pressure_profile = """0		                       1.000
50		                       1.004
250		                       1.027
450		                       1.046
650		                       1.062
850		                       1.072
1050	                       1.088
1250	                       1.101
1450	                       1.127
1650	                       1.157
1850	                       1.170
2050	                       1.160
2250	                       1.152
2450	                       1.153
2650	                       1.148
2850	                       1.143
3050	                       1.139
3250	                       1.136
3450	                       1.140
3650	                       1.142
3850	                       1.142
4050	                       1.153
4250	                       1.161
4450	                       1.168
4650	                       1.165
4850	                       1.166
5050	                       1.168
5250	                       1.170
5450	                       1.172
5650	                       1.175
5850	                       1.175
6050	                       1.178
6250	                       1.181
6450	                       1.184
6650	                       1.187
6850	                       1.189
7050	                       1.189
7250	                       1.188
7450	                       1.188
7650	                       1.190
7850	                       1.192
8000	                       1.192
10000	                       1.192
"""
times = []
pressures = []
for l in pressure_profile.splitlines():
    time, pressure = l.split()
    times.append((float(time)/1e6))
    pressures.append(float(pressure))
times = np.array(times)
pressures = np.array(pressures)
times, pressures
# Out:
# (array([0.00e+00, 5.00e-05, 2.50e-04, 4.50e-04, 6.50e-04, 8.50e-04,
#         1.05e-03, 1.25e-03, 1.45e-03, 1.65e-03, 1.85e-03, 2.05e-03,
#         2.25e-03, 2.45e-03, 2.65e-03, 2.85e-03, 3.05e-03, 3.25e-03,
#         3.45e-03, 3.65e-03, 3.85e-03, 4.05e-03, 4.25e-03, 4.45e-03,
#         4.65e-03, 4.85e-03, 5.05e-03, 5.25e-03, 5.45e-03, 5.65e-03,
#         5.85e-03, 6.05e-03, 6.25e-03, 6.45e-03, 6.65e-03, 6.85e-03,
#         7.05e-03, 7.25e-03, 7.45e-03, 7.65e-03, 7.85e-03, 8.00e-03,
#         1.00e-02]),
#  array([1.   , 1.004, 1.027, 1.046, 1.062, 1.072, 1.088, 1.101, 1.127,
#         1.157, 1.17 , 1.16 , 1.152, 1.153, 1.148, 1.143, 1.139, 1.136,
#         1.14 , 1.142, 1.142, 1.153, 1.161, 1.168, 1.165, 1.166, 1.168,
#         1.17 , 1.172, 1.175, 1.175, 1.178, 1.181, 1.184, 1.187, 1.189,
#         1.189, 1.188, 1.188, 1.19 , 1.192, 1.192, 1.192]))

# %%
"""
Calculate an array of relative volumes, to correspond
to the array of relative pressures given by `pressures`
assuming isentropic compression/expansion.
"""
initial_pressure = 16e5
gas.TP = 900, initial_pressure
initial_entropy = gas.entropy_mass
initial_density = gas.density
initial_volume = 1.0
volumes = np.ones_like(pressures)
for i, p in enumerate(pressures):
    gas.SP = initial_entropy, p*initial_pressure
    volumes[i] = initial_volume*initial_density/gas.density
volumes
# Out:
# array([1.        , 0.99697827, 0.98000187, 0.96646952, 0.95540166,
#        0.94863061, 0.93802287, 0.92960222, 0.91327009, 0.89522296,
#        0.88765364, 0.89346307, 0.89817386, 0.8975819 , 0.90055072,
#        0.90354217, 0.90595181, 0.90776874, 0.90534802, 0.9041432 ,
#        0.9041432 , 0.8975819 , 0.8928782 , 0.88880859, 0.89054748,
#        0.88996698, 0.88880859, 0.88765364, 0.88650214, 0.88478129,
#        0.88478129, 0.88306809, 0.88136248, 0.87966441, 0.87797383,
#        0.87685091, 0.87685091, 0.87741196, 0.87741196, 0.87629068,
#        0.87517269, 0.87517269, 0.87517269])

# %%
plt.plot(times, volumes, '.-')

# %%
import scipy.interpolate
spl = scipy.interpolate.UnivariateSpline(times, volumes, k=3,s=0.0001)

plt.plot(times, volumes, '.', label="From experiment profile,\nassuming isentropic compression")
t=np.linspace(0,max(times),1000)
plt.plot(t, spl(t), label="Interpolated spline")
plt.xlabel('Time (s)')
plt.ylabel('Volume (m$^3$)')
plt.legend(loc='best')

# %%
velocity = spl.derivative(n=1)

# %%
plt.plot(t, velocity(t))
plt.xlabel('Time (s)')
plt.ylabel('Wall velocity (m/s)')
plt.hlines(0,0,max(t))

# %%
def get_ignition_delay(gas, temperature, pressure_bar, mole_fractions, plot=False):
    """
    A general function to find the igniton delay.
    Using C2H + O --> CH* as the indication of ignition
    
    gas is a cantera Solution object
    temperature in K
    pressure_bar is in bar
    mole_fractions is a dict
    """
    gas.TPX = temperature, pressure_bar*1e5, mole_fractions

    reactor = ct.IdealGasReactor(gas)
    environment = ct.Reservoir(ct.Solution('air.xml'))

    ct.Wall(reactor, environment, A=1.0, velocity=velocity)
    reactor_network = ct.ReactorNet([reactor])
    
    time = 0.0
    end_time = 10e-3
    
    times = []
    concentrations = []
    pressures = []
    temperatures = []
    volumes = []
    
    print_data = True
    while time < end_time:
        time = reactor_network.time
        times.append(time)
        temperatures.append(reactor.T)
        pressures.append(reactor.thermo.P)
        concentrations.append(reactor.thermo.concentrations)
        volumes.append(reactor.volume)
        # take a timestep
        # the size of the step will be determined by the ODE solver
        # depending on how quickly things are changing.
        reactor_network.step()
    
    print("Reached end time {0:.2f} ms in {1} steps".format(times[-1]*1e3, len(times)))
    # convert the lists into arrays
    concentrations = np.array(concentrations)
    times = np.array(times)
    pressures = np.array(pressures)
    temperatures = np.array(temperatures)
    volumes = np.array(volumes)

    if plot:
        plt.plot(times*1e3, volumes)
        plt.ylabel("Volume")
        plt.xlabel("Time (ms)")
        plt.tight_layout()
        plt.show()
    
    if plot:
        plt.subplot(2,1,1)
        plt.plot(times*1e3, pressures/1e5)
        plt.ylabel("Pressure (bar)", color='b')
        ax2 = plt.gca().twinx()
        ax2.set_ylabel('Temperature (K)', color='r')
        ax2.plot(times*1e3, temperatures, 'r')
    # Using C2H + O --> CH* as the indication of ignition
    i_c2h = gas.species_index('C2H')   
    i_o = gas.species_index('O')
    excited_ch_generation = concentrations[:,i_o] * concentrations[:,i_c2h]
    if plot:
        plt.subplot(2,1,2)
        plt.plot(times*1e3, excited_ch_generation, 'g')
        plt.ylabel("CH* emission")
        plt.ylim(0,max(1e-13,1.1*max(excited_ch_generation)))
        plt.xlabel("Time (ms)")
        plt.tight_layout()
        plt.show()
    step_with_highest_ch_gen = excited_ch_generation.argmax()
    if step_with_highest_ch_gen > 1 and excited_ch_generation.max()>1e-20:
        ignition_time_ms = 1e3 * times[step_with_highest_ch_gen]
        print("At {0} K {1} bar, ignition delay time is {2} ms".format(temperature, pressure_bar, ignition_time_ms))
        return ignition_time_ms
    else:
        print("At {0} K {1} bar, no ignition detected".format(temperature, pressure_bar))
        return np.infty

# %%
def get_ignition_delay_air_n2(temperature, pressure_bar=16, phi=1.0, plot=False):
    """
    For figure 14. Uses synthetic air, diluted in N2.
    
    temperature in K
    pressure in bar
    phi is equivalence ratio
    """
    set_gas_concentrations(gas, phi)
    mole_fractions = gas.X
    if plot:
        gas()
    time = get_ignition_delay(gas, temperature, pressure_bar, mole_fractions, plot=plot)
    return time

# %%
plt.rcParams['figure.figsize'] = [10, 8]
get_ignition_delay_air_n2(1000/.8, 16, 1, plot=True)

# %%
DAG_temperatures = 1000/np.linspace(0.70,1.5,10)
pressures_bar = 16
phi = 1

DAG_results = dict()
times = []
for T in DAG_temperatures:
    t = get_ignition_delay_air_n2(T, pressures_bar, phi, plot=False)
    times.append(t)
    DAG_results[pressures_bar] = times
# Out:
#   gas:
#
#        temperature         1342.75  K
#           pressure     2.65825e+06  Pa
#            density         6.84018  kg/m^3
#   mean mol. weight         28.7276  amu
#
#                           1 kg            1 kmol
#                        -----------      ------------
#           enthalpy      1.1795e+06        3.388e+07     J
#    internal energy       7.909e+05        2.272e+07     J
#            entropy          7584.1        2.179e+05     J/K
#     Gibbs function      -9.004e+06       -2.587e+08     J
#  heat capacity c_p          1284.7        3.691e+04     J/K
#  heat capacity c_v          995.23        2.859e+04     J/K
#
#                            X                 Y          Chem. Pot. / RT
#                      -------------     ------------     ------------
#                 o2      0.0656168        0.0730886          -26.887
#                 n2       0.929134         0.906038         -22.4745
#             ic8h18     0.00524934        0.0208732         -99.6022
#      [+2179 minor]              0                0

# %%
plt.semilogy(1000/DAG_temperatures, times, label='{}bar'.format(pressures_bar))
plt.legend(loc='best')
plt.xlabel('1000 K / $T$')
plt.ylabel('$\\tau_{ign} = t([CH^*]_{max})/ms$')

plt.rcParams['figure.figsize'] = [10, 8]

# %%
import pickle
with open('ic8-LLNL.pkl', 'rb') as fp:
    (LLNL_temperatures, LLNL_results) = pickle.load(fp)

# %%
import pickle
with open('ic8-RMG.pkl','rb') as fp:
    (RMG_temperatures, RMG_results) = pickle.load(fp)

# %% [markdown]
# ### Using the predictions for ignition delay of iso-octane with pressure profile from Fig. 14 of Dagaut et al.

# %%
# extracted values of predicted ignition delay for iso-octane in Fig.14 
# using the docstrings
predict_ic8 = """0.657614                 0.0438935
0.660053                 0.0508193
0.668666                 0.0605986
0.674810                 0.0712038
0.682193                 0.0824521
0.690803                 0.0997690
0.695710                 0.117224
0.705556                 0.141850
0.712933                 0.169140
0.722793                 0.193028
0.730166                 0.233559
0.740019                 0.274467
0.748628                 0.332111
0.759721                 0.384622
0.765868                 0.445364
0.775710                 0.546873
0.786810                 0.615061
0.799138                 0.712339
0.806515                 0.849383
0.818843                 0.983721
0.829936                 1.13926
0.843501                 1.31950
0.852120                 1.52800
0.864449                 1.76967
0.878014                 2.04964
0.889110                 2.33921
0.900212                 2.59264
0.910061                 3.09168
0.927338                 3.52918
0.935965                 3.96890
0.942116                 4.52889
0.958153                 5.24581
0.969245                 6.07524
0.985293                 6.73451
0.993909                 7.91373
1.00872                  8.90155
1.02476                  9.86753
1.03338                  11.4268
1.04572                  12.8521
1.06423                  14.6714
1.07409                  16.9904
1.08520                  18.5574
1.10124                  21.1825
1.11357                  23.4784
1.12466                  27.5917
1.13824                  30.1389
1.14933                  35.4191
1.16290                  39.8386
1.17523                  46.1394
1.18633                  51.8925
1.19865                  61.8858
1.20728                  68.5850
1.21961                  80.6040
1.23070                  94.7255
"""

ign_times = []
temps = []

for k in predict_ic8.splitlines():
    temp, ign_time = k.split()
    temps.append(float(temp))
    ign_times.append(float(ign_time))
    
ign_times = np.array(ign_times)
temps = np.array(temps)
#print(temps, ign_times)

# %%
experiment_ic8 = """ 0.742197            0.129438
0.792731            0.238540
0.858775            0.582623
0.897119            1.02386
0.916046            1.35725
1.01424             4.07608
1.05446             8.48794
1.08368             10.3738
1.11478             15.2007
1.16585             24.9217
1.17410             28.0282
1.18433             30.0848
"""

exp_ign_times = []
exp_temps = []



for z in experiment_ic8.splitlines():
    exp_temp, exp_ign_time = z.split()
    exp_temps.append(float(exp_temp))
    exp_ign_times.append(float(exp_ign_time))
    
exp_ign_times = np.array(exp_ign_times)
exp_temps = np.array(exp_temps)

# %%
plt.semilogy(temps,ign_times, 'r.:')
plt.semilogy(exp_temps,exp_ign_times, 'g+')
plt.title("Dagaut's Figure 14, iso-octane")

# %%
plt.semilogy(temps,ign_times, 'r.:',label='Dagaut et al. Prediction Fig.14'.format(pressures_bar))

plt.semilogy(exp_temps,exp_ign_times, 'g+',label='Dagaut et al. Experiment Fig.14'.format(pressures_bar))

plt.semilogy(1000/LLNL_temperatures,LLNL_results,label='LLNL model, {}bar'.format(pressures_bar))
plt.legend(loc='best')
plt.xlabel('1000 K / $T$')
plt.ylabel('$\\tau_{ign} = t([CH^*]_{max})/ms$')


plt.semilogy(1000/RMG_temperatures,RMG_results,label='RMG model, {}bar'.format(pressures_bar))
plt.legend(loc='best')
plt.xlabel('1000 K / $T$')
plt.ylabel('$\\tau_{ign} = t([CH^*]_{max})/ms$')

plt.semilogy(1000/DAG_temperatures,times,label='Dagaut et al. model, {}bar'.format(pressures_bar))
plt.legend(loc='best')
plt.xlabel('1000 K / $T$')
plt.ylabel('$\\tau_{ign} = t([CH^*]_{max})/ms$')
plt.rcParams['figure.figsize'] = [15, 10]

plt.title('Ignition delay of Iso-octane using Pressure Profile for a Non-constant volume reactor with a moving wall')
plt.show()
