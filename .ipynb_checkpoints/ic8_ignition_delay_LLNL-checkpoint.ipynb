# %% [markdown]
# # Trying to model ignition delay from LLNL for Iso-octane

# %%
import cantera as ct
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
from cantera import ck2cti
ck2cti.main([
    '--input=/Users/ebubeajulu/Code/GTL/ic8/ic8_ver3_mech.txt',
    '--thermo=/Users/ebubeajulu/Code/GTL/ic8/prf_icv3_therm_dat.txt',
    '--output=/Users/ebubeajulu/Code/GTL/ic8/chemkin/chem_annotated.cti',
    '--permissive'
        ])
# Out:
# WARNING:root:Found additional declaration of species CH2O2H
# WARNING:root:Found additional declaration of species TIC4H7Q2-I
# WARNING:root:Found additional declaration of species IIC4H7Q2-I
# WARNING:root:Found additional declaration of species IIC4H7Q2-T
# INFO:root:Skipping unexpected species "HOCO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CH3CHO2H" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5H12" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H11-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H11-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H11O-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H11O-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H11O-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H11O2H-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H11O2H-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H11O2H-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H11O2-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H11O2-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H11O2-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H11O-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H11O-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H11O-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH1-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH1-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH1-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH1-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH2-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH2-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH2-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH2-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH3-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH3-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10O1-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10O1-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10O1-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10O1-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10O2-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10O2-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH1-2O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH1-3O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH1-4O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH1-5O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH2-1O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH2-3O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH2-4O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH2-5O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH3-1O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OOH3-2O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5KET12" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5KET13" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5KET14" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5KET15" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5KET21" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5KET23" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5KET24" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5KET25" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5KET31" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5KET32" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OH-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10OH-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "O2C5H10OH-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "O2C5H10OH-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6H14" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H13-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H13-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H13-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H111-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H111-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H111-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H111-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H112-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H112-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H112-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H113-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H11O1-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H11O2-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12O1-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12O1-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12O1-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12O1-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12O2-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12O2-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12O2-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12O3-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H13O2H-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H13O2H-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H13O2H-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H13O2-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H13O2-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H13O2-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH1-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH1-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH1-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH1-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH2-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH2-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH2-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH2-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH2-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH3-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH3-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH3-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH3-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH3-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH1-2O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH1-3O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH1-4O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH1-5O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH2-1O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH2-3O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH2-4O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH2-5O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH2-6O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH3-1O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH3-2O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH3-4O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH3-5O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OOH3-6O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6KET12" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6KET13" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6KET14" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6KET15" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6KET21" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6KET23" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6KET24" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6KET25" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6KET26" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6KET31" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6KET32" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6KET34" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6KET35" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6KET36" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H13O-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H13O-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H13O-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OH-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OH-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H12OH-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "O2C6H12OH-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "O2C6H12OH-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "O2C6H12OH-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7H16" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H15-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H15-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H15-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H15-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H131-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H131-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H131-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H131-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H131-7" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H132-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H132-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H132-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H132-7" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H133-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H133-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H133-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H133-7" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H13O1-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H13O2-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H13O3-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H15O2-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H15O2-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H15O2-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H15O2-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H15O2H-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H15O2H-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H15O2H-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H15O2H-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H15O-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H15O-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H15O-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H15O-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH1-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH1-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH1-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH1-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH2-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH2-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH2-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH2-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH2-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH3-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH3-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH3-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH3-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH3-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH3-7" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH4-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH4-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH4-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH1-2O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH1-3O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH1-4O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH1-5O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH2-1O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH2-3O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH2-4O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH2-5O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH2-6O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH3-1O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH3-2O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH3-4O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH3-5O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH3-6O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH3-7O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH4-1O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH4-2O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OOH4-3O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14O1-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14O1-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14O1-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14O1-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14O2-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14O2-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14O2-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14O2-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14O3-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14O3-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET12" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET13" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET14" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET15" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET21" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET23" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET24" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET25" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET26" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET31" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET32" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET34" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET35" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET36" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET37" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET41" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET42" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC7KET43" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OH-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OH-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C7H14OH-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "O2C7H14OH-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "O2C7H14OH-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "O2C7H14OH-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5H11CHO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5H11CO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10CHO-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10CHO-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10CHO-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10CHO-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H10CHO-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC4H9COCH3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC4H9COCH2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C4H8COCH3-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C4H8COCH3-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C4H8COCH3-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C4H8COCH3-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C4H7OOH1-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C4H7O1-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H9OOH1-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H9O1-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H9OOH1-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H9O1-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H11OOH1-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H11O1-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H11OOH1-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H11O1-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H91-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C4H7CHO1-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C4H7CO1-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C4H6CHO1-14" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C4H6CHO1-13" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC3H7COC2H5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C3H6COC2H5-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C3H6COC2H5-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C3H6COC2H5-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC3H7COC2H4P" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC3H7COC2H4S" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CHCHCHO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H102-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "ETES1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "MVOX" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "VTHF" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "EDHF" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "ETC6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "KES1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H111O2H-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H111O2H-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H111O2H-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H111O2H-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H112O2H-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H112O2H-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H112O2H-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H113O2H-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H113O2H-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D1KET34" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D1KET35" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D1KET36" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D1KET43" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D1KET45" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D1KET46" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D1KET53" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D1KET54" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D1KET56" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D1KET63" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D1KET64" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D1KET65" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D2KET45" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D2KET46" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D2KET54" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D2KET56" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D2KET64" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D2KET65" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D3KET21" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC6D3KET12" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H112O2-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H111O2-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H111O2-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H111O2-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H111O2-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H112O2-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H112O2-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H112O2-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H113O2-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H113O2-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH3-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH3-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH3-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH4-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH4-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH4-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH5-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH5-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH5-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH6-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH6-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH6-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH3-4O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH3-5O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH3-6O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH4-3O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH4-5O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH4-6O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH5-3O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH5-4O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH5-6O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH6-3O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH6-4O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H101OOH6-5O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H102OOH5-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H103OOH1-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H102OOH4-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H102OOH4-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H102OOH5-6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H102OOH6-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H102OOH6-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H103OOH1-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H103OOH2-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H102OOH4-5O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H102OOH4-6O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H102OOH5-4O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H102OOH5-6O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H102OOH6-4O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H102OOH6-5O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H103OOH2-1O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H103OOH1-2O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C2H3COC3H7" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H81-4" while reading thermodynamics entry.
# WARNING:root:Found additional thermo entry for species C4H7CHO1-4. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C4H7CO1-4. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C4H6CHO1-43. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C4H6CHO1-44. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species NC3H7COCH3. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species NC3H7COCH2. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C3H6COCH3-1. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C3H6COCH3-2. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C3H6COCH3-3. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species AC3H5CHO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species AC3H5CO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C2H3CHCHO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C5H10-1. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C5H10-2. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C5H91-3. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C5H91-4. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C5H91-5. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C5H92-4. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C5H92-5. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C5H9O1-3. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C5H9O2-4. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C5H11-2. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species NC4H9CHO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species NC4H9CO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C4H8CHO-1. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C4H8CHO-2. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C4H8CHO-3. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C4H8CHO-4. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C2H5COC2H5. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C2H5COC2H4P. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C2H5COC2H4S. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C2H5COC2H3. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species PC2H4COC2H3. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species SC2H4COC2H3. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C5H81-3. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species CH2O2H. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species XC7H13O-Z. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species PC7H13O-O. If --permissive was given, the first entry is used.
# INFO:root:Skipping unexpected species "C7H162-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CH2COOH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "OLC8OOH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NE" while reading thermodynamics entry.
# WARNING:root:Found additional thermo entry for species OCHO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species O2CHO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species HOCHO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species HO2CHO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species HOCH2O. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C2H3O1-2. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C2H3CO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C2H3CHO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species CH2CCH2OH. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species CH3COCH2O. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species CH3CHOCHO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species CH3COCH2O2. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C3H6OH. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species TC3H6OH. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species HOC3H6O2. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C3H5OH. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species IC3H5OH. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C4H8OH-2O2. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C4H8OH-1O2. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species IO2C4H8OH. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species IC4H8OH. If --permissive was given, the first entry is used.
# INFO:root:Skipping unexpected species "C4H8OH-2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C4H8OH-1" while reading thermodynamics entry.
# WARNING:root:Found additional thermo entry for species CH3CHOOCOCH3. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species CH2CHOOHCOCH3. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species IC3H5O2HCHO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species TC3H6O2HCO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species TC3H6O2CHO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species IC4H6OH. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C4H7O. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species IC4H7O. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species TC3H6OHCHO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species IC4H7OH. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species IC4H7OOH. If --permissive was given, the first entry is used.
# INFO:root:Skipping unexpected species "C4H2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC4H3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "IC4H3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C4H4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC4H5" while reading thermodynamics entry.
# WARNING:root:Found additional thermo entry for species IC3H5CO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species SC3H5CO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species IC3H5CHO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species SC3H5CHO. If --permissive was given, the first entry is used.
# WARNING:root:Found additional thermo entry for species C2H3COCH3. If --permissive was given, the first entry is used.
# INFO:root:Skipping unexpected species "NC4H10" while reading thermodynamics entry.
# WARNING:root:Found additional thermo entry for species IC4H10. If --permissive was given, the first entry is used.
# INFO:root:Skipping unexpected species "C7H6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5CH3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5CH2J" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5CH2OOJ" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5CH2OOH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5CH2OJ" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5CH2OH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5CHOH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5CHO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5CJO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H4CH3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "OC6H4CH3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "HOC6H4CH3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "OC6H4O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "HOC6H4CH2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "HOC6H4CH2OO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "HOC6H4CH2O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "HOC6H4CH2OOH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "HOC6H4CHO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "HOC6H4CO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H4OH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H6" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "YOC6JDO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "RODC6JDO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "O*CC*CCJ*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "BICPD" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6JYOO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CY13PD" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5OH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CY13PD5J" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5OJ" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "FULVENE" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CYC5H8" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CH2CY24PD" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CYC6H7" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "FULVENYL" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CPDJCH3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "STYR" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "DICYPD" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CYC5H4CH3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CYC5H9" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "BICPDJ" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*CC(C#C)*C" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*CC*CCJ" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "LINC6H7" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*CC*CC" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CH3CY24PD" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CYC5H7_1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*CCJC*C" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CPDC*C" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CHDKO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CHDJKO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CYPDONE" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "HCOCJ*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CYC5H5OJ" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CYC5H5OH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CYC5H4OH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "O*CJC*CC*C" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CJ*C*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CJ*CC*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "O*CHOJ" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "HCOHCO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CPDOOH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*OCCJC*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "DHCO2J" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*OCJOH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CPDJONE" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*CC*C*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CJ*CC*C*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*CCJC*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*CCCJ*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "O*CC*CC*CJ" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*OCCCJC*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*OCC*CJ" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "O*CJC*CCC*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*OCCCJ*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*OCCC*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*OCJC*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*OCC*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*CCCO2J" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "O*CC*CC*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CYC4H5O21" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "O*CC*CCJC*O" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*OC*CCJ" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H5O1_1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C14H14" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C14H13" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "STYLBEN" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "XYLENE" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "IND" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NAPH" while reading thermodynamics entry.
# WARNING:root:Found additional thermo entry for species CH3OCO. If --permissive was given, the first entry is used.
# INFO:root:Skipping unexpected species "CR1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CR2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CR3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CR4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CR5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5C2H2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5CH2CHO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5CH2CO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5C2H" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C*CC*CCOH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "PHCPH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "O2C6H4CH3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "LC6H5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "HO2C6H4CH2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "RODC6J(C)DO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "OCC*CC*CJC" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5C2H2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5C2H5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C6H5C2H4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "PHCCHPH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "CJC*CC#C" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C12H10" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C10H10" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C10H9" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "PHCH2CH2CCH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "PHCH2CHCCH2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "PHCH2CCCH3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "PHCH2CHCCH2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "PHCH2CCH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "OC6H4CH2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C14H13OO" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C14H12OH" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5D1OOH3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H91O2-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H81OOH3-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H81OOH3-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5D1OOH4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H81OOH4-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H81OOH4-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H91O2-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5D1OOH5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H91O2-5" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H81OOH5-3" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H81OOH5-4" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H92O2-1" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H81OOH5-4O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H81OOH4-5O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H81OOH3-4O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H81OOH5-3O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H81OOH4-3O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "C5H81OOH3-5O2" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5D1KET53" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5D1KET43" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5D1KET35" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5D1KET54" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5D1KET45" while reading thermodynamics entry.
# INFO:root:Skipping unexpected species "NC5D1KET34" while reading thermodynamics entry.
# Wrote CTI mechanism file to '/Users/ebubeajulu/Code/GTL/ic8/chemkin/chem_annotated.cti'.
# Mechanism contains 874 species and 7522 reactions.
# Validating mechanism...
#
# **** WARNING ****
# For species EC6H13O2, discontinuity in s/R detected at Tmid = 1388
# 	Value computed using low-temperature polynomial:  107.806
# 	Value computed using high-temperature polynomial: 107.116
# PASSED.

# %%
gas = ct.Solution('/Users/ebubeajulu/Code/GTL/ic8/ic8_ver3_mech.cti')
# Out:
# **** WARNING ****
# For species EC6H13O2, discontinuity in s/R detected at Tmid = 1388
# 	Value computed using low-temperature polynomial:  107.806
# 	Value computed using high-temperature polynomial: 107.116

# %%
sorted(gas.species_names)
# Out:
# ['A-AC5H10O',
#  'A-AC6H12O',
#  'A-BC5H10O',
#  'A-BC6H12O',
#  'A-CC5H10O',
#  'A-CC6H12O',
#  'A-DC5H10O',
#  'A-DC6H12O',
#  'A-EC6H12O',
#  'AC3H4CH2CHO',
#  'AC3H4CH2COCH3',
#  'AC3H4COC2H5',
#  'AC3H4COCH3',
#  'AC3H5CHCHO',
#  'AC3H5CHCOCH3',
#  'AC3H5CHO',
#  'AC3H5CO',
#  'AC3H5OOH',
#  'AC5H10',
#  'AC5H10CHO',
#  'AC5H10OH',
#  'AC5H10OOH-A',
#  'AC5H10OOH-AO2',
#  'AC5H10OOH-B',
#  'AC5H10OOH-BO2',
#  'AC5H10OOH-C',
#  'AC5H10OOH-CO2',
#  'AC5H10OOH-D',
#  'AC5H10OOH-DO2',
#  'AC5H11',
#  'AC5H11O',
#  'AC5H11O2',
#  'AC5H11O2H',
#  'AC5H9-A1',
#  'AC5H9-A2',
#  'AC5H9-C',
#  'AC5H9-D',
#  'AC5H9O-A2',
#  'AC5H9O-C',
#  'AC6H11-A2',
#  'AC6H11-C',
#  'AC6H11-D',
#  'AC6H11-E',
#  'AC6H11O-C',
#  'AC6H12',
#  'AC6H12CHO-B',
#  'AC6H12CHO-D',
#  'AC6H12OH',
#  'AC6H12OOH-A',
#  'AC6H12OOH-AO2',
#  'AC6H12OOH-B',
#  'AC6H12OOH-BO2',
#  'AC6H12OOH-C',
#  'AC6H12OOH-CO2',
#  'AC6H12OOH-D',
#  'AC6H12OOH-DO2',
#  'AC6H12OOH-E',
#  'AC6H12OOH-EO2',
#  'AC6H13',
#  'AC6H13O',
#  'AC6H13O2',
#  'AC6H13O2H',
#  'AC8H16OOH-A',
#  'AC8H16OOH-AO2',
#  'AC8H16OOH-B',
#  'AC8H16OOH-BO2',
#  'AC8H16OOH-C',
#  'AC8H16OOH-CO2',
#  'AC8H16OOH-D',
#  'AC8H16OOH-DO2',
#  'AC8H17',
#  'AC8H17O',
#  'AC8H17O2',
#  'AC8H17O2H',
#  'ACC6H10',
#  'ACC6H9-A',
#  'ACC6H9-D',
#  'AO2C5H10OH',
#  'AO2C6H12OH',
#  'AR',
#  'B-CC5H10O',
#  'B-CC6H12O',
#  'B-DC5H10O',
#  'B-DC6H12O',
#  'B-EC6H12O',
#  'BC5H10',
#  'BC5H10CHO',
#  'BC5H10OH',
#  'BC5H10OOH-A',
#  'BC5H10OOH-AO2',
#  'BC5H10OOH-C',
#  'BC5H10OOH-CO2',
#  'BC5H10OOH-D',
#  'BC5H10OOH-DO2',
#  'BC5H11',
#  'BC5H11O',
#  'BC5H11O2',
#  'BC5H11O2H',
#  'BC6H11-E',
#  'BC6H12',
#  'BC6H12CHO-D',
#  'BC6H12OH',
#  'BC6H12OOH-A',
#  'BC6H12OOH-AO2',
#  'BC6H12OOH-C',
#  'BC6H12OOH-CO2',
#  'BC6H12OOH-D',
#  'BC6H12OOH-DO2',
#  'BC6H12OOH-E',
#  'BC6H12OOH-EO2',
#  'BC6H13',
#  'BC6H13O',
#  'BC6H13O2',
#  'BC6H13O2H',
#  'BC8H16O-CO2H',
#  'BC8H16OH-C',
#  'BC8H16OH-CO2',
#  'BC8H16OOH-A',
#  'BC8H16OOH-AO2',
#  'BC8H16OOH-C',
#  'BC8H16OOH-CO2',
#  'BC8H16OOH-D',
#  'BC8H16OOH-DO2',
#  'BC8H17',
#  'BC8H17O',
#  'BC8H17O2',
#  'BC8H17O2H',
#  'BO2C5H10OH',
#  'BO2C6H12OH',
#  'C',
#  'C-DC5H10O',
#  'C-DC6H12O',
#  'C-EC6H12O',
#  'C2H',
#  'C2H2',
#  'C2H3',
#  'C2H3CHCHO',
#  'C2H3CHO',
#  'C2H3CO',
#  'C2H3COCH3',
#  'C2H3O1-2',
#  'C2H3OOH',
#  'C2H4',
#  'C2H4O1-2',
#  'C2H4O2H',
#  'C2H5',
#  'C2H5CHCO',
#  'C2H5CHO',
#  'C2H5CO',
#  'C2H5COC2H3',
#  'C2H5COC2H4P',
#  'C2H5COC2H4S',
#  'C2H5COC2H5',
#  'C2H5COCH2',
#  'C2H5COCH3',
#  'C2H5O',
#  'C2H5O2',
#  'C2H5O2H',
#  'C2H5OH',
#  'C2H6',
#  'C3H2',
#  'C3H3',
#  'C3H4-A',
#  'C3H4-P',
#  'C3H5-A',
#  'C3H5-S',
#  'C3H5-T',
#  'C3H51-2,3OOH',
#  'C3H52-1,3OOH',
#  'C3H5O',
#  'C3H5OH',
#  'C3H6',
#  'C3H6CHO-1',
#  'C3H6CHO-2',
#  'C3H6CHO-3',
#  'C3H6COCH3-1',
#  'C3H6COCH3-2',
#  'C3H6COCH3-3',
#  'C3H6O1-2',
#  'C3H6O1-3',
#  'C3H6OH',
#  'C3H6OOH1-2',
#  'C3H6OOH1-2O2',
#  'C3H6OOH1-3',
#  'C3H6OOH1-3O2',
#  'C3H6OOH2-1',
#  'C3H6OOH2-1O2',
#  'C3H6OOH2-2',
#  'C3H8',
#  'C3KET12',
#  'C3KET13',
#  'C3KET21',
#  'C4H10',
#  'C4H5',
#  'C4H6',
#  'C4H6CHO1-23',
#  'C4H6CHO1-24',
#  'C4H6CHO1-43',
#  'C4H6CHO1-44',
#  'C4H6CHO2-11',
#  'C4H6CHO2-21',
#  'C4H6CHO2-24',
#  'C4H71-1',
#  'C4H71-2',
#  'C4H71-3',
#  'C4H71-4',
#  'C4H72-2',
#  'C4H7CHO1-2',
#  'C4H7CHO1-4',
#  'C4H7CHO2-1',
#  'C4H7CHO2-2',
#  'C4H7CO1-2',
#  'C4H7CO1-4',
#  'C4H7CO2-1',
#  'C4H7CO2-2',
#  'C4H7O',
#  'C4H8-1',
#  'C4H8-2',
#  'C4H8CHO-1',
#  'C4H8CHO-2',
#  'C4H8CHO-3',
#  'C4H8CHO-4',
#  'C4H8CHO1-2',
#  'C4H8CHO2-2',
#  'C4H8CHO3-2',
#  'C4H8CHO4-2',
#  'C4H8O1-2',
#  'C4H8O1-3',
#  'C4H8O1-4',
#  'C4H8O2-3',
#  'C4H8OH-1O2',
#  'C4H8OH-2O2',
#  'C4H8OOH1-1',
#  'C4H8OOH1-2',
#  'C4H8OOH1-2O2',
#  'C4H8OOH1-3',
#  'C4H8OOH1-3O2',
#  'C4H8OOH1-4',
#  'C4H8OOH1-4O2',
#  'C4H8OOH2-1',
#  'C4H8OOH2-1O2',
#  'C4H8OOH2-2',
#  'C4H8OOH2-3',
#  'C4H8OOH2-3O2',
#  'C4H8OOH2-4',
#  'C4H8OOH2-4O2',
#  'C5H10-1',
#  'C5H10-2',
#  'C5H10CHO1-2',
#  'C5H10CHO2-2',
#  'C5H10CHO3-2',
#  'C5H10CHO4-2',
#  'C5H10CHO5-2',
#  'C5H11-2',
#  'C5H81-3',
#  'C5H91-2',
#  'C5H91-3',
#  'C5H91-4',
#  'C5H91-5',
#  'C5H92-4',
#  'C5H92-5',
#  'C5H9O1-3',
#  'C5H9O2-4',
#  'C7H16-24',
#  'C7KET24XX1',
#  'C7KET24XX2',
#  'C7KET24XY1',
#  'C7KET24XY2',
#  'C7KET24XZ',
#  'C7KET24ZX',
#  'C7KET24ZY',
#  'CC4H8O',
#  'CC5H10',
#  'CC5H10CHO',
#  'CC5H10OH',
#  'CC5H10OOH-A',
#  'CC5H10OOH-AO2',
#  'CC5H10OOH-B',
#  'CC5H10OOH-BO2',
#  'CC5H10OOH-D',
#  'CC5H10OOH-DO2',
#  'CC5H11',
#  'CC5H11O',
#  'CC5H11O2',
#  'CC5H11O2H',
#  'CC5H9-A',
#  'CC5H9-B',
#  'CC5H9O-B',
#  'CC6H11-A',
#  'CC6H11-B',
#  'CC6H11-D',
#  'CC6H11O-B',
#  'CC6H12',
#  'CC6H12CHO-B',
#  'CC6H12CHO-D',
#  'CC6H12OH',
#  'CC6H12OOH-A',
#  'CC6H12OOH-AO2',
#  'CC6H12OOH-B',
#  'CC6H12OOH-BO2',
#  'CC6H12OOH-D',
#  'CC6H12OOH-DO2',
#  'CC6H12OOH-E',
#  'CC6H12OOH-EO2',
#  'CC6H13',
#  'CC6H13O',
#  'CC6H13O2',
#  'CC6H13O2H',
#  'CC8H16O-BO2H',
#  'CC8H16O-DO2H',
#  'CC8H16OH-B',
#  'CC8H16OH-BO2',
#  'CC8H16OH-D',
#  'CC8H16OH-DO2',
#  'CC8H16OOH-A',
#  'CC8H16OOH-AO2',
#  'CC8H16OOH-B',
#  'CC8H16OOH-BO2',
#  'CC8H16OOH-D',
#  'CC8H16OOH-DO2',
#  'CC8H17',
#  'CC8H17O',
#  'CC8H17O2',
#  'CC8H17O2H',
#  'CH',
#  'CH2',
#  'CH2(S)',
#  'CH2CCH2OH',
#  'CH2CCHCH3',
#  'CH2CCHO',
#  'CH2CH2CHO',
#  'CH2CH2COCH3',
#  'CH2CHO',
#  'CH2CHOOHCOCH3',
#  'CH2CO',
#  'CH2O',
#  'CH2O2H',
#  'CH2OCH2O2H',
#  'CH2OCHO',
#  'CH2OH',
#  'CH3',
#  'CH3CHCHO',
#  'CH3CHCO',
#  'CH3CHCOCH3',
#  'CH3CHO',
#  'CH3CHOCHO',
#  'CH3CHOOCOCH3',
#  'CH3CO',
#  'CH3CO2',
#  'CH3CO3',
#  'CH3CO3H',
#  'CH3COCH2',
#  'CH3COCH2O',
#  'CH3COCH2O2',
#  'CH3COCH2O2H',
#  'CH3COCH3',
#  'CH3O',
#  'CH3O2',
#  'CH3O2H',
#  'CH3OCH2',
#  'CH3OCH2O',
#  'CH3OCH2O2',
#  'CH3OCH2O2H',
#  'CH3OCH3',
#  'CH3OCHO',
#  'CH3OCO',
#  'CH3OH',
#  'CH4',
#  'CO',
#  'CO2',
#  'CO2C5H10OH',
#  'CO2C6H12OH',
#  'D-EC6H12O',
#  'DC5H10CHO',
#  'DC5H10OOH-A',
#  'DC5H10OOH-AO2',
#  'DC5H10OOH-B',
#  'DC5H10OOH-BO2',
#  'DC5H10OOH-C',
#  'DC5H10OOH-CO2',
#  'DC5H11',
#  'DC5H11O',
#  'DC5H11O2',
#  'DC5H11O2H',
#  'DC6H11-A',
#  'DC6H11-B',
#  'DC6H11-C',
#  'DC6H11-D',
#  'DC6H11O-C',
#  'DC6H12',
#  'DC6H12CHO-B',
#  'DC6H12CHO-D',
#  'DC6H12OH',
#  'DC6H12OOH-A',
#  'DC6H12OOH-AO2',
#  'DC6H12OOH-B',
#  'DC6H12OOH-BO2',
#  'DC6H12OOH-C',
#  'DC6H12OOH-CO2',
#  'DC6H12OOH-E',
#  'DC6H12OOH-EO2',
#  'DC6H13',
#  'DC6H13O',
#  'DC6H13O2',
#  'DC6H13O2H',
#  'DC8H16O-CO2H',
#  'DC8H16OH-C',
#  'DC8H16OH-CO2',
#  'DC8H16OOH-A',
#  'DC8H16OOH-AO2',
#  'DC8H16OOH-B',
#  'DC8H16OOH-BO2',
#  'DC8H16OOH-C',
#  'DC8H16OOH-CO2',
#  'DC8H16OOH-D',
#  'DC8H16OOH-DO2',
#  'DC8H17',
#  'DC8H17O',
#  'DC8H17O2',
#  'DC8H17O2H',
#  'DO2C6H12OH',
#  'EC6H12CHO-B',
#  'EC6H12CHO-D',
#  'EC6H12OOH-A',
#  'EC6H12OOH-AO2',
#  'EC6H12OOH-B',
#  'EC6H12OOH-BO2',
#  'EC6H12OOH-C',
#  'EC6H12OOH-CO2',
#  'EC6H12OOH-D',
#  'EC6H12OOH-DO2',
#  'EC6H13',
#  'EC6H13O',
#  'EC6H13O2',
#  'EC6H13O2H',
#  'F-FC6H12O',
#  'F-GC6H12O',
#  'F-HC6H12O',
#  'FC6H12CHO',
#  'FC6H12OOH-F',
#  'FC6H12OOH-FO2',
#  'FC6H12OOH-G',
#  'FC6H12OOH-GO2',
#  'FC6H12OOH-H',
#  'FC6H12OOH-HO2',
#  'FC6H13',
#  'FC6H13O',
#  'FC6H13O2',
#  'FC6H13O2H',
#  'G-HC6H12O',
#  'GC6H12CHO',
#  'GC6H12OOH-F',
#  'GC6H12OOH-FO2',
#  'GC6H12OOH-H',
#  'GC6H12OOH-HO2',
#  'GC6H13',
#  'GC6H13O',
#  'GC6H13O2',
#  'GC6H13O2H',
#  'H',
#  'H2',
#  'H2O',
#  'H2O2',
#  'HC6H12CHO',
#  'HC6H12OOH-F',
#  'HC6H12OOH-FO2',
#  'HC6H12OOH-G',
#  'HC6H12OOH-GO2',
#  'HC6H13',
#  'HC6H13O',
#  'HC6H13O2',
#  'HC6H13O2H',
#  'HCCO',
#  'HCCOH',
#  'HCO',
#  'HE',
#  'HO2',
#  'HO2CH2OCHO',
#  'HO2CHO',
#  'HOC3H6O2',
#  'HOCH2O',
#  'HOCH2O2',
#  'HOCH2O2H',
#  'HOCH2OCO',
#  'HOCHO',
#  'IC3H5CHCHO',
#  'IC3H5CHCOCH3',
#  'IC3H5CHO',
#  'IC3H5CO',
#  'IC3H5COC2H4P',
#  'IC3H5COC2H4S',
#  'IC3H5COC2H5',
#  'IC3H5COCH2',
#  'IC3H5COCH3',
#  'IC3H5O2HCHO',
#  'IC3H5OH',
#  'IC3H6CH2CHO',
#  'IC3H6CH2COCH3',
#  'IC3H6CHCHO',
#  'IC3H6CHCO',
#  'IC3H6CHCOCH2',
#  'IC3H6CHCOCH3',
#  'IC3H6CHO',
#  'IC3H6CO',
#  'IC3H6COC2H5',
#  'IC3H6COCH3',
#  'IC3H7',
#  'IC3H7CHCHO',
#  'IC3H7CHCOCH3',
#  'IC3H7CHO',
#  'IC3H7CO',
#  'IC3H7COC2H4P',
#  'IC3H7COC2H4S',
#  'IC3H7COC2H5',
#  'IC3H7COC3H6-I',
#  'IC3H7COC3H6-T',
#  'IC3H7COC3H7-I',
#  'IC3H7COCH2',
#  'IC3H7COCH3',
#  'IC3H7O',
#  'IC3H7O2',
#  'IC3H7O2H',
#  'IC4H10',
#  'IC4H6OH',
#  'IC4H6Q2-II',
#  'IC4H7',
#  'IC4H7-I1',
#  'IC4H7CHO',
#  'IC4H7CO',
#  'IC4H7COCH2',
#  'IC4H7COCH3',
#  'IC4H7O',
#  'IC4H7OH',
#  'IC4H7OOH',
#  'IC4H8',
#  'IC4H8O',
#  'IC4H8O2H-I',
#  'IC4H8O2H-T',
#  'IC4H8OH',
#  'IC4H8OOH-IO2',
#  'IC4H8OOH-TO2',
#  'IC4H9',
#  'IC4H9CHO',
#  'IC4H9CO',
#  'IC4H9COCH2',
#  'IC4H9COCH3',
#  'IC4H9O',
#  'IC4H9O2',
#  'IC4H9O2H',
#  'IC4KETII',
#  'IC4KETIT',
#  'IC5H10CHO-BA',
#  'IC5H10CHO-BC',
#  'IC5H10CHO-BD',
#  'IC5H11CHO',
#  'IC5H11CHO-B',
#  'IC5H11CO',
#  'IC5H11CO-B',
#  'IC5H12',
#  'IC5H7',
#  'IC5H7O',
#  'IC5H8',
#  'IC5KETAA',
#  'IC5KETAB',
#  'IC5KETAC',
#  'IC5KETAD',
#  'IC5KETCA',
#  'IC5KETCB',
#  'IC5KETCD',
#  'IC5KETDA',
#  'IC5KETDB',
#  'IC5KETDC',
#  'IC6H13CHO-B',
#  'IC6H13CHO-D',
#  'IC6H13CO-B',
#  'IC6H13CO-D',
#  'IC6H14',
#  'IC6KETAA',
#  'IC6KETAB',
#  'IC6KETAC',
#  'IC6KETAD',
#  'IC6KETAE',
#  'IC6KETCA',
#  'IC6KETCB',
#  'IC6KETCD',
#  'IC6KETCE',
#  'IC6KETDA',
#  'IC6KETDB',
#  'IC6KETDC',
#  'IC6KETDE',
#  'IC6KETEA',
#  'IC6KETEB',
#  'IC6KETEC',
#  'IC6KETED',
#  'IC8ETERAA',
#  'IC8ETERAB',
#  'IC8ETERAC',
#  'IC8ETERAD',
#  'IC8ETERBC',
#  'IC8ETERBD',
#  'IC8ETERCD',
#  'IC8ETERDD',
#  'IC8H14',
#  'IC8H15',
#  'IC8H16',
#  'IC8H18',
#  'IC8KETAA',
#  'IC8KETAB',
#  'IC8KETAC',
#  'IC8KETAD',
#  'IC8KETBA',
#  'IC8KETBC',
#  'IC8KETBD',
#  'IC8KETDA',
#  'IC8KETDB',
#  'IC8KETDC',
#  'IC8KETDD',
#  'IIC4H7Q2-I',
#  'IIC4H7Q2-T',
#  'IO2C4H8OH',
#  'JC8H16',
#  'N-NC7H14O',
#  'N-OC7H14O',
#  'N-PC7H14O',
#  'N-QC7H14O',
#  'N2',
#  'NC3H7',
#  'NC3H7CHO',
#  'NC3H7CO',
#  'NC3H7COCH2',
#  'NC3H7COCH3',
#  'NC3H7O',
#  'NC3H7O2',
#  'NC3H7O2H',
#  'NC4H9CHO',
#  'NC4H9CHO-2',
#  'NC4H9CO',
#  'NC4H9CO-2',
#  'NC4KET12',
#  'NC4KET13',
#  'NC4KET14',
#  'NC4KET21',
#  'NC4KET23',
#  'NC4KET24',
#  'NC5H11CHO-2',
#  'NC5H11CO-2',
#  'NC7H14OOH-N2',
#  'NC7H14OOH-N2O2',
#  'NC7H14OOH-O',
#  'NC7H14OOH-OO2',
#  'NC7H14OOH-P',
#  'NC7H14OOH-PO2',
#  'NC7H14OOH-Q',
#  'NC7H14OOH-QO2',
#  'NC7H15',
#  'NC7H15O',
#  'NC7H15O2',
#  'NC7H15O2H',
#  'NEO-C5H10O',
#  'NEOC5H10COCH3',
#  'NEOC5H10OOH',
#  'NEOC5H10OOH-O2',
#  'NEOC5H11',
#  'NEOC5H11CHO',
#  'NEOC5H11CO',
#  'NEOC5H11COCH2',
#  'NEOC5H11COCH3',
#  'NEOC5H11O',
#  'NEOC5H11O2',
#  'NEOC5H11O2H',
#  'NEOC5H12',
#  'NEOC5H9Q2',
#  'NEOC5H9Q2-N',
#  'NEOC5KEJOL',
#  'NEOC5KET',
#  'NEOC5KETOX',
#  'NEOC6H11',
#  'NEOC6H11-H',
#  'NEOC6H12',
#  'NEOC6H12OH',
#  'NEOC6H13CHO',
#  'NEOC6H13CO',
#  'NEOC6H14',
#  'NEOC6KETFF',
#  'NEOC6KETFG',
#  'NEOC6KETFH',
#  'NEOC6KETGF',
#  'NEOC6KETGH',
#  'NEOC6KETHF',
#  'NEOC6KETHG',
#  'NEOC7H16',
#  'NEOC7KETNN',
#  'NEOC7KETNO',
#  'NEOC7KETNP',
#  'NEOC7KETNQ',
#  'NEOC7KETON',
#  'NEOC7KETOP',
#  'NEOC7KETOQ',
#  'NEOC7KETPN',
#  'NEOC7KETPO',
#  'NEOC7KETPQ',
#  'NEOC7KETQN',
#  'NEOC7KETQO',
#  'NEOC7KETQP',
#  'NEOO2C6H12OH',
#  'O',
#  'O-PC7H14O',
#  'O-QC7H14O',
#  'O2',
#  'O2C2H4OH',
#  'O2C4H8CHO',
#  'O2CH2OCH2O2H',
#  'O2CHO',
#  'O2HC4H8CO',
#  'OC7H13-N',
#  'OC7H13O-N',
#  'OC7H13O-Q',
#  'OC7H13OOH-N',
#  'OC7H13OOH-Q',
#  'OC7H14',
#  'OC7H14OH',
#  'OC7H14OOH-N',
#  'OC7H14OOH-NO2',
#  'OC7H14OOH-P',
#  'OC7H14OOH-PO2',
#  'OC7H14OOH-Q',
#  'OC7H14OOH-QO2',
#  'OC7H15',
#  'OC7H15O',
#  'OC7H15O2',
#  'OC7H15O2H',
#  'OCH2O2H',
#  'OCH2OCHO',
#  'OCHO',
#  'OH',
#  'OO2C7H14OH',
#  'P-QC7H14O',
#  'PC2H4COC2H3',
#  'PC2H4OH',
#  'PC4H8OH',
#  'PC4H9',
#  'PC4H9O',
#  'PC4H9O2',
#  'PC4H9O2H',
#  'PC7H13-N',
#  'PC7H13-O',
#  'PC7H13O-O',
#  'PC7H13OOH-O',
#  'PC7H14',
#  'PC7H14OH',
#  'PC7H14OOH-N',
#  'PC7H14OOH-NO2',
#  'PC7H14OOH-O',
#  'PC7H14OOH-OO2',
#  'PC7H14OOH-Q',
#  'PC7H14OOH-QO2',
#  'PC7H15',
#  'PC7H15O',
#  'PC7H15O2',
#  'PC7H15O2H',
#  'PO2C7H14OH',
#  'QC7H14OOH-N',
#  'QC7H14OOH-NO2',
#  'QC7H14OOH-O',
#  'QC7H14OOH-OO2',
#  'QC7H14OOH-P',
#  'QC7H14OOH-PO2',
#  'QC7H15',
#  'QC7H15O',
#  'QC7H15O2',
#  'QC7H15O2H',
#  'SC2H4COC2H3',
#  'SC2H4OH',
#  'SC3H5CHO',
#  'SC3H5CO',
#  'SC4H8OH',
#  'SC4H9',
#  'SC4H9O',
#  'SC4H9O2',
#  'SC4H9O2H',
#  'TC3H6CH2CHO',
#  'TC3H6CH2COCH3',
#  'TC3H6CHO',
#  'TC3H6COC2H5',
#  'TC3H6COCH3',
#  'TC3H6O2CHO',
#  'TC3H6O2HCO',
#  'TC3H6OCHO',
#  'TC3H6OH',
#  'TC3H6OHCHO',
#  'TC4H8CH2CHO',
#  'TC4H8CHO',
#  'TC4H8COC2H5',
#  'TC4H8COCH3',
#  'TC4H8O2H-I',
#  'TC4H8OOH-IO2',
#  'TC4H9',
#  'TC4H9CHCHO',
#  'TC4H9CHCOCH3',
#  'TC4H9CHO',
#  'TC4H9CO',
#  'TC4H9COC2H4P',
#  'TC4H9COC2H4S',
#  'TC4H9COC2H5',
#  'TC4H9COCH2',
#  'TC4H9COCH3',
#  'TC4H9O',
#  'TC4H9O2',
#  'TC4H9O2H',
#  'TIC4H7Q2-I',
#  'X-X1C7H14O',
#  'X-X2C7H14O',
#  'X-Y1C7H14O',
#  'X-Y2C7H14O',
#  'X-ZC7H14O',
#  'XC7H13-X1',
#  'XC7H13-X2',
#  'XC7H13-Y2',
#  'XC7H13-Z',
#  'XC7H13O-X1',
#  'XC7H13O-Y2',
#  'XC7H13O-Z',
#  'XC7H13OOH-X1',
#  'XC7H13OOH-Y2',
#  'XC7H13OOH-Z',
#  'XC7H14',
#  'XC7H14OH',
#  'XC7H14OOH-X1',
#  'XC7H14OOH-X1O2',
#  'XC7H14OOH-X2',
#  'XC7H14OOH-X2O2',
#  'XC7H14OOH-Y1',
#  'XC7H14OOH-Y1O2',
#  'XC7H14OOH-Y2',
#  'XC7H14OOH-Y2O2',
#  'XC7H14OOH-Z',
#  'XC7H14OOH-ZO2',
#  'XC7H15',
#  'XC7H15O',
#  'XC7H15O2',
#  'XC7H15O2H',
#  'XO2C7H14OH',
#  'Y-YC7H14O',
#  'Y-ZC7H14O',
#  'YC7H13-X2',
#  'YC7H13-Y2',
#  'YC7H13O-X1',
#  'YC7H13O-X2',
#  'YC7H13O-Y2',
#  'YC7H13OOH-X1',
#  'YC7H13OOH-X2',
#  'YC7H14',
#  'YC7H14OH',
#  'YC7H14OOH-X1',
#  'YC7H14OOH-X1O2',
#  'YC7H14OOH-X2',
#  'YC7H14OOH-X2O2',
#  'YC7H14OOH-Y2',
#  'YC7H14OOH-Y2O2',
#  'YC7H14OOH-Z',
#  'YC7H14OOH-ZO2',
#  'YC7H15',
#  'YC7H15O',
#  'YC7H15O2',
#  'YC7H15O2H',
#  'YO2C7H14OH',
#  'ZC7H14OOH-X',
#  'ZC7H14OOH-XO2',
#  'ZC7H14OOH-Y',
#  'ZC7H14OOH-YO2',
#  'ZC7H15',
#  'ZC7H15O',
#  'ZC7H15O2',
#  'ZC7H15O2H']

# %%
gas.TP = 900,10e6
gas.set_equivalence_ratio(phi=1.0, fuel='IC8H18', oxidizer='O2:0.2, N2:0.8' )
gas()
# Out:
#   gas:
#
#        temperature             900  K
#           pressure           1e+07  Pa
#            density         40.2989  kg/m^3
#   mean mol. weight         30.1557  amu
#
#                           1 kg            1 kmol
#                        -----------      ------------
#           enthalpy      5.8605e+05        1.767e+07     J
#    internal energy       3.379e+05        1.019e+07     J
#            entropy            6719        2.026e+05     J/K
#     Gibbs function      -5.461e+06       -1.647e+08     J
#  heat capacity c_p          1282.7        3.868e+04     J/K
#  heat capacity c_v            1007        3.037e+04     J/K
#
#                            X                 Y          Chem. Pot. / RT
#                      -------------     ------------     ------------
#                 O2        0.19685         0.208881         -23.3084
#                 N2       0.787402         0.731465         -20.2331
#             IC8H18       0.015748         0.059654         -94.4585
#      [ +871 minor]              0                0

# %%
def set_gas_concentrations(gas, phi):
    """
    Set the concentrations in the gas according to the description
    in the paper by 
    """
    # Set it to desired stoichiometry with synthetic air (20% O2 : 80% N2)
    gas.set_equivalence_ratio(phi=1.0, fuel='IC8H18', oxidizer='O2:0.2, N2:0.8' )
    # Then dilute the whole thing 1:2 with extra N2
    gas.X = gas.X / 3.0 
    gas.X[gas.species_index('N2')] += 2./3.

set_gas_concentrations(gas, 1.0)
gas()
# Out:
#   gas:
#
#        temperature             900  K
#           pressure           1e+07  Pa
#            density         40.2989  kg/m^3
#   mean mol. weight         30.1557  amu
#
#                           1 kg            1 kmol
#                        -----------      ------------
#           enthalpy      5.8605e+05        1.767e+07     J
#    internal energy       3.379e+05        1.019e+07     J
#            entropy            6719        2.026e+05     J/K
#     Gibbs function      -5.461e+06       -1.647e+08     J
#  heat capacity c_p          1282.7        3.868e+04     J/K
#  heat capacity c_v            1007        3.037e+04     J/K
#
#                            X                 Y          Chem. Pot. / RT
#                      -------------     ------------     ------------
#                 O2        0.19685         0.208881         -23.3084
#                 N2       0.787402         0.731465         -20.2331
#             IC8H18       0.015748         0.059654         -94.4585
#      [ +871 minor]              0                0

# %%
gas.species_index('N2')
# Out:
# 6

# %%
def get_ignition_delay(gas, temperature, pressure_bar, mole_fractions, plot=False):
    """
    A general function to find the igniton delay.
    Using C2H + O --> CH* as the indication of ignition
    
    gas is a cantera Solution object
    temperature in K
    pressure_bar is in bar
    mole_fractions is a dict
    """
    gas.TPX = temperature, pressure_bar*1e5, mole_fractions

    reactor = ct.IdealGasReactor(gas)
    reactor_network = ct.ReactorNet([reactor])
    
    time = 0.0
    end_time = 10e-3
    
    times = []
    concentrations = []
    pressures = []
    temperatures = []
    
    print_data = True
    while time < end_time:
        time = reactor_network.time
        times.append(time)
        temperatures.append(reactor.T)
        pressures.append(reactor.thermo.P)
        concentrations.append(reactor.thermo.concentrations)
        # take a timestep
        # the size of the step will be determined by the ODE solver
        # depending on how quickly things are changing.
        reactor_network.step()
    
    print("Reached end time {0:.2f} ms in {1} steps".format(times[-1]*1e3, len(times)))
    # convert the lists into arrays
    concentrations = np.array(concentrations)
    times = np.array(times)
    pressures = np.array(pressures)
    temperatures = np.array(temperatures)

    if plot:
        plt.subplot(2,1,1)
        plt.plot(times*1e3, pressures/1e5)
        plt.ylabel("Pressure (bar)", color='b')
        ax2 = plt.gca().twinx()
        ax2.set_ylabel('Temperature (K)', color='r')
        ax2.plot(times*1e3, temperatures, 'r')
    # Using C2H + O --> CH* as the indication of ignition
    i_c2h = gas.species_index('C2H')   
    i_o = gas.species_index('O')
    excited_ch_generation = concentrations[:,i_o] * concentrations[:,i_c2h]
    if plot:
        plt.subplot(2,1,2)
        plt.plot(times*1e3, excited_ch_generation, 'g')
        plt.ylabel("CH* emission")
        plt.ylim(0,max(1e-13,1.1*max(excited_ch_generation)))
        plt.xlabel("Time (ms)")
        plt.tight_layout()
        plt.show()
    step_with_highest_ch_gen = excited_ch_generation.argmax()
    if step_with_highest_ch_gen > 1 and excited_ch_generation.max()>1e-20:
        ignition_time_ms = 1e3 * times[step_with_highest_ch_gen]
        print("At {0} K {1} bar, ignition delay time is {2} ms".format(temperature, pressure_bar, ignition_time_ms))
        return ignition_time_ms
    else:
        print("At {0} K {1} bar, no ignition detected".format(temperature, pressure_bar))
        return np.infty

# %%
def get_ignition_delay_air(temperature, pressure_bar=10, phi=1.0, plot=False):
    """
    For figure 14
    
    temperature in K
    pressure in bar
    phi is equivalence ratio
    burns DME in air
    """
    gas.set_equivalence_ratio(phi=phi, fuel='IC8H18', oxidizer='O2:0.2, N2:0.8')
    mole_fractions = gas.X

    time = get_ignition_delay(gas, temperature, pressure_bar, mole_fractions, plot=plot)
    return time

# %%
get_ignition_delay_air(1000, 16, 1, plot=True)
plt.rcParams['figure.figsize'] = [10, 8]
# Out:
# Reached end time 10.13 ms in 3414 steps
# At 1000 K 16 bar, ignition delay time is 0.655117382312 ms

# %% [markdown]
# # Figure 14 ignition delay times from LLNL for iso-octane in N2 as bath gas comparing to the Dagaut et al 2014

# %%
temperatures = 1000/np.linspace(0.75,1.55,25)
pressures_bar = 16
phi = 1

results = dict()
times = []
for T in temperatures:
    t = get_ignition_delay_air(T,pressures_bar, phi, plot=False)
    times.append(t)
    results[pressures_bar]=times
# Out:
# Reached end time 14.08 ms in 2812 steps
# At 1333.33333333 K 16 bar, ignition delay time is 0.0190545109556 ms
# Reached end time 14.78 ms in 2884 steps
# At 1276.59574468 K 16 bar, ignition delay time is 0.0396496201444 ms
# Reached end time 13.32 ms in 2945 steps
# At 1224.48979592 K 16 bar, ignition delay time is 0.0803423229808 ms
# Reached end time 11.07 ms in 3180 steps
# At 1176.47058824 K 16 bar, ignition delay time is 0.152715178632 ms
# Reached end time 15.56 ms in 3161 steps
# At 1132.0754717 K 16 bar, ignition delay time is 0.26002044005 ms
# Reached end time 12.12 ms in 3175 steps
# At 1090.90909091 K 16 bar, ignition delay time is 0.382523344779 ms
# Reached end time 11.44 ms in 3497 steps
# At 1052.63157895 K 16 bar, ignition delay time is 0.494404284917 ms
# Reached end time 12.56 ms in 3317 steps
# At 1016.94915254 K 16 bar, ignition delay time is 0.59928973601 ms
# Reached end time 10.30 ms in 3381 steps
# At 983.606557377 K 16 bar, ignition delay time is 0.715320675224 ms
# Reached end time 11.03 ms in 3661 steps
# At 952.380952381 K 16 bar, ignition delay time is 0.847690408863 ms
# Reached end time 11.60 ms in 3416 steps
# At 923.076923077 K 16 bar, ignition delay time is 0.97660487992 ms
# Reached end time 10.95 ms in 3547 steps
# At 895.52238806 K 16 bar, ignition delay time is 1.04391751162 ms
# Reached end time 10.33 ms in 3811 steps
# At 869.565217391 K 16 bar, ignition delay time is 0.979571226254 ms
# Reached end time 17.83 ms in 3811 steps
# At 845.070422535 K 16 bar, ignition delay time is 0.866446360946 ms
# Reached end time 10.33 ms in 3885 steps
# At 821.917808219 K 16 bar, ignition delay time is 0.809688086902 ms
# Reached end time 10.30 ms in 4233 steps
# At 800.0 K 16 bar, ignition delay time is 0.818384898894 ms
# Reached end time 10.65 ms in 4182 steps
# At 779.220779221 K 16 bar, ignition delay time is 0.904820301029 ms
# Reached end time 11.49 ms in 4336 steps
# At 759.493670886 K 16 bar, ignition delay time is 1.09613737322 ms
# Reached end time 11.41 ms in 4253 steps
# At 740.740740741 K 16 bar, ignition delay time is 1.44053076869 ms
# Reached end time 13.76 ms in 4409 steps
# At 722.891566265 K 16 bar, ignition delay time is 2.02091441169 ms
# Reached end time 10.24 ms in 4399 steps
# At 705.882352941 K 16 bar, ignition delay time is 2.97863829564 ms
# Reached end time 11.09 ms in 4639 steps
# At 689.655172414 K 16 bar, ignition delay time is 4.55511734589 ms
# Reached end time 11.94 ms in 4886 steps
# At 674.157303371 K 16 bar, ignition delay time is 7.16688696086 ms
# Reached end time 10.02 ms in 205 steps
# At 659.340659341 K 16 bar, no ignition detected
# Reached end time 10.04 ms in 121 steps
# At 645.161290323 K 16 bar, no ignition detected

# %%
plt.semilogy(1000/temperatures,times,label='{}bar'.format(pressures_bar))
plt.legend(loc='best')
plt.xlabel('1000 K / $T$')
plt.ylabel('$\\tau_{ign} = t([CH^*]_{max})/ms$')
plt.rcParams['figure.figsize'] = [10, 8]

# %%
import pickle
with open('fig14-RMG.pkl','w') as fp:
    pickle.dump((temperatures, results), fp)

# %%
yvalues = [0.06886,
0.0736576,
0.0980208,
0.114044,
0.124062,
0.156951,
0.173651,
0.198648,
0.231141,
0.264390,
0.312826,
0.363912,
0.409464,
0.509394,
0.582827,
0.655603,
0.725330,
0.858172,
0.998451,
1.24212,
1.32894,
1.52038,
1.68201,
1.92431,
2.20192,
2.83392,
3.13533,
3.58715,
4.24412,
5.10800,
5.94379,
6.25259,
7.27499,
8.90312,
10.3613,
11.2741,
12.2662,
15.0134,
16.8935,
18.3809,
19.9966,
22.1233,
24.8937,
27.5413,
29.9649,
33.1548,
34.3018,
37.9586,
38.6149,
38.6307,
38.0157,
36.1695,
34.4098,
32.7417,
31.1460,
31.1659,
30.6627,
29.6658,
29.6767,
29.6983,
32.3264,
33.4463,
37.6381,
40.2689,
44.5537,
45.3261,
51.8626]


xvalues = [0.005842,
0.018862,
0.044848,
0.064360,
0.079548,
0.092509,
0.114212,
0.127208,
0.151068,
0.159716,
0.181396,
0.194387,
0.218258,
0.231225,
0.252916,
0.263745,
0.283274,
0.302780,
0.322292,
0.335259,
0.356974,
0.374318,
0.391674,
0.409018,
0.435057,
0.467577,
0.487107,
0.506624,
0.526130,
0.560848,
0.586881,
0.602081,
0.623767,
0.654130,
0.686686,
0.712743,
0.734452,
0.771338,
0.797383,
0.821266,
0.838628,
0.858158,
0.884203,
0.903733,
0.925442,
0.949320,
0.971047,
1.00145, 
1.01883, 
1.03840, 
1.07318, 
1.09929, 
1.12105, 
1.15150, 
1.16891, 
1.19934, 
1.22326, 
1.24718, 
1.26458, 
1.29936, 
1.34281, 
1.36671, 
1.39710, 
1.41882, 
1.44052, 
1.46008, 
1.48394]

# %%
plt.semilogy(xvalues, yvalues, 'r^',label='Pressure profile')

# %%
plt.semilogy(xvalues, yvalues, 'r^',label='Pressure profile')


    
plt.semilogy(1000/temperatures,times,label='{}bar'.format(pressures_bar))
plt.legend(loc='best')
plt.xlabel('1000 K / $T$')
plt.ylabel('$\\tau_{ign} = t([CH^*]_{max})/ms$')
plt.show
# Out:
# <function matplotlib.pyplot.show>
