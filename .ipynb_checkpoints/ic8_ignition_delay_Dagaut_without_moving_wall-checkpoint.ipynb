# %% [markdown]
# # Trying to model ignition delay from RMG for Iso-octane

# %%
import cantera as ct
import numpy as np
# %matplotlib inline

from matplotlib import pyplot as plt

# %%
from cantera import ck2cti
ck2cti.main([
    '--input=/Users/ebubeajulu/Code/GTL/ic8/chemkin/chem_annotated.inp',
    '--output=/Users/ebubeajulu/Code/GTL/ic8/chemkin/chem_annotated.cti',
    '--permissive'
        ])

# %%
gas = ct.Solution('/Users/ebubeajulu/Code/GTL/ic8/chemkin/chem_annotated.cti')

# %%
sorted(gas.species_names)

# %%
gas.TP = 900, 10e6
gas.set_equivalence_ratio(phi=1.0, fuel='iC8H18(1)', oxidizer='O2(2):0.2, N2:0.8' )
gas()

# %%
def set_gas_concentrations(gas, phi):
    """
    Set the concentrations in the gas according to the description
    in the paper by 
    """
    # Set it to desired stoichiometry with synthetic air (20% O2 : 80% N2)
    gas.set_equivalence_ratio(phi=1.0, fuel='iC8H18(1)', oxidizer='O2(2):0.2, N2:0.8' )
    # Then dilute the whole thing 1:2 with extra N2
    gas.X = gas.X / 3.0 
    gas.X[gas.species_index('N2')] += 2./3.

set_gas_concentrations(gas, 1.0)
gas()

# %%
def get_ignition_delay(gas, temperature, pressure_bar, mole_fractions, plot=False):
    """
    A general function to find the igniton delay.
    Using C2H + O --> CH* as the indication of ignition
    
    gas is a cantera Solution object
    temperature in K
    pressure_bar is in bar
    mole_fractions is a dict
    """
    gas.TPX = temperature, pressure_bar*1e5, mole_fractions

    reactor = ct.IdealGasReactor(gas)
    reactor_network = ct.ReactorNet([reactor])
    
    time = 0.0
    end_time = 10e-3
    
    times = []
    concentrations = []
    pressures = []
    temperatures = []
    
    print_data = True
    while time < end_time:
        time = reactor_network.time
        times.append(time)
        temperatures.append(reactor.T)
        pressures.append(reactor.thermo.P)
        concentrations.append(reactor.thermo.concentrations)
        # take a timestep
        # the size of the step will be determined by the ODE solver
        # depending on how quickly things are changing.
        reactor_network.step()
    
    print("Reached end time {0:.2f} ms in {1} steps".format(times[-1]*1e3, len(times)))
    # convert the lists into arrays
    concentrations = np.array(concentrations)
    times = np.array(times)
    pressures = np.array(pressures)
    temperatures = np.array(temperatures)

    if plot:
        plt.subplot(2,1,1)
        plt.plot(times*1e3, pressures/1e5)
        plt.ylabel("Pressure (bar)", color='b')
        ax2 = plt.gca().twinx()
        ax2.set_ylabel('Temperature (K)', color='r')
        ax2.plot(times*1e3, temperatures, 'r')
    # Using C2H + O --> CH* as the indication of ignition
    i_c2h = gas.species_index('C2H(4)')   
    i_o = gas.species_index('O(5)')
    excited_ch_generation = concentrations[:,i_o] * concentrations[:,i_c2h]
    if plot:
        plt.subplot(2,1,2)
        plt.plot(times*1e3, excited_ch_generation, 'g')
        plt.ylabel("CH* emission")
        plt.ylim(0,max(1e-13,1.1*max(excited_ch_generation)))
        plt.xlabel("Time (ms)")
        plt.tight_layout()
        plt.show()
    step_with_highest_ch_gen = excited_ch_generation.argmax()
    if step_with_highest_ch_gen > 1 and excited_ch_generation.max()>1e-20:
        ignition_time_ms = 1e3 * times[step_with_highest_ch_gen]
        print("At {0} K {1} bar, ignition delay time is {2} ms".format(temperature, pressure_bar, ignition_time_ms))
        return ignition_time_ms
    else:
        print("At {0} K {1} bar, no ignition detected".format(temperature, pressure_bar))
        return np.infty

# %%
def get_ignition_delay_air(temperature, pressure_bar=10, phi=1.0, plot=False):
    """
    For figure 14
    
    temperature in K
    pressure in bar
    phi is equivalence ratio
    burns DME in air
    """
    set_gas_concentrations(gas,phi)
    mole_fractions = gas.X

    time = get_ignition_delay(gas, temperature, pressure_bar, mole_fractions, plot=plot)
    return time

# %%
get_ignition_delay_air(1000, 16, 1, plot=True)
plt.rcParams['figure.figsize'] = [10, 10]

# %% [markdown]
# # Figure 14 ignition delay times from LLNL for iso-octane in N2 as bath gas comparing to the Dagaut et al 2014

# %%
RMG_temperatures = 1000/np.linspace(0.75,1.55,25)
pressures_bar = 16
phi = 1

RMG_results = dict()
times = []
for T in RMG_temperatures:
    t = get_ignition_delay_air(T,pressures_bar, phi, plot=False)
    times.append(t)
    RMG_results[pressures_bar]=times

# %%
plt.semilogy(1000/RMG_temperatures,times,label='{}bar'.format(pressures_bar))
plt.legend(loc='best')
plt.xlabel('1000 K / $T$')
plt.ylabel('$\\tau_{ign} = t([CH^*]_{max})/ms$')
plt.rcParams['figure.figsize'] = [10, 8]

# %% [markdown]
# # Importing the GTL mechanism from Dagaut for Iso-octane and comparing to LLNL and RMG model

# %%
gas = ct.Solution('/Users/ebubeajulu/Code/GTL/ic8/Dagaut_DKM.cti')
# Out:
# **** WARNING ****
# For species phc2h5, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  37.6503
# 	Value computed using high-temperature polynomial: 37.5953
#
#
# **** WARNING ****
# For species c3h6o, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  20.1255
# 	Value computed using high-temperature polynomial: 20.1621
#
#
# **** WARNING ****
# For species c3h5e1q2, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  22.8128
# 	Value computed using high-temperature polynomial: 22.8359
#
#
# **** WARNING ****
# For species ho2c2h4hco, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  24.3847
# 	Value computed using high-temperature polynomial: 24.4168
#
#
# **** WARNING ****
# For species c3h3hco, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  21.03
# 	Value computed using high-temperature polynomial: 21.1259
#
#
# **** WARNING ****
# For species c3h3co, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  19.115
# 	Value computed using high-temperature polynomial: 19.1449
#
#
# **** WARNING ****
# For species meall, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  20.128
# 	Value computed using high-temperature polynomial: 20.1809
#
#
# **** WARNING ****
# For species ch3coc2h4o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  30.5099
# 	Value computed using high-temperature polynomial: 30.5417
#
#
# **** WARNING ****
# For species c2h5coch2o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  30.4473
# 	Value computed using high-temperature polynomial: 30.5008
#
#
# **** WARNING ****
# For species c2h5coch2o, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  26.3096
# 	Value computed using high-temperature polynomial: 26.3362
#
#
# **** WARNING ****
# For species Lc6h6, discontinuity in cp/R detected at Tmid = 1399
# 	Value computed using low-temperature polynomial:  28.4439
# 	Value computed using high-temperature polynomial: 28.5381
#
#
# **** WARNING ****
# For species Lc6h6, discontinuity in h/RT detected at Tmid = 1399
# 	Value computed using low-temperature polynomial:  48.1571
# 	Value computed using high-temperature polynomial: 48.2049
#
#
# **** WARNING ****
# For species Lc6h4, discontinuity in cp/R detected at Tmid = 1399
# 	Value computed using low-temperature polynomial:  24.3161
# 	Value computed using high-temperature polynomial: 24.4095
#
#
# **** WARNING ****
# For species Lc6h4, discontinuity in h/RT detected at Tmid = 1399
# 	Value computed using low-temperature polynomial:  61.4309
# 	Value computed using high-temperature polynomial: 61.4712
#
#
# **** WARNING ****
# For species phc2h2co, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  39.1844
# 	Value computed using high-temperature polynomial: 39.3368
#
#
# **** WARNING ****
# For species phcoc2h3, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  38.0595
# 	Value computed using high-temperature polynomial: 37.882
#
#
# **** WARNING ****
# For species pbzohAqjB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.1357
# 	Value computed using high-temperature polynomial: 50.2973
#
#
# **** WARNING ****
# For species pbzohAqjB, discontinuity in h/RT detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  16.0876
# 	Value computed using high-temperature polynomial: 15.9218
#
#
# **** WARNING ****
# For species pbzohBqjA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.1357
# 	Value computed using high-temperature polynomial: 50.2973
#
#
# **** WARNING ****
# For species pbzohBqjA, discontinuity in h/RT detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  16.0876
# 	Value computed using high-temperature polynomial: 15.9218
#
#
# **** WARNING ****
# For species Aophc3h4-2, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  40.9186
# 	Value computed using high-temperature polynomial: 41.0194
#
#
# **** WARNING ****
# For species c14h14, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  60.4292
# 	Value computed using high-temperature polynomial: 60.3536
#
#
# **** WARNING ****
# For species MeEc8oCoIrA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  53.6254
# 	Value computed using high-temperature polynomial: 53.7161
#
#
# **** WARNING ****
# For species c9oAoGqjF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  59.0668
# 	Value computed using high-temperature polynomial: 59.174
#
#
# **** WARNING ****
# For species Hc9oAoGqF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  59.1353
# 	Value computed using high-temperature polynomial: 59.2322
#
#
# **** WARNING ****
# For species c9oAoGqFqjH, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  64.2474
# 	Value computed using high-temperature polynomial: 64.3708
#
#
# **** WARNING ****
# For species c9oAoGoFqH, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  59.4563
# 	Value computed using high-temperature polynomial: 59.6755
#
#
# **** WARNING ****
# For species c5oAoEqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  35.6942
# 	Value computed using high-temperature polynomial: 35.8052
#
#
# **** WARNING ****
# For species c5oAoEqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  35.9642
# 	Value computed using high-temperature polynomial: 36.0522
#
#
# **** WARNING ****
# For species Ac7oBoG, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  41.8077
# 	Value computed using high-temperature polynomial: 41.8497
#
#
# **** WARNING ****
# For species c7oBoGqjA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  46.1297
# 	Value computed using high-temperature polynomial: 46.194
#
#
# **** WARNING ****
# For species Cc7oBoGqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  46.143
# 	Value computed using high-temperature polynomial: 46.1973
#
#
# **** WARNING ****
# For species c7oBoGqAqjC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  51.3195
# 	Value computed using high-temperature polynomial: 51.3871
#
#
# **** WARNING ****
# For species c7oBoGqAqjD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  51.0531
# 	Value computed using high-temperature polynomial: 51.1331
#
#
# **** WARNING ****
# For species EtDc7oEoIqjA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  58.542
# 	Value computed using high-temperature polynomial: 58.6477
#
#
# **** WARNING ****
# For species CEtDc7oEoIqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  58.005
# 	Value computed using high-temperature polynomial: 58.0873
#
#
# **** WARNING ****
# For species DEtDc7oEoIqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  58.2645
# 	Value computed using high-temperature polynomial: 58.3491
#
#
# **** WARNING ****
# For species EtDc7oEoIqAqjC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  63.4582
# 	Value computed using high-temperature polynomial: 63.593
#
#
# **** WARNING ****
# For species EtDc7oAoEoIqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  59.026
# 	Value computed using high-temperature polynomial: 59.273
#
#
# **** WARNING ****
# For species Cc6oAoD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  35.2616
# 	Value computed using high-temperature polynomial: 35.3557
#
#
# **** WARNING ****
# For species c6oAoCoF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  35.5848
# 	Value computed using high-temperature polynomial: 35.6472
#
#
# **** WARNING ****
# For species c6oyAoCoF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  33.4308
# 	Value computed using high-temperature polynomial: 33.4776
#
#
# **** WARNING ****
# For species c6oAoCoyF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  33.4308
# 	Value computed using high-temperature polynomial: 33.4776
#
#
# **** WARNING ****
# For species Ec5oAoD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  29.3908
# 	Value computed using high-temperature polynomial: 29.4252
#
#
# **** WARNING ****
# For species Ec5oAoC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  28.9397
# 	Value computed using high-temperature polynomial: 29.0181
#
#
# **** WARNING ****
# For species c9oAoCqjF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  58.9425
# 	Value computed using high-temperature polynomial: 59.0637
#
#
# **** WARNING ****
# For species Dc9oAoCqF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  58.9563
# 	Value computed using high-temperature polynomial: 59.064
#
#
# **** WARNING ****
# For species c9oAoCqFqjD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  64.129
# 	Value computed using high-temperature polynomial: 64.2588
#
#
# **** WARNING ****
# For species c9oAoCoFqD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  59.2931
# 	Value computed using high-temperature polynomial: 59.6184
#
#
# **** WARNING ****
# For species c6oAoC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  36.981
# 	Value computed using high-temperature polynomial: 37.1365
#
#
# **** WARNING ****
# For species c6oyAoC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  34.8346
# 	Value computed using high-temperature polynomial: 34.9134
#
#
# **** WARNING ****
# For species MeEc8oAoCqjI, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  58.7615
# 	Value computed using high-temperature polynomial: 58.8289
#
#
# **** WARNING ****
# For species MeEc8oAoCqIqjD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  63.9447
# 	Value computed using high-temperature polynomial: 64.0261
#
#
# **** WARNING ****
# For species MeEc8oAoCqIqjG, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  63.6737
# 	Value computed using high-temperature polynomial: 63.7713
#
#
# **** WARNING ****
# For species MeEc8oAoCoIqD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  59.4302
# 	Value computed using high-temperature polynomial: 59.6462
#
#
# **** WARNING ****
# For species MeEc8oAoCoIqG, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  59.163
# 	Value computed using high-temperature polynomial: 59.4118
#
#
# **** WARNING ****
# For species c9oDoFqjA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  58.5423
# 	Value computed using high-temperature polynomial: 58.7048
#
#
# **** WARNING ****
# For species Cc9oDoFqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  58.5617
# 	Value computed using high-temperature polynomial: 58.7058
#
#
# **** WARNING ****
# For species c9oDoFqAqjC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  63.7272
# 	Value computed using high-temperature polynomial: 63.9004
#
#
# **** WARNING ****
# For species c9oAoDoFqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  59.2931
# 	Value computed using high-temperature polynomial: 59.6184
#
#
# **** WARNING ****
# For species EtDc7oAoIqD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  60.6688
# 	Value computed using high-temperature polynomial: 60.792
#
#
# **** WARNING ****
# For species c7oAoD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  43.0455
# 	Value computed using high-temperature polynomial: 43.2045
#
#
# **** WARNING ****
# For species c7oyAoD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  40.9011
# 	Value computed using high-temperature polynomial: 40.9868
#
#
# **** WARNING ****
# For species EtDc7oAoIqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  60.602
# 	Value computed using high-temperature polynomial: 60.6764
#
#
# **** WARNING ****
# For species MeEc8oAoIqD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  60.5284
# 	Value computed using high-temperature polynomial: 60.6342
#
#
# **** WARNING ****
# For species MeEc8oAoIqF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  60.5284
# 	Value computed using high-temperature polynomial: 60.6342
#
#
# **** WARNING ****
# For species MeCc6oAoG, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  43.1875
# 	Value computed using high-temperature polynomial: 43.2697
#
#
# **** WARNING ****
# For species MeCc6oyAoG, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  41.0404
# 	Value computed using high-temperature polynomial: 41.0816
#
#
# **** WARNING ****
# For species MeCc6oAoyG, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  41.0404
# 	Value computed using high-temperature polynomial: 41.0816
#
#
# **** WARNING ****
# For species MeEc8oAoIqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  60.5273
# 	Value computed using high-temperature polynomial: 60.639
#
#
# **** WARNING ****
# For species c9oAqFqjC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  65.2219
# 	Value computed using high-temperature polynomial: 65.2919
#
#
# **** WARNING ****
# For species c9oAqFqjD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  65.2222
# 	Value computed using high-temperature polynomial: 65.2919
#
#
# **** WARNING ****
# For species c9oAqFqjH, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  65.221
# 	Value computed using high-temperature polynomial: 65.2919
#
#
# **** WARNING ****
# For species c9oAoFqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  60.3873
# 	Value computed using high-temperature polynomial: 60.5628
#
#
# **** WARNING ****
# For species c9oAoFqD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  60.3901
# 	Value computed using high-temperature polynomial: 60.5609
#
#
# **** WARNING ****
# For species c9oAoFqH, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  60.3901
# 	Value computed using high-temperature polynomial: 60.5609
#
#
# **** WARNING ****
# For species pchoEqjB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  57.7084
# 	Value computed using high-temperature polynomial: 57.8379
#
#
# **** WARNING ****
# For species DpchoEqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  57.1793
# 	Value computed using high-temperature polynomial: 57.2892
#
#
# **** WARNING ****
# For species Bc5oAoC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  29.195
# 	Value computed using high-temperature polynomial: 29.2819
#
#
# **** WARNING ****
# For species Ac7oD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.5717
# 	Value computed using high-temperature polynomial: 42.6222
#
#
# **** WARNING ****
# For species BchxoAoD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  33.5319
# 	Value computed using high-temperature polynomial: 33.6249
#
#
# **** WARNING ****
# For species Ic9oAoD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  53.633
# 	Value computed using high-temperature polynomial: 53.7223
#
#
# **** WARNING ****
# For species Gc7oAoD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  41.2148
# 	Value computed using high-temperature polynomial: 41.3002
#
#
# **** WARNING ****
# For species Ic9oBoD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  53.6943
# 	Value computed using high-temperature polynomial: 53.7696
#
#
# **** WARNING ****
# For species Gc7oBoD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  41.2718
# 	Value computed using high-temperature polynomial: 41.3468
#
#
# **** WARNING ****
# For species MeEc8e1oIqG, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  58.235
# 	Value computed using high-temperature polynomial: 58.302
#
#
# **** WARNING ****
# For species Ic9oCoD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  53.7903
# 	Value computed using high-temperature polynomial: 53.8765
#
#
# **** WARNING ****
# For species Gc7oCoD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  41.372
# 	Value computed using high-temperature polynomial: 41.4578
#
#
# **** WARNING ****
# For species Ac5oBoC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  29.5477
# 	Value computed using high-temperature polynomial: 29.5829
#
#
# **** WARNING ****
# For species MeEc8e1oIqF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  58.235
# 	Value computed using high-temperature polynomial: 58.302
#
#
# **** WARNING ****
# For species c7e2oAoG, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  41.6175
# 	Value computed using high-temperature polynomial: 41.6873
#
#
# **** WARNING ****
# For species c7e2oyAoG, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  39.6994
# 	Value computed using high-temperature polynomial: 39.7477
#
#
# **** WARNING ****
# For species Etall, discontinuity in cp/R detected at Tmid = 1390
# 	Value computed using low-temperature polynomial:  29.8168
# 	Value computed using high-temperature polynomial: 29.6574
#
#
# **** WARNING ****
# For species c9e8oD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  53.1722
# 	Value computed using high-temperature polynomial: 53.2723
#
#
# **** WARNING ****
# For species c5oAoE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  30.7752
# 	Value computed using high-temperature polynomial: 30.8543
#
#
# **** WARNING ****
# For species c5oyAoE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  28.6292
# 	Value computed using high-temperature polynomial: 28.6582
#
#
# **** WARNING ****
# For species etvinket, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  28.2299
# 	Value computed using high-temperature polynomial: 28.0679
#
#
# **** WARNING ****
# For species metacrol, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  26.2025
# 	Value computed using high-temperature polynomial: 26.3562
#
#
# **** WARNING ****
# For species c4h7o, discontinuity in cp/R detected at Tmid = 1390
# 	Value computed using low-temperature polynomial:  29.7898
# 	Value computed using high-temperature polynomial: 30.7835
#
#
# **** WARNING ****
# For species c4h7o, discontinuity in h/RT detected at Tmid = 1390
# 	Value computed using low-temperature polynomial:  21.9716
# 	Value computed using high-temperature polynomial: 22.2718
#
#
# **** WARNING ****
# For species c4h7o, discontinuity in s/R detected at Tmid = 1390
# 	Value computed using low-temperature polynomial:  69.7669
# 	Value computed using high-temperature polynomial: 70.11
#
#
# **** WARNING ****
# For species c5h9hco-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  34.6932
# 	Value computed using high-temperature polynomial: 34.7288
#
#
# **** WARNING ****
# For species pe1ol2e4e, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  28.703
# 	Value computed using high-temperature polynomial: 28.8901
#
#
# **** WARNING ****
# For species pe1jol2e4e, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  26.9327
# 	Value computed using high-temperature polynomial: 27.0281
#
#
# **** WARNING ****
# For species b1*o4ol, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  28.0226
# 	Value computed using high-temperature polynomial: 28.0613
#
#
# **** WARNING ****
# For species hoc2h4hco, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  21.813
# 	Value computed using high-temperature polynomial: 21.8485
#
#
# **** WARNING ****
# For species c3h6ooh1-1o2, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  28.4329
# 	Value computed using high-temperature polynomial: 28.4024
#
#
# **** WARNING ****
# For species c4h8qjAqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  34.6269
# 	Value computed using high-temperature polynomial: 34.5447
#
#
# **** WARNING ****
# For species c4h8o#4, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  27.9104
# 	Value computed using high-temperature polynomial: 28.0606
#
#
# **** WARNING ****
# For species c4h7oAqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  31.111
# 	Value computed using high-temperature polynomial: 31.1565
#
#
# **** WARNING ****
# For species c4h7oAqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  30.8441
# 	Value computed using high-temperature polynomial: 30.9022
#
#
# **** WARNING ****
# For species c4h7oAqD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  30.5938
# 	Value computed using high-temperature polynomial: 30.6317
#
#
# **** WARNING ****
# For species c4h7oBqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  30.4499
# 	Value computed using high-temperature polynomial: 30.5035
#
#
# **** WARNING ****
# For species c4h7oBqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  31.0294
# 	Value computed using high-temperature polynomial: 31.0651
#
#
# **** WARNING ****
# For species c4h7oBqD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  30.5099
# 	Value computed using high-temperature polynomial: 30.5417
#
#
# **** WARNING ****
# For species c5h11qjB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  36.7922
# 	Value computed using high-temperature polynomial: 36.7053
#
#
# **** WARNING ****
# For species c5h11qjC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  36.7915
# 	Value computed using high-temperature polynomial: 36.7053
#
#
# **** WARNING ****
# For species c5h10rAqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  36.5465
# 	Value computed using high-temperature polynomial: 36.4504
#
#
# **** WARNING ****
# For species c5h10rBqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  36.0355
# 	Value computed using high-temperature polynomial: 35.9175
#
#
# **** WARNING ****
# For species c5h10rCqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  36.2572
# 	Value computed using high-temperature polynomial: 36.155
#
#
# **** WARNING ****
# For species c5h10rDqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  36.3124
# 	Value computed using high-temperature polynomial: 36.2052
#
#
# **** WARNING ****
# For species c5h10rEqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  36.5447
# 	Value computed using high-temperature polynomial: 36.4513
#
#
# **** WARNING ****
# For species c5h10rAqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  36.5447
# 	Value computed using high-temperature polynomial: 36.4513
#
#
# **** WARNING ****
# For species c5h10rBqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  36.3124
# 	Value computed using high-temperature polynomial: 36.2052
#
#
# **** WARNING ****
# For species c5h10qjAqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  40.8346
# 	Value computed using high-temperature polynomial: 40.7496
#
#
# **** WARNING ****
# For species c5h10qjBqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  41.4619
# 	Value computed using high-temperature polynomial: 41.3756
#
#
# **** WARNING ****
# For species c5h10qjCqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  41.4628
# 	Value computed using high-temperature polynomial: 41.3756
#
#
# **** WARNING ****
# For species c5h10qjDqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  41.4633
# 	Value computed using high-temperature polynomial: 41.3756
#
#
# **** WARNING ****
# For species c5h10qjAqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  41.4619
# 	Value computed using high-temperature polynomial: 41.3756
#
#
# **** WARNING ****
# For species c5h10qjBqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  41.677
# 	Value computed using high-temperature polynomial: 41.585
#
#
# **** WARNING ****
# For species c5h10qjEqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  41.4621
# 	Value computed using high-temperature polynomial: 41.3756
#
#
# **** WARNING ****
# For species c5h10qjAqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  41.4621
# 	Value computed using high-temperature polynomial: 41.3756
#
#
# **** WARNING ****
# For species c5h9oAqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  36.5669
# 	Value computed using high-temperature polynomial: 36.6836
#
#
# **** WARNING ****
# For species c5h9oAqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  37.3196
# 	Value computed using high-temperature polynomial: 37.3672
#
#
# **** WARNING ****
# For species c5h9oAqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  37.0518
# 	Value computed using high-temperature polynomial: 37.1131
#
#
# **** WARNING ****
# For species c5h9oAqD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  37.0546
# 	Value computed using high-temperature polynomial: 37.1115
#
#
# **** WARNING ****
# For species c5h9oAqE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  36.8027
# 	Value computed using high-temperature polynomial: 36.8442
#
#
# **** WARNING ****
# For species c5h9oBqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  36.6578
# 	Value computed using high-temperature polynomial: 36.712
#
#
# **** WARNING ****
# For species c5h9oBqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  37.2385
# 	Value computed using high-temperature polynomial: 37.2801
#
#
# **** WARNING ****
# For species c5h9oBqD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  36.9714
# 	Value computed using high-temperature polynomial: 37.0251
#
#
# **** WARNING ****
# For species c5h9oCqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  36.6556
# 	Value computed using high-temperature polynomial: 36.7545
#
#
# **** WARNING ****
# For species c5h9oCqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  37.1762
# 	Value computed using high-temperature polynomial: 37.2879
#
#
# **** WARNING ****
# For species c5h10o-AC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  34.3695
# 	Value computed using high-temperature polynomial: 34.521
#
#
# **** WARNING ****
# For species c5h10o-BD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  34.3695
# 	Value computed using high-temperature polynomial: 34.521
#
#
# **** WARNING ****
# For species c5h10o-AD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  34.1284
# 	Value computed using high-temperature polynomial: 34.3695
#
#
# **** WARNING ****
# For species nc5h11o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  38.3861
# 	Value computed using high-temperature polynomial: 38.3038
#
#
# **** WARNING ****
# For species nc3h7coch2o2, discontinuity in cp/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  40.6753
# 	Value computed using high-temperature polynomial: 41.2646
#
#
# **** WARNING ****
# For species nc3h7coch2o2, discontinuity in h/RT detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  8.29766
# 	Value computed using high-temperature polynomial: 8.46498
#
#
# **** WARNING ****
# For species nc3h7coch2o2, discontinuity in s/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  98.2808
# 	Value computed using high-temperature polynomial: 98.4716
#
#
# **** WARNING ****
# For species nc3h7coch2o2h, discontinuity in cp/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  42.772
# 	Value computed using high-temperature polynomial: 43.145
#
#
# **** WARNING ****
# For species nc3h7coch2o2h, discontinuity in h/RT detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  -3.21938
# 	Value computed using high-temperature polynomial: -3.05602
#
#
# **** WARNING ****
# For species nc3h7coch2o2h, discontinuity in s/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  102.517
# 	Value computed using high-temperature polynomial: 102.705
#
#
# **** WARNING ****
# For species nc3h7coch2o, discontinuity in cp/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  38.0512
# 	Value computed using high-temperature polynomial: 38.63
#
#
# **** WARNING ****
# For species nc3h7coch2o, discontinuity in h/RT detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  6.42283
# 	Value computed using high-temperature polynomial: 6.5736
#
#
# **** WARNING ****
# For species nc3h7coch2o, discontinuity in s/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  90.2443
# 	Value computed using high-temperature polynomial: 90.4159
#
#
# **** WARNING ****
# For species c2h5coc2h4o2, discontinuity in cp/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  41.4146
# 	Value computed using high-temperature polynomial: 42.2063
#
#
# **** WARNING ****
# For species c2h5coc2h4o2, discontinuity in h/RT detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  7.92517
# 	Value computed using high-temperature polynomial: 8.17676
#
#
# **** WARNING ****
# For species c2h5coc2h4o2, discontinuity in s/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  98.5755
# 	Value computed using high-temperature polynomial: 98.8633
#
#
# **** WARNING ****
# For species c2h5coc2h4o2h, discontinuity in cp/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  43.4457
# 	Value computed using high-temperature polynomial: 44.0603
#
#
# **** WARNING ****
# For species c2h5coc2h4o2h, discontinuity in h/RT detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  -3.5967
# 	Value computed using high-temperature polynomial: -3.34459
#
#
# **** WARNING ****
# For species c2h5coc2h4o2h, discontinuity in s/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  102.808
# 	Value computed using high-temperature polynomial: 103.098
#
#
# **** WARNING ****
# For species c2h5coc2h4o, discontinuity in cp/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  38.7018
# 	Value computed using high-temperature polynomial: 39.5691
#
#
# **** WARNING ****
# For species c2h5coc2h4o, discontinuity in h/RT detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  6.04394
# 	Value computed using high-temperature polynomial: 6.28548
#
#
# **** WARNING ****
# For species c2h5coc2h4o, discontinuity in s/R detected at Tmid = 1397
# 	Value computed using low-temperature polynomial:  90.5318
# 	Value computed using high-temperature polynomial: 90.8074
#
#
# **** WARNING ****
# For species c6h13qjB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  43.0004
# 	Value computed using high-temperature polynomial: 42.9114
#
#
# **** WARNING ****
# For species c6h13qjC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.9998
# 	Value computed using high-temperature polynomial: 42.9114
#
#
# **** WARNING ****
# For species c6h12rAqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.758
# 	Value computed using high-temperature polynomial: 42.6576
#
#
# **** WARNING ****
# For species c6h12rCqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.4675
# 	Value computed using high-temperature polynomial: 42.3616
#
#
# **** WARNING ****
# For species c6h12rDqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.4675
# 	Value computed using high-temperature polynomial: 42.3623
#
#
# **** WARNING ****
# For species c6h12rEqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.5231
# 	Value computed using high-temperature polynomial: 42.4105
#
#
# **** WARNING ****
# For species c6h12rFqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.755
# 	Value computed using high-temperature polynomial: 42.66
#
#
# **** WARNING ****
# For species c6h12rAqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.755
# 	Value computed using high-temperature polynomial: 42.66
#
#
# **** WARNING ****
# For species c6h12rBqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.5231
# 	Value computed using high-temperature polynomial: 42.4105
#
#
# **** WARNING ****
# For species c6h12rDqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.4675
# 	Value computed using high-temperature polynomial: 42.3623
#
#
# **** WARNING ****
# For species c6h12rEqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.5231
# 	Value computed using high-temperature polynomial: 42.4105
#
#
# **** WARNING ****
# For species c6h12rFqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.755
# 	Value computed using high-temperature polynomial: 42.66
#
#
# **** WARNING ****
# For species c6h12qjBqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  47.6704
# 	Value computed using high-temperature polynomial: 47.5861
#
#
# **** WARNING ****
# For species c6h12qjCqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  47.6704
# 	Value computed using high-temperature polynomial: 47.5861
#
#
# **** WARNING ****
# For species c6h12qjDqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  47.6723
# 	Value computed using high-temperature polynomial: 47.5861
#
#
# **** WARNING ****
# For species c6h12qjEqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  47.6718
# 	Value computed using high-temperature polynomial: 47.5861
#
#
# **** WARNING ****
# For species c6h12qjAqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  47.6704
# 	Value computed using high-temperature polynomial: 47.5861
#
#
# **** WARNING ****
# For species c6h12qjFqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  47.6706
# 	Value computed using high-temperature polynomial: 47.5861
#
#
# **** WARNING ****
# For species c6h12qjAqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  47.6706
# 	Value computed using high-temperature polynomial: 47.5861
#
#
# **** WARNING ****
# For species c6h12qjFqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  47.6706
# 	Value computed using high-temperature polynomial: 47.5861
#
#
# **** WARNING ****
# For species c6h11oAqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  43.5287
# 	Value computed using high-temperature polynomial: 43.5799
#
#
# **** WARNING ****
# For species c6h11oAqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  43.2657
# 	Value computed using high-temperature polynomial: 43.3269
#
#
# **** WARNING ****
# For species c6h11oAqD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  43.2657
# 	Value computed using high-temperature polynomial: 43.3269
#
#
# **** WARNING ****
# For species c6h11oAqE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  43.2657
# 	Value computed using high-temperature polynomial: 43.3269
#
#
# **** WARNING ****
# For species c6h11oBqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.8647
# 	Value computed using high-temperature polynomial: 42.9259
#
#
# **** WARNING ****
# For species c6h11oBqD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  43.182
# 	Value computed using high-temperature polynomial: 43.241
#
#
# **** WARNING ****
# For species c6h11oBqE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  43.182
# 	Value computed using high-temperature polynomial: 43.241
#
#
# **** WARNING ****
# For species c6h11oCqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.8639
# 	Value computed using high-temperature polynomial: 42.9632
#
#
# **** WARNING ****
# For species c6h11oCqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  43.3815
# 	Value computed using high-temperature polynomial: 43.4911
#
#
# **** WARNING ****
# For species c6h11oCqD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  43.3815
# 	Value computed using high-temperature polynomial: 43.4911
#
#
# **** WARNING ****
# For species c6h11oCqE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  43.1174
# 	Value computed using high-temperature polynomial: 43.2451
#
#
# **** WARNING ****
# For species c6h11oCqF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.8641
# 	Value computed using high-temperature polynomial: 42.9606
#
#
# **** WARNING ****
# For species c6h12o-AC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  40.583
# 	Value computed using high-temperature polynomial: 40.7319
#
#
# **** WARNING ****
# For species c6h12o-BD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  40.583
# 	Value computed using high-temperature polynomial: 40.7319
#
#
# **** WARNING ****
# For species c6h12o-AD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  40.3352
# 	Value computed using high-temperature polynomial: 40.5516
#
#
# **** WARNING ****
# For species c6h12o-BE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  40.5841
# 	Value computed using high-temperature polynomial: 40.8624
#
#
# **** WARNING ****
# For species c6h12o-AE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  40.3352
# 	Value computed using high-temperature polynomial: 40.5516
#
#
# **** WARNING ****
# For species c7h14o-AD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  46.5487
# 	Value computed using high-temperature polynomial: 46.7429
#
#
# **** WARNING ****
# For species c7h14o-BE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  46.7926
# 	Value computed using high-temperature polynomial: 47.0426
#
#
# **** WARNING ****
# For species c7h14o-AE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  46.5487
# 	Value computed using high-temperature polynomial: 46.7429
#
#
# **** WARNING ****
# For species c7h14o-BF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  46.7926
# 	Value computed using high-temperature polynomial: 47.0426
#
#
# **** WARNING ****
# For species c7h13oAqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.7369
# 	Value computed using high-temperature polynomial: 49.7932
#
#
# **** WARNING ****
# For species c7h13oAqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.4707
# 	Value computed using high-temperature polynomial: 49.5399
#
#
# **** WARNING ****
# For species c7h13oAqD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.4707
# 	Value computed using high-temperature polynomial: 49.5399
#
#
# **** WARNING ****
# For species c7h13oAqE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.4707
# 	Value computed using high-temperature polynomial: 49.5399
#
#
# **** WARNING ****
# For species c7h13oBqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.0756
# 	Value computed using high-temperature polynomial: 49.1407
#
#
# **** WARNING ****
# For species c7h13oBqD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.3894
# 	Value computed using high-temperature polynomial: 49.4506
#
#
# **** WARNING ****
# For species c7h13oBqE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.3894
# 	Value computed using high-temperature polynomial: 49.4506
#
#
# **** WARNING ****
# For species c7h13oBqF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.3894
# 	Value computed using high-temperature polynomial: 49.4506
#
#
# **** WARNING ****
# For species c7h13oCqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.0749
# 	Value computed using high-temperature polynomial: 49.1707
#
#
# **** WARNING ****
# For species c7h13oCqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.5961
# 	Value computed using high-temperature polynomial: 49.7008
#
#
# **** WARNING ****
# For species c7h13oCqD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.5922
# 	Value computed using high-temperature polynomial: 49.7022
#
#
# **** WARNING ****
# For species c7h13oCqE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.3271
# 	Value computed using high-temperature polynomial: 49.4515
#
#
# **** WARNING ****
# For species c7h13oCqF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.3271
# 	Value computed using high-temperature polynomial: 49.4515
#
#
# **** WARNING ****
# For species c7h13oCqG, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.0749
# 	Value computed using high-temperature polynomial: 49.1707
#
#
# **** WARNING ****
# For species c7h13oDqA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.0749
# 	Value computed using high-temperature polynomial: 49.1707
#
#
# **** WARNING ****
# For species c7h13oDqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.3271
# 	Value computed using high-temperature polynomial: 49.4515
#
#
# **** WARNING ****
# For species c7h13oDqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.5922
# 	Value computed using high-temperature polynomial: 49.7022
#
#
# **** WARNING ****
# For species c8h17qjB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  55.4193
# 	Value computed using high-temperature polynomial: 55.3311
#
#
# **** WARNING ****
# For species c8h17qjC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  55.421
# 	Value computed using high-temperature polynomial: 55.3294
#
#
# **** WARNING ****
# For species c8h17qjD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  55.4212
# 	Value computed using high-temperature polynomial: 55.3294
#
#
# **** WARNING ****
# For species c8h16rAqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  55.1739
# 	Value computed using high-temperature polynomial: 55.0716
#
#
# **** WARNING ****
# For species c8h16rCqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  54.8878
# 	Value computed using high-temperature polynomial: 54.7757
#
#
# **** WARNING ****
# For species c8h16rDqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  54.8878
# 	Value computed using high-temperature polynomial: 54.7757
#
#
# **** WARNING ****
# For species c8h16rEqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  54.8859
# 	Value computed using high-temperature polynomial: 54.7757
#
#
# **** WARNING ****
# For species c8h16rFqB, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  54.8859
# 	Value computed using high-temperature polynomial: 54.7757
#
#
# **** WARNING ****
# For species c8h16rAqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  55.1739
# 	Value computed using high-temperature polynomial: 55.0716
#
#
# **** WARNING ****
# For species c8h16rBqC, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  54.9434
# 	Value computed using high-temperature polynomial: 54.8264
#
#
# **** WARNING ****
# ...
#
#
# **** WARNING ****
# For species c10h19oEqI, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  67.9512
# 	Value computed using high-temperature polynomial: 68.0784
#
#
# **** WARNING ****
# For species c10h20o-BD, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  65.5106
# 	Value computed using high-temperature polynomial: 66.2886
#
#
# **** WARNING ****
# For species c10h20o-CE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  65.5106
# 	Value computed using high-temperature polynomial: 66.2886
#
#
# **** WARNING ****
# For species c10h20o-DF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  65.5106
# 	Value computed using high-temperature polynomial: 66.2886
#
#
# **** WARNING ****
# For species c10h20o-BE, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  65.4249
# 	Value computed using high-temperature polynomial: 65.6367
#
#
# **** WARNING ****
# For species c10h20o-CF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  65.4249
# 	Value computed using high-temperature polynomial: 65.6367
#
#
# **** WARNING ****
# For species c10h20o-DG, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  65.4249
# 	Value computed using high-temperature polynomial: 65.6367
#
#
# **** WARNING ****
# For species c10h20o-BF, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  65.4249
# 	Value computed using high-temperature polynomial: 65.6367
#
#
# **** WARNING ****
# For species c10h20o-CG, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  65.4249
# 	Value computed using high-temperature polynomial: 65.6367
#
#
# **** WARNING ****
# For species choch2ch2cho, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  24.5471
# 	Value computed using high-temperature polynomial: 24.5783
#
#
# **** WARNING ****
# For species nc4h9coch2o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.8647
# 	Value computed using high-temperature polynomial: 42.9259
#
#
# **** WARNING ****
# For species nc5h11coch2o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.0756
# 	Value computed using high-temperature polynomial: 49.1407
#
#
# **** WARNING ****
# For species nc6h13coch2o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  55.287
# 	Value computed using high-temperature polynomial: 55.3519
#
#
# **** WARNING ****
# For species nc7h15coch2o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  61.4984
# 	Value computed using high-temperature polynomial: 61.5652
#
#
# **** WARNING ****
# For species nc3h7coc2h4o2, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  41.2769
# 	Value computed using high-temperature polynomial: 41.3366
#
#
# **** WARNING ****
# For species nc3h7coc2h4o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.8655
# 	Value computed using high-temperature polynomial: 42.9619
#
#
# **** WARNING ****
# For species nc3h7coc2h4o, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  38.7225
# 	Value computed using high-temperature polynomial: 38.7874
#
#
# **** WARNING ****
# For species nc4h9coc2h4p, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.5717
# 	Value computed using high-temperature polynomial: 42.6222
#
#
# **** WARNING ****
# For species nc4h9coc2h4o2, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  47.4823
# 	Value computed using high-temperature polynomial: 47.549
#
#
# **** WARNING ****
# For species nc4h9coc2h4o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.0749
# 	Value computed using high-temperature polynomial: 49.1707
#
#
# **** WARNING ****
# For species nc4h9coc2h4o, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  44.9347
# 	Value computed using high-temperature polynomial: 44.9993
#
#
# **** WARNING ****
# For species nc5h11coc2h4p, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  48.7801
# 	Value computed using high-temperature polynomial: 48.832
#
#
# **** WARNING ****
# For species nc5h11coc2h4o2, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  53.6933
# 	Value computed using high-temperature polynomial: 53.7627
#
#
# **** WARNING ****
# For species nc5h11coc2h4o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  55.2822
# 	Value computed using high-temperature polynomial: 55.3836
#
#
# **** WARNING ****
# For species nc5h11coc2h4o, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  51.1437
# 	Value computed using high-temperature polynomial: 51.2111
#
#
# **** WARNING ****
# For species nc6h13coc2h4p, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  54.9901
# 	Value computed using high-temperature polynomial: 55.0494
#
#
# **** WARNING ****
# For species nc6h13coc2h4o2, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  59.901
# 	Value computed using high-temperature polynomial: 59.9782
#
#
# **** WARNING ****
# For species nc6h13coc2h4o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  61.4958
# 	Value computed using high-temperature polynomial: 61.5963
#
#
# **** WARNING ****
# For species nc6h13coc2h4o, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  57.3462
# 	Value computed using high-temperature polynomial: 57.4238
#
#
# **** WARNING ****
# For species nc5h11coc3h6-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  54.9901
# 	Value computed using high-temperature polynomial: 55.0494
#
#
# **** WARNING ****
# For species nc5h11coc3h6o2-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  59.9013
# 	Value computed using high-temperature polynomial: 59.9782
#
#
# **** WARNING ****
# For species npecoc3h6o2h-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  61.4958
# 	Value computed using high-temperature polynomial: 61.5963
#
#
# **** WARNING ****
# For species nc5h11coc3h6o-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  57.3465
# 	Value computed using high-temperature polynomial: 57.4238
#
#
# **** WARNING ****
# For species nc4h9coc3h6-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  48.7801
# 	Value computed using high-temperature polynomial: 48.832
#
#
# **** WARNING ****
# For species nc4h9coc3h6o2-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  53.6936
# 	Value computed using high-temperature polynomial: 53.7627
#
#
# **** WARNING ****
# For species nc4h9coc3h6o2h-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  55.2822
# 	Value computed using high-temperature polynomial: 55.3836
#
#
# **** WARNING ****
# For species nc4h9coc3h6o-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  51.1421
# 	Value computed using high-temperature polynomial: 51.2111
#
#
# **** WARNING ****
# For species nc3h7coc3h6-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.5717
# 	Value computed using high-temperature polynomial: 42.6222
#
#
# **** WARNING ****
# For species nc3h7coc3h6o2-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  47.4816
# 	Value computed using high-temperature polynomial: 47.549
#
#
# **** WARNING ****
# For species nc3h7coc3h6o2h-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  49.0749
# 	Value computed using high-temperature polynomial: 49.1707
#
#
# **** WARNING ****
# For species nc3h7coc3h6o-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  44.9368
# 	Value computed using high-temperature polynomial: 44.9993
#
#
# **** WARNING ****
# For species c2h5coc3h6-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  36.3618
# 	Value computed using high-temperature polynomial: 36.4092
#
#
# **** WARNING ****
# For species c2h5coc3h6o2-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  41.2721
# 	Value computed using high-temperature polynomial: 41.3371
#
#
# **** WARNING ****
# For species c2h5coc3h6o2h-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.8641
# 	Value computed using high-temperature polynomial: 42.9606
#
#
# **** WARNING ****
# For species c2h5coc3h6o-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  38.725
# 	Value computed using high-temperature polynomial: 38.7892
#
#
# **** WARNING ****
# For species c2h5coc5h9-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  46.9645
# 	Value computed using high-temperature polynomial: 47.0542
#
#
# **** WARNING ****
# For species sc2h4coc5h9-1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.4422
# 	Value computed using high-temperature polynomial: 45.4929
#
#
# **** WARNING ****
# For species c2h5coc5h8-13, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.1516
# 	Value computed using high-temperature polynomial: 45.2064
#
#
# **** WARNING ****
# For species c2h5coc5h8-15, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.3874
# 	Value computed using high-temperature polynomial: 45.4396
#
#
# **** WARNING ****
# For species hxolcy3o1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.1052
# 	Value computed using high-temperature polynomial: 42.7493
#
#
# **** WARNING ****
# For species hxolcy4o1, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.0192
# 	Value computed using high-temperature polynomial: 42.1087
#
#
# **** WARNING ****
# For species hxolcy5o2, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.6859
# 	Value computed using high-temperature polynomial: 42.9497
#
#
# **** WARNING ****
# For species hxolcy6o3, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  42.4355
# 	Value computed using high-temperature polynomial: 42.6381
#
#
# **** WARNING ****
# For species hxol1*o3o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.7335
# 	Value computed using high-temperature polynomial: 45.8698
#
#
# **** WARNING ****
# For species hxol1*o4o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.7335
# 	Value computed using high-temperature polynomial: 45.8698
#
#
# **** WARNING ****
# For species hxol2*o3o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.4878
# 	Value computed using high-temperature polynomial: 45.5528
#
#
# **** WARNING ****
# For species hxol2*o4o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.2161
# 	Value computed using high-temperature polynomial: 45.2977
#
#
# **** WARNING ****
# For species hxol2*o5o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.2161
# 	Value computed using high-temperature polynomial: 45.2977
#
#
# **** WARNING ****
# For species hxol3*o2o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.485
# 	Value computed using high-temperature polynomial: 45.5897
#
#
# **** WARNING ****
# For species hxol3*o4o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.4793
# 	Value computed using high-temperature polynomial: 45.5901
#
#
# **** WARNING ****
# For species hxol3*o5o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.2158
# 	Value computed using high-temperature polynomial: 45.3406
#
#
# **** WARNING ****
# For species hxol3*o6o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  44.9643
# 	Value computed using high-temperature polynomial: 45.0604
#
#
# **** WARNING ****
# For species hxol4*o2o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.2158
# 	Value computed using high-temperature polynomial: 45.3406
#
#
# **** WARNING ****
# For species hxol4*o3o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.4853
# 	Value computed using high-temperature polynomial: 45.5922
#
#
# **** WARNING ****
# For species hxol4*o5o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.485
# 	Value computed using high-temperature polynomial: 45.5897
#
#
# **** WARNING ****
# For species hxol4*o6o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  44.9643
# 	Value computed using high-temperature polynomial: 45.0604
#
#
# **** WARNING ****
# For species hxol5*o2o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.2809
# 	Value computed using high-temperature polynomial: 45.3354
#
#
# **** WARNING ****
# For species hxol5*o3o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.2809
# 	Value computed using high-temperature polynomial: 45.3354
#
#
# **** WARNING ****
# For species hxol5*o6o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  44.9695
# 	Value computed using high-temperature polynomial: 45.0284
#
#
# **** WARNING ****
# For species hxol6*o3o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.3618
# 	Value computed using high-temperature polynomial: 45.4251
#
#
# **** WARNING ****
# For species hxol6*o4o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.3625
# 	Value computed using high-temperature polynomial: 45.4241
#
#
# **** WARNING ****
# For species hxol6*o5o2h, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  45.6277
# 	Value computed using high-temperature polynomial: 45.6813
#
#
# **** WARNING ****
# For species ch2ch2cooh, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  20.3534
# 	Value computed using high-temperature polynomial: 20.3977
#
#
# **** WARNING ****
# For species pe1*o5ol, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  34.2307
# 	Value computed using high-temperature polynomial: 34.272
#
#
# **** WARNING ****
# For species pe1ol3*o4e, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  30.3315
# 	Value computed using high-temperature polynomial: 30.1679
#
#
# **** WARNING ****
# For species eche2oA, discontinuity in cp/R detected at Tmid = 1000
# 	Value computed using low-temperature polynomial:  47.9532
# 	Value computed using high-temperature polynomial: 48.1048

# %%
sorted(gas.species_names)
# Out:
# ['A1c2h3AC',
#  'A1c2hAC',
#  'A2-X',
#  'A2O',
#  'A2oh',
#  'ASTYRYL',
#  'Ac10h21',
#  'Ac4h7-1',
#  'Ac5e1oC',
#  'Ac5e4oB',
#  'Ac5h11',
#  'Ac5h9-1',
#  'Ac5oB',
#  'Ac5oBoC',
#  'Ac5oBoD',
#  'Ac6e3e5oB',
#  'Ac6e5oB',
#  'Ac6e5oC',
#  'Ac6h11-3',
#  'Ac6h13',
#  'Ac6h9-15',
#  'Ac6oC',
#  'Ac7e1oD',
#  'Ac7e3oB',
#  'Ac7e4oB',
#  'Ac7e4oC',
#  'Ac7e6oB',
#  'Ac7h13-3',
#  'Ac7h15',
#  'Ac7oBoD',
#  'Ac7oBoG',
#  'Ac7oD',
#  'Ac8e5oC',
#  'Ac8h15-4',
#  'Ac8h17',
#  'Ac9e2oF',
#  'Ac9e3oF',
#  'Ac9e5oB',
#  'Ac9e5oC',
#  'Ac9e5oD',
#  'Ac9e6oB',
#  'Ac9e6oC',
#  'Ac9e6oD',
#  'Ac9h19',
#  'Ac9oBoF',
#  'Ac9oCoF',
#  'Ac9oDoF',
#  'AchxqBqD',
#  'Aeche1',
#  'AechoB',
#  'AechoD',
#  'AechoE',
#  'Amche1',
#  'Amche3',
#  'AmchoC',
#  'AmchoD',
#  'AmchqBqD',
#  'Ao2pchohB',
#  'Aophc3h4-2',
#  'Apche2',
#  'ApchoB',
#  'ApchoC',
#  'ApchoE',
#  'ApchoF',
#  'ApchohB',
#  'ApchqA',
#  'ApchqB',
#  'ApchqC',
#  'ApchqD',
#  'ApchqDqF',
#  'ApchqE',
#  'ApchqF',
#  'ApchqG',
#  'Aphc2h4',
#  'Aphc3h5ohB',
#  'BPHPROPY',
#  'BSTYRYL',
#  'Bc10h21',
#  'Bc5e1oC',
#  'Bc5h11',
#  'Bc5h9-1',
#  'Bc5oA',
#  'Bc5oAoC',
#  'Bc5oAoD',
#  'Bc5oAqE',
#  'Bc6e5oA',
#  'Bc6h11-3',
#  'Bc6h13',
#  'Bc6oAoF',
#  'Bc7e6oA',
#  'Bc7h15',
#  'Bc8h17',
#  'Bc9h19',
#  'BchxoAoC',
#  'BchxoAoD',
#  'Bchxone',
#  'BchxqAqC',
#  'BchxqAqD',
#  'BmchohA',
#  'Bo2pchohA',
#  'Bo2pchohC',
#  'BpchoA',
#  'BpchoC',
#  'BpchoE',
#  'BpchoF',
#  'BpchoG',
#  'BpchohA',
#  'BpchohC',
#  'BpchqA',
#  'BpchqB',
#  'BpchqC',
#  'BpchqD',
#  'BpchqDqF',
#  'BpchqE',
#  'BpchqEqG',
#  'BpchqEqH',
#  'BpchqEqI',
#  'BpchqF',
#  'BpchqG',
#  'Bphc2h4',
#  'Bphc3h5ohA',
#  'Bphc3h5ohC',
#  'C',
#  'CEtDc7oEoIqA',
#  'CEtDc7oIqA',
#  'CMeEc8oIqA',
#  'CPD',
#  'Cc10h19-1',
#  'Cc10h21',
#  'Cc4h7-1',
#  'Cc5e4oA',
#  'Cc5e4oB',
#  'Cc5h11',
#  'Cc5h9-1',
#  'Cc5oAqE',
#  'Cc6e5oA',
#  'Cc6h11-1',
#  'Cc6h13',
#  'Cc6oA',
#  'Cc6oAoD',
#  'Cc7e1oD',
#  'Cc7h11-16',
#  'Cc7h13-1',
#  'Cc7h15',
#  'Cc7oBoGqA',
#  'Cc8h15-1',
#  'Cc8h17',
#  'Cc9h17-1',
#  'Cc9h19',
#  'Cc9oAqF',
#  'Cc9oDoFqA',
#  'Cchxone',
#  'Ceche1',
#  'Cmche1',
#  'Co2pchohB',
#  'Co2pchohD',
#  'Cophc3h4-1',
#  'Cpche4',
#  'CpchoA',
#  'CpchoB',
#  'CpchoBqE',
#  'CpchoE',
#  'CpchoF',
#  'CpchoG',
#  'CpchohB',
#  'CpchohD',
#  'CpchqA',
#  'CpchqB',
#  'CpchqC',
#  'CpchqD',
#  'CpchqDqF',
#  'CpchqE',
#  'CpchqEqG',
#  'CpchqEqH',
#  'CpchqEqI',
#  'CpchqF',
#  'CpchqFqH',
#  'CpchqG',
#  'Cphc3h5ohB',
#  'DEtDc7oAqI',
#  'DEtDc7oEoIqA',
#  'DEtDc7oIqA',
#  'DMeEc8oAoCqI',
#  'DMeEc8oAqI',
#  'DMeEc8oIqA',
#  'Dc10h19-2',
#  'Dc10h21',
#  'Dc4e1oA',
#  'Dc4h7-1',
#  'Dc4oAqC',
#  'Dc5e4oA',
#  'Dc5e4oB',
#  'Dc5h9-1',
#  'Dc5h9-2',
#  'Dc5oBohE',
#  'Dc6e5oA',
#  'Dc6e5oAoC',
#  'Dc7e1oC',
#  'Dc7e1oE',
#  'Dc7e6oA',
#  'Dc7e6oB',
#  'Dc7h13-1',
#  'Dc7h13-2',
#  'Dc7h15',
#  'Dc7oA',
#  'Dc7oAoC',
#  'Dc7oBoGqA',
#  'Dc8h15-2',
#  'Dc8h17',
#  'Dc9e8oA',
#  'Dc9e8oB',
#  'Dc9e8oC',
#  'Dc9h17-2',
#  'Dc9h19',
#  'Dc9oAoCqF',
#  'Dc9oAqF',
#  'Dchxe2oA',
#  'DchxoAoC',
#  'Dchxone',
#  'DchxoqB',
#  'Dmche1',
#  'Do2pchohC',
#  'Do2pchohE',
#  'Dpche2',
#  'Dpche5',
#  'Dpche5e7',
#  'DpchoA',
#  'DpchoB',
#  'DpchoC',
#  'DpchoE',
#  'DpchoEqB',
#  'DpchoF',
#  'DpchoG',
#  'DpchohC',
#  'DpchohE',
#  'DpchqA',
#  'DpchqB',
#  'DpchqBqE',
#  'DpchqC',
#  'DpchqCqE',
#  'DpchqCqF',
#  'DpchqE',
#  'DpchqEqG',
#  'DpchqEqH',
#  'DpchqF',
#  'DpchqFqH',
#  'DpchqG',
#  'Ec10h19-3',
#  'Ec10h21',
#  'Ec5e1oC',
#  'Ec5e4oA',
#  'Ec5e4oB',
#  'Ec5h9-1',
#  'Ec5h9-2',
#  'Ec5oA',
#  'Ec5oAoB',
#  'Ec5oAoC',
#  'Ec5oAoD',
#  'Ec6e5oA',
#  'Ec6h9-13',
#  'Ec7e6oA',
#  'Ec7e6oAoB',
#  'Ec7h13-3',
#  'Ec8h15-1',
#  'Ec8h15-3',
#  'Ec8oA',
#  'Ec9h17-3',
#  'Ec9h19',
#  'Echxe1qC',
#  'Echxe2oAoD',
#  'Emche13',
#  'Eo2pchohD',
#  'Eo2pchohF',
#  'Epche6',
#  'EpchoA',
#  'EpchoB',
#  'EpchoC',
#  'EpchoF',
#  'EpchoG',
#  'EpchoH',
#  'EpchohD',
#  'EpchohF',
#  'EpchqA',
#  'EpchqB',
#  'EpchqC',
#  'EpchqCqF',
#  'EpchqD',
#  'EpchqDqB',
#  'EpchqE',
#  'EpchqF',
#  'EpchqFqH',
#  'EpchqG',
#  'EtBc5e7oyA',
#  'EtCc6e1rH',
#  'EtCc6oArH',
#  'EtDc7e1e8ojE',
#  'EtDc7e1e8qE',
#  'EtDc7e1oCrI',
#  'EtDc7e1oHrI',
#  'EtDc7e1oIojD',
#  'EtDc7e1oIojE',
#  'EtDc7e1oIqD',
#  'EtDc7e1oIqE',
#  'EtDc7e1oIrC',
#  'EtDc7e1oyI',
#  'EtDc7e1qEqHrI',
#  'EtDc7e3oIrG',
#  'EtDc7e4oIrA',
#  'EtDc7e6oArI',
#  'EtDc7e6oBrI',
#  'EtDc7e6oCrI',
#  'EtDc7e9oAojC',
#  'EtDc7e9oAqC',
#  'EtDc7e9oArG',
#  'EtDc7e9oBrA',
#  'EtDc7e9oBrG',
#  'EtDc7e9oCrA',
#  'EtDc7e9oCrH',
#  'EtDc7e9oyA',
#  'EtDc7oAoCrI',
#  'EtDc7oAoEoIqC',
#  'EtDc7oAoEoIqD',
#  'EtDc7oAoHrI',
#  'EtDc7oAoI',
#  'EtDc7oAoIqC',
#  'EtDc7oAoIqD',
#  'EtDc7oAoyI',
#  'EtDc7oAqIqjD',
#  'EtDc7oAqjI',
#  'EtDc7oArI',
#  'EtDc7oBoIrA',
#  'EtDc7oCoIrA',
#  'EtDc7oEoIqAqjC',
#  'EtDc7oEoIqAqjD',
#  'EtDc7oEoIqjA',
#  'EtDc7oEoIrA',
#  'EtDc7oIqAqjC',
#  'EtDc7oIqAqjD',
#  'EtDc7oIqjA',
#  'EtDc7oIrA',
#  'EtDc7oyAoI',
#  'Etall',
#  'FMeEc8oAqI',
#  'Fc10h19-4',
#  'Fc10h19oB',
#  'Fc6e1e4',
#  'Fc6e1oA',
#  'Fc6e1oC',
#  'Fc6e1oCoE',
#  'Fc6e2oA',
#  'Fc6e3oAoE',
#  'Fc6e5oA',
#  'Fc6h11-1',
#  'Fc6h9-13',
#  'Fc6oAoC',
#  'Fc6oAoCoD',
#  'Fc6oAoDoE',
#  'Fc6oAoE',
#  'Fc9e1oC',
#  'Fc9e1oD',
#  'Fc9e1oE',
#  'Fc9e1qAqH',
#  'Fc9e1qDqF',
#  'Fc9e1qEqG',
#  'Fc9e1qEqH',
#  'Fc9e4oA',
#  'Fc9h17-4',
#  'Fc9oA',
#  'Fc9oAoC',
#  'Fc9oAoD',
#  'Fc9oAoE',
#  'Fc9oAoG',
#  'Fc9oAoH',
#  'Fmche14',
#  'Fo2pchohE',
#  'Fo2pchohG',
#  'Fpche7',
#  'FpchoA',
#  'FpchoB',
#  'FpchoC',
#  'FpchoE',
#  'FpchoG',
#  'FpchohE',
#  'FpchohG',
#  'FpchqA',
#  'FpchqB',
#  'FpchqBqE',
#  'FpchqC',
#  'FpchqCqE',
#  'FpchqD',
#  'FpchqDqE',
#  'FpchqE',
#  'FpchqEqG',
#  'FpchqEqH',
#  'FpchqF',
#  'FpchqG',
#  'GMeEc8oAoCqI',
#  'Gc10h19oC',
#  'Gc7e1e3',
#  'Gc7e1oC',
#  'Gc7e1oD',
#  'Gc7e1oE',
#  'Gc7e1oF',
#  'Gc7e3oA',
#  'Gc7e3oB',
#  'Gc7e4oA',
#  'Gc7e4oB',
#  'Gc7e4oC',
#  'Gc7h13-1',
#  'Gc7h13-3',
#  'Gc7oAoD',
#  'Gc7oBoD',
#  'Gc7oCoD',
#  'Gic7al',
#  'Gmche13',
#  'Gmche14',
#  'Go2pchohF',
#  'Gpc7al',
#  'GpchoB',
#  'GpchoC',
#  'GpchoE',
#  'GpchoF',
#  'GpchohF',
#  'GpchqA',
#  'GpchqB',
#  'GpchqBqE',
#  'GpchqC',
#  'GpchqCqE',
#  'GpchqCqF',
#  'GpchqD',
#  'GpchqDqF',
#  'GpchqE',
#  'GpchqEqH',
#  'GpchqEqI',
#  'GpchqF',
#  'GpchqG',
#  'Hc8h15-1',
#  'Hc8h15-3',
#  'Hc8oD',
#  'Hc9oAoGqF',
#  'Hc9oAqF',
#  'HpchoE',
#  'HpchoF',
#  'HpchqBqE',
#  'HpchqCqE',
#  'HpchqCqF',
#  'HpchqDqF',
#  'HpchqE',
#  'HpchqEqG',
#  'HpchqF',
#  'Ic9e3oA',
#  'Ic9e3oB',
#  'Ic9e3oE',
#  'Ic9e3qFqH',
#  'Ic9e4oA',
#  'Ic9e4oB',
#  'Ic9e4oC',
#  'Ic9oAoD',
#  'Ic9oBoD',
#  'Ic9oCoD',
#  'Iic9e1qDqI',
#  'Ipc9oAoB',
#  'Ipche4e6',
#  'Ipche5e7',
#  'IpchoE',
#  'IpchqBqE',
#  'IpchqCqE',
#  'IpchqCqF',
#  'IpchqE',
#  'IpchqEqG',
#  'IpchqEqH',
#  'IpchqF',
#  'Lc6h4',
#  'Lc6h6',
#  'Lc6h7',
#  'MeBc4e1oErD',
#  'MeBc5e1e4rF',
#  'MeBc5e1rF',
#  'MeBc5e4oArF',
#  'MeBc5e6oArE',
#  'MeBc5oAoCrF',
#  'MeBc5oAoF',
#  'MeBc5oArF',
#  'MeBc5oyAoF',
#  'MeBc6e7oAoF',
#  'MeBc6e7oAoyF',
#  'MeBc6e7oyAoF',
#  'MeCc4e3oArE',
#  'MeCc5e4e5oA',
#  'MeCc5e4e5oyA',
#  'MeCc6e1e7rF',
#  'MeCc6e1oDrG',
#  'MeCc6e1oG',
#  'MeCc6e1oyG',
#  'MeCc6e1rG',
#  'MeCc6e3oArG',
#  'MeCc6e5e7oA',
#  'MeCc6e5e7oyA',
#  'MeCc6e5oAoG',
#  'MeCc6e5oAoyG',
#  'MeCc6e5oyAoG',
#  'MeCc6e7oA',
#  'MeCc6e7oAqErF',
#  'MeCc6e7oArF',
#  'MeCc6e7oBrA',
#  'MeCc6e7oDrA',
#  'MeCc6e7oyA',
#  'MeCc6oAoDoG',
#  'MeCc6oAoDoyG',
#  'MeCc6oAoDrG',
#  'MeCc6oAoG',
#  'MeCc6oAoyG',
#  'MeCc6oBoGrA',
#  'MeCc6oyAoDoG',
#  'MeCc6oyAoG',
#  'MeDc6e5oArG',
#  'MeDc6e5oBrG',
#  'MeDc6e7oArF',
#  'MeDc6e7oBrF',
#  'MeDc6oBoGrF',
#  'MeDc6oCoGrF',
#  'MeDc7e1rH',
#  'MeDc7e8rA',
#  'MeDc7oArH',
#  'MeDc7oHrA',
#  'MeDc8e7oBrI',
#  'MeDc8e7oCrI',
#  'MeDc8e9oArH',
#  'MeDc8e9oBrH',
#  'MeDc8e9oCrH',
#  'MeDc8oBoIrH',
#  'MeDc8oCoIrH',
#  'MeEc6e1oGrF',
#  'MeEc6e5oAqCrG',
#  'MeEc6e5oArG',
#  'MeEc6e5oBrG',
#  'MeEc7e6e8oA',
#  'MeEc7e6e8oyA',
#  'MeEc8e1oCrI',
#  'MeEc8e1oDrI',
#  'MeEc8e1oIojD',
#  'MeEc8e1oIojF',
#  'MeEc8e1oIojG',
#  'MeEc8e1oIqD',
#  'MeEc8e1oIqF',
#  'MeEc8e1oIqG',
#  'MeEc8e1oIrC',
#  'MeEc8e1oyI',
#  'MeEc8e5oArI',
#  'MeEc8e8oAojF',
#  'MeEc8e8oAqF',
#  'MeEc8e9oAojC',
#  'MeEc8e9oAqC',
#  'MeEc8e9oArD',
#  'MeEc8e9oBrH',
#  'MeEc8e9oCrA',
#  'MeEc8e9oDrA',
#  'MeEc8e9oyA',
#  'MeEc8oAoCoIqD',
#  'MeEc8oAoCoIqG',
#  'MeEc8oAoCqIqjD',
#  'MeEc8oAoCqIqjG',
#  'MeEc8oAoCqjI',
#  'MeEc8oAoCrI',
#  'MeEc8oAoDrI',
#  'MeEc8oAoFrI',
#  'MeEc8oAoI',
#  'MeEc8oAoIqC',
#  'MeEc8oAoIqD',
#  'MeEc8oAoIqF',
#  'MeEc8oAoyI',
#  'MeEc8oAqIqjD',
#  'MeEc8oAqIqjF',
#  'MeEc8oAqjI',
#  'MeEc8oArI',
#  'MeEc8oBoIrA',
#  'MeEc8oCoIrA',
#  'MeEc8oDoIrA',
#  'MeEc8oIqAqjC',
#  'MeEc8oIqAqjD',
#  'MeEc8oIqjA',
#  'MeEc8oIrA',
#  'MeEc8oyAoI',
#  'Mec8oor',
#  'P2c4h4134',
#  'U-c6h5',
#  'ac3h4',
#  'ac3h4hco1',
#  'ac3h5',
#  'ac3h5co',
#  'ac3h5hco',
#  'aceton',
#  'acrol',
#  'ar',
#  'b1*o4ol',
#  'b1j*o4ol',
#  'b1jol3e',
#  'b1ol',
#  'b1ol1j',
#  'b1ol2e4j',
#  'b1ol2j',
#  'b1ol3e',
#  'b1ol3j',
#  'b1ol4j',
#  'bbdtmpe1',
#  'bbdtmpe3',
#  'bddm1pe',
#  'bddm1pe1',
#  'bddm1pe3',
#  'bddm2pe',
#  'bddm2pe1',
#  'bddm2pe3',
#  'bddm3pe2',
#  'bddmpe2',
#  'bddtmpe1',
#  'bddtmpe2',
#  'biphenyl',
#  'bme1bu',
#  'bme2b1',
#  'bme2bu',
#  'bme2pe4',
#  'bmepral',
#  'bmepryl',
#  'butanone',
#  'butyn2',
#  'butyne',
#  'c10h10',
#  'c10h19oAqB',
#  'c10h19oAqC',
#  'c10h19oAqD',
#  'c10h19oAqE',
#  'c10h19oBqA',
#  'c10h19oBqC',
#  'c10h19oBqD',
#  'c10h19oBqE',
#  'c10h19oBqF',
#  'c10h19oCqA',
#  'c10h19oCqB',
#  'c10h19oCqD',
#  'c10h19oCqE',
#  'c10h19oCqF',
#  'c10h19oCqG',
#  'c10h19oDqA',
#  'c10h19oDqB',
#  'c10h19oDqC',
#  'c10h19oDqE',
#  'c10h19oDqF',
#  'c10h19oDqG',
#  'c10h19oDqH',
#  'c10h19oEqA',
#  'c10h19oEqB',
#  'c10h19oEqC',
#  'c10h19oEqD',
#  'c10h19oEqF',
#  'c10h19oEqG',
#  'c10h19oEqH',
#  'c10h19oEqI',
#  'c10h20-1',
#  'c10h20-2',
#  'c10h20-3',
#  'c10h20-4',
#  'c10h20-5',
#  'c10h20o-AB',
#  'c10h20o-AC',
#  'c10h20o-AD',
#  'c10h20o-AE',
#  'c10h20o-BC',
#  'c10h20o-BD',
#  'c10h20o-BE',
#  'c10h20o-BF',
#  'c10h20o-CD',
#  'c10h20o-CE',
#  'c10h20o-CF',
#  'c10h20o-CG',
#  'c10h20o-DE',
#  'c10h20o-DF',
#  'c10h20o-DG',
#  'c10h20o-EF',
#  'c10h20qjAqB',
#  'c10h20qjAqC',
#  'c10h20qjAqD',
#  'c10h20qjAqE',
#  'c10h20qjBqA',
#  'c10h20qjBqC',
#  'c10h20qjBqD',
#  'c10h20qjBqE',
#  'c10h20qjCqA',
#  'c10h20qjCqB',
#  'c10h20qjCqD',
#  'c10h20qjCqE',
#  'c10h20qjDqA',
#  'c10h20qjDqB',
#  'c10h20qjDqC',
#  'c10h20qjDqE',
#  'c10h20qjEqA',
#  'c10h20qjEqB',
#  'c10h20qjEqC',
#  'c10h20qjEqD',
#  'c10h20qjFqB',
#  'c10h20qjFqC',
#  'c10h20qjFqD',
#  'c10h20qjFqE',
#  'c10h20qjGqC',
#  'c10h20qjGqD',
#  'c10h20qjGqE',
#  'c10h20qjHqD',
#  'c10h20qjHqE',
#  'c10h20qjIqE',
#  'c10h20qjohAB',
#  'c10h20qjohBC',
#  'c10h20qjohCD',
#  'c10h20qjohDE',
#  'c10h20qjohEF',
#  'c10h20rAqB',
#  'c10h20rAqC',
#  'c10h20rAqD',
#  'c10h20rAqE',
#  'c10h20rBqA',
#  'c10h20rBqC',
#  'c10h20rBqD',
#  'c10h20rBqE',
#  'c10h20rCqA',
#  'c10h20rCqB',
#  'c10h20rCqD',
#  'c10h20rCqE',
#  'c10h20rDqA',
#  'c10h20rDqB',
#  'c10h20rDqC',
#  'c10h20rDqE',
#  'c10h20rEqA',
#  'c10h20rEqB',
#  'c10h20rEqC',
#  'c10h20rEqD',
#  'c10h20rFqB',
#  'c10h20rFqC',
#  'c10h20rFqD',
#  'c10h20rFqE',
#  'c10h20rGqC',
#  'c10h20rGqD',
#  'c10h20rGqE',
#  'c10h20rHqD',
#  'c10h20rHqE',
#  'c10h20rIqE',
#  'c10h20rohAB',
#  'c10h20rohBC',
#  'c10h20rohCD',
#  'c10h20rohDE',
#  'c10h20rohEF',
#  'c10h21ojA',
#  'c10h21ojB',
#  'c10h21ojC',
#  'c10h21ojD',
#  'c10h21ojE',
#  'c10h21qA',
#  'c10h21qB',
#  'c10h21qC',
#  'c10h21qD',
#  'c10h21qE',
#  'c10h21qjA',
#  'c10h21qjB',
#  'c10h21qjC',
#  'c10h21qjD',
#  'c10h21qjE',
#  'c10h9',
#  'c14h14',
#  'c2',
#  'c2c4h8',
#  'c2c5h10',
#  'c2h',
#  'c2h2',
#  'c2h2oh',
#  'c2h3',
#  'c2h3ch2oh',
#  'c2h3chcho',
#  'c2h3choh',
#  'c2h3co',
#  'c2h3coc2h4',
#  'c2h3coc3h6-2',
#  'c2h3coc3h6-3',
#  'c2h3coc3h7',
#  'c2h3coc4h8-3',
#  'c2h3coc4h8-4',
#  'c2h3coc4h9',
#  'c2h3coc5h10-4',
#  'c2h3coc5h10-5',
#  'c2h3coc5h11',
#  'c2h3coc6h12-5',
#  'c2h3coc6h12-6',
#  'c2h3coc6h13',
#  'c2h3coch2co',
#  'c2h3coch2hco',
#  'c2h3coch2oh',
#  'c2h3cochoh',
#  'c2h3coco',
#  'c2h3cohco',
#  'c2h3cooh',
#  'c2h3o',
#  'c2h4',
#  'c2h4cohco',
#  'c2h4o',
#  'c2h4o2h',
#  'c2h5',
#  'c2h5co',
#  'c2h5coc2h3',
#  'c2h5coc2h4o',
#  'c2h5coc2h4o2',
#  'c2h5coc2h4o2h',
#  'c2h5coc2h4p',
#  'c2h5coc2h4s',
#  'c2h5coc2h5',
#  'c2h5coc3h4',
#  'c2h5coc3h5-1',
#  'c2h5coc3h6-1',
#  'c2h5coc3h6o-1',
#  'c2h5coc3h6o2-1',
#  'c2h5coc3h6o2h-1',
#  'c2h5coc5h8-13',
#  'c2h5coc5h8-15',
#  'c2h5coc5h9-1',
#  'c2h5coch2',
#  'c2h5coch2o',
#  'c2h5coch2o2',
#  'c2h5coch2o2h',
#  'c2h5o',
#  'c2h5o2',
#  'c2h5o2h',
#  'c2h5oh',
#  'c2h6',
#  'c2hco',
#  'c2o',
#  'c3h2',
#  'c3h3',
#  'c3h3co',
#  'c3h3hco',
#  'c3h3o',
#  'c3h4hco',
#  'c3h4o',
#  'c3h4o2h',
#  'c3h4oh',
#  'c3h5co',
#  'c3h5e1q2',
#  'c3h5o',
#  'c3h5o2h',
#  'c3h5oh',
#  'c3h6',
#  'c3h6cho-1',
#  'c3h6coc2h3-1',
#  'c3h6coc2h3-2',
#  'c3h6coc2h3-3',
#  'c3h6coch3-1',
#  'c3h6coch3-2',
#  'c3h6coch3-3',
#  'c3h6o',
#  'c3h6o1-3',
#  'c3h6oh',
#  'c3h6ooh1-1',
#  'c3h6ooh1-1o2',
#  'c3h6ooh1-2',
#  'c3h6ooh1-2o2',
#  'c3h6ooh1-3',
#  'c3h6ooh1-3o2',
#  'c3h6ooh2-1',
#  'c3h6ooh2-1o2',
#  'c3h7chco',
#  'c3h7co',
#  'c3h7coc2h3',
#  'c3h7coch3',
#  'c3h8',
#  'c3ket12',
#  'c3ket13',
#  'c3ket21',
#  'c4h',
#  'c4h10',
#  'c4h2',
#  'c4h4',
#  'c4h4o',
#  'c4h5co',
#  'c4h5hco',
#  'c4h6',
#  'c4h6o2h',
#  'c4h7co-1',
#  'c4h7co-2',
#  'c4h7hco-1',
#  'c4h7hco-2',
#  'c4h7o',
#  'c4h7o2h',
#  'c4h7oAqB',
#  'c4h7oAqC',
#  'c4h7oAqD',
#  'c4h7oBqA',
#  'c4h7oBqC',
#  'c4h7oBqD',
#  'c4h7oh',
#  'c4h8',
#  'c4h8hco-2',
#  'c4h8o',
#  'c4h8o#3',
#  'c4h8o#4',
#  'c4h8o#5',
#  'c4h8o2',
#  'c4h8qjAqA',
#  'c4h8qjAqB',
#  'c4h8qjBqA',
#  'c4h8qjCqA',
#  'c4h8qjCqB',
#  'c4h8qjDqA',
#  'c4h8qjDqB',
#  'c4h8rAqA',
#  'c4h8rAqB',
#  'c4h8rBqA',
#  'c4h8rCqA',
#  'c4h8rCqB',
#  'c4h8rDqA',
#  'c4h8rDqB',
#  'c4h9coco',
#  'c4h9cohco',
#  'c4h9o',
#  'c4h9qjA',
#  'c4h9qjB',
#  'c4oAoC',
#  'c4oyAoC',
#  'c5e2oA',
#  'c5e2oyA',
#  'c5e4oAoC',
#  'c5e4oB',
#  'c5e4oyAoC',
#  'c5h10',
#  'c5h10o-AB',
#  'c5h10o-AC',
#  'c5h10o-AD',
#  'c5h10o-AE',
#  'c5h10o-BC',
#  'c5h10o-BD',
#  'c5h10qjAqA',
#  'c5h10qjAqB',
#  'c5h10qjAqC',
#  'c5h10qjBqA',
#  'c5h10qjBqB',
#  'c5h10qjBqC',
#  'c5h10qjCqA',
#  'c5h10qjCqB',
#  'c5h10qjDqA',
#  'c5h10qjDqB',
#  'c5h10qjEqA',
#  'c5h10qjEqB',
#  'c5h10rAqA',
#  'c5h10rAqB',
#  'c5h10rAqC',
#  'c5h10rBqA',
#  'c5h10rBqB',
#  'c5h10rBqC',
#  'c5h10rCqA',
#  'c5h10rCqB',
#  'c5h10rDqA',
#  'c5h10rDqB',
#  'c5h10rEqA',
#  'c5h10rEqB',
#  'c5h11co',
#  'c5h11hco',
#  'c5h11qjA',
#  'c5h11qjB',
#  'c5h11qjC',
#  'c5h3',
#  'c5h4',
#  'c5h4o',
#  'c5h4oh',
#  'c5h5',
#  'c5h5o',
#  'c5h7',
#  'c5h8-12',
#  'c5h8-13',
#  'c5h8-14',
#  'c5h9co-1',
#  'c5h9co-2',
#  'c5h9co-3',
#  'c5h9hco-1',
#  'c5h9hco-2',
#  'c5h9hco-3',
#  'c5h9oAqA',
#  'c5h9oAqB',
#  'c5h9oAqC',
#  'c5h9oAqD',
#  'c5h9oAqE',
#  'c5h9oBqA',
#  'c5h9oBqC',
#  'c5h9oBqD',
#  'c5h9oBqE',
#  'c5h9oCqA',
#  'c5h9oCqB',
#  'c5h9oh',
#  'c5oAoE',
#  'c5oAoEqB',
#  'c5oAoEqC',
#  'c5oAqEqjB',
#  'c5oAqEqjC',
#  'c5oAqjE',
#  'c5oBqjDohE',
#  'c5oyAoE',
#  'c6alCco',
#  'c6e1e5oC',
#  ...]

# %%
for species in gas.species():
    if species.composition == {'C':8, 'H':18}:
        print(species.name)
# Out:
# nc8h18
# ic8h18

# %%
gas.TP = 900, 10e6
gas.set_equivalence_ratio(phi=1.0, fuel='ic8h18', oxidizer='o2:0.2, n2:0.8' )
gas()
# Out:
#   gas:
#
#        temperature             900  K
#           pressure           1e+07  Pa
#            density         40.2989  kg/m^3
#   mean mol. weight         30.1557  amu
#
#                           1 kg            1 kmol
#                        -----------      ------------
#           enthalpy      5.8703e+05         1.77e+07     J
#    internal energy      3.3889e+05        1.022e+07     J
#            entropy          6720.8        2.027e+05     J/K
#     Gibbs function     -5.4617e+06       -1.647e+08     J
#  heat capacity c_p          1287.9        3.884e+04     J/K
#  heat capacity c_v          1012.2        3.052e+04     J/K
#
#                            X                 Y          Chem. Pot. / RT
#                      -------------     ------------     ------------
#                 o2        0.19685         0.208881         -23.3196
#                 n2       0.787402         0.731465         -20.2328
#             ic8h18       0.015748         0.059654         -94.5016
#      [+2179 minor]              0                0

# %%
def set_gas_concentrations(gas, phi):
    """
    Set the concentrations in the gas according to the description
    in the paper by 
    """
    # Set it to desired stoichiometry with synthetic air (20% O2 : 80% N2)
    gas.set_equivalence_ratio(phi=1.0, fuel='ic8h18', oxidizer='o2:0.2, n2:0.8' )
    # Then dilute the whole thing 1:2 with extra N2
    gas.X = gas.X / 3.0 
    gas.X[gas.species_index('n2')] += 2./3.

set_gas_concentrations(gas, 1.0)
gas()
# Out:
#   gas:
#
#        temperature             900  K
#           pressure           1e+07  Pa
#            density         40.2989  kg/m^3
#   mean mol. weight         30.1557  amu
#
#                           1 kg            1 kmol
#                        -----------      ------------
#           enthalpy      5.8703e+05         1.77e+07     J
#    internal energy      3.3889e+05        1.022e+07     J
#            entropy          6720.8        2.027e+05     J/K
#     Gibbs function     -5.4617e+06       -1.647e+08     J
#  heat capacity c_p          1287.9        3.884e+04     J/K
#  heat capacity c_v          1012.2        3.052e+04     J/K
#
#                            X                 Y          Chem. Pot. / RT
#                      -------------     ------------     ------------
#                 o2        0.19685         0.208881         -23.3196
#                 n2       0.787402         0.731465         -20.2328
#             ic8h18       0.015748         0.059654         -94.5016
#      [+2179 minor]              0                0

# %%
def get_ignition_delay(gas, temperature, pressure_bar, mole_fractions, plot=False):
    """
    A general function to find the igniton delay.
    Using C2H + O --> CH* as the indication of ignition
    
    gas is a cantera Solution object
    temperature in K
    pressure_bar is in bar
    mole_fractions is a dict
    """
    gas.TPX = temperature, pressure_bar*1e5, mole_fractions

    reactor = ct.IdealGasReactor(gas)
    reactor_network = ct.ReactorNet([reactor])
    
    time = 0.0
    end_time = 10e-3
    
    times = []
    concentrations = []
    pressures = []
    temperatures = []
    
    print_data = True
    while time < end_time:
        time = reactor_network.time
        times.append(time)
        temperatures.append(reactor.T)
        pressures.append(reactor.thermo.P)
        concentrations.append(reactor.thermo.concentrations)
        # take a timestep
        # the size of the step will be determined by the ODE solver
        # depending on how quickly things are changing.
        reactor_network.step()
    
    print("Reached end time {0:.2f} ms in {1} steps".format(times[-1]*1e3, len(times)))
    # convert the lists into arrays
    concentrations = np.array(concentrations)
    times = np.array(times)
    pressures = np.array(pressures)
    temperatures = np.array(temperatures)

    if plot:
        plt.subplot(2,1,1)
        plt.plot(times*1e3, pressures/1e5)
        plt.ylabel("Pressure (bar)", color='b')
        ax2 = plt.gca().twinx()
        ax2.set_ylabel('Temperature (K)', color='r')
        ax2.plot(times*1e3, temperatures, 'r')
    # Using C2H + O --> CH* as the indication of ignition
    i_c2h = gas.species_index('C2H')   
    i_o = gas.species_index('O')
    excited_ch_generation = concentrations[:,i_o] * concentrations[:,i_c2h]
    if plot:
        plt.subplot(2,1,2)
        plt.plot(times*1e3, excited_ch_generation, 'g')
        plt.ylabel("CH* emission")
        plt.ylim(0,max(1e-13,1.1*max(excited_ch_generation)))
        plt.xlabel("Time (ms)")
        plt.tight_layout()
        plt.show()
    step_with_highest_ch_gen = excited_ch_generation.argmax()
    if step_with_highest_ch_gen > 1 and excited_ch_generation.max()>1e-20:
        ignition_time_ms = 1e3 * times[step_with_highest_ch_gen]
        print("At {0} K {1} bar, ignition delay time is {2} ms".format(temperature, pressure_bar, ignition_time_ms))
        return ignition_time_ms
    else:
        print("At {0} K {1} bar, no ignition detected".format(temperature, pressure_bar))
        return np.infty

# %%
def get_ignition_delay_air(temperature, pressure_bar=10, phi=1.0, plot=False):
    """
    For figure 14
    
    temperature in K
    pressure in bar
    phi is equivalence ratio
    """
    set_gas_concentrations(gas, phi)
    mole_fractions = gas.X

    time = get_ignition_delay(gas, temperature, pressure_bar, mole_fractions, plot=plot)
    return time

# %%
get_ignition_delay_air(1000, 16, 1, plot=True)
plt.rcParams['figure.figsize'] = [10, 8]
# Out:
# Reached end time 10.38 ms in 5722 steps
# At 1000 K 16 bar, ignition delay time is 3.37273998544 ms

# %%
DAG_temperatures = 1000/np.linspace(0.70,1.55,25)
pressures_bar = 16
phi = 1

DAG_results = dict()
times = []
for T in DAG_temperatures:
    t = get_ignition_delay_air(T,pressures_bar, phi, plot=False)
    times.append(t)
    DAG_results[pressures_bar]=times
# Out:
# Reached end time 10.47 ms in 5066 steps
# At 1428.57142857 K 16 bar, ignition delay time is 0.035107200055 ms
# Reached end time 10.43 ms in 5518 steps
# At 1359.7733711 K 16 bar, ignition delay time is 0.0655630802287 ms
# Reached end time 10.15 ms in 5540 steps
# At 1297.2972973 K 16 bar, ignition delay time is 0.115889944249 ms
# Reached end time 10.16 ms in 5302 steps
# At 1240.31007752 K 16 bar, ignition delay time is 0.200293736396 ms
# Reached end time 10.49 ms in 5588 steps
# At 1188.11881188 K 16 bar, ignition delay time is 0.345780704927 ms
# Reached end time 10.41 ms in 5311 steps
# At 1140.14251781 K 16 bar, ignition delay time is 0.596427881415 ms
# Reached end time 10.60 ms in 5237 steps
# At 1095.89041096 K 16 bar, ignition delay time is 1.01441473652 ms
# Reached end time 10.00 ms in 5435 steps
# At 1054.94505495 K 16 bar, ignition delay time is 1.68084102541 ms
# Reached end time 10.39 ms in 5167 steps
# At 1016.94915254 K 16 bar, ignition delay time is 2.71031571728 ms
# Reached end time 10.25 ms in 5778 steps
# At 981.595092025 K 16 bar, ignition delay time is 4.30879145413 ms
# Reached end time 10.38 ms in 5649 steps
# At 948.616600791 K 16 bar, ignition delay time is 6.91864535123 ms
# Reached end time 10.00 ms in 1020 steps
# At 917.782026769 K 16 bar, no ignition detected
# Reached end time 10.00 ms in 614 steps
# At 888.888888889 K 16 bar, no ignition detected
# Reached end time 10.06 ms in 453 steps
# At 861.759425494 K 16 bar, no ignition detected
# Reached end time 10.03 ms in 299 steps
# At 836.236933798 K 16 bar, no ignition detected
# Reached end time 10.08 ms in 241 steps
# At 812.182741117 K 16 bar, no ignition detected
# Reached end time 10.03 ms in 193 steps
# At 789.473684211 K 16 bar, no ignition detected
# Reached end time 10.04 ms in 121 steps
# At 768.0 K 16 bar, no ignition detected
# Reached end time 10.17 ms in 95 steps
# At 747.663551402 K 16 bar, no ignition detected
# Reached end time 10.22 ms in 67 steps
# At 728.376327769 K 16 bar, no ignition detected
# Reached end time 10.19 ms in 68 steps
# At 710.059171598 K 16 bar, no ignition detected
# Reached end time 10.34 ms in 44 steps
# At 692.640692641 K 16 bar, no ignition detected
# Reached end time 10.82 ms in 38 steps
# At 676.056338028 K 16 bar, no ignition detected
# Reached end time 11.17 ms in 34 steps
# At 660.247592847 K 16 bar, no ignition detected
# Reached end time 10.67 ms in 25 steps
# At 645.161290323 K 16 bar, no ignition detected

# %%
plt.semilogy(1000/DAG_temperatures,times,label='{}bar'.format(pressures_bar))
plt.legend(loc='best')
plt.xlabel('1000 K / $T$')
plt.ylabel('$\\tau_{ign} = t([CH^*]_{max})/ms$')
plt.rcParams['figure.figsize'] = [10, 8]

# %%
import pickle
with open('ic8-LLNL.pkl') as fp:
    (LLNL_temperatures, LLNL_results) = pickle.load(fp)

# %%
plt.semilogy(1000/LLNL_temperatures,LLNL_results[pressures_bar],label='LLNL {}bar'.format(pressures_bar))
plt.legend(loc='best')
plt.xlabel('1000 K / $T$')
plt.ylabel('$\\tau_{ign} = t([CH^*]_{max})/ms$')


plt.semilogy(1000/DAG_temperatures,times,label='Dagaut et Al {}bar'.format(pressures_bar))
plt.legend(loc='best')
plt.xlabel('1000 K / $T$')
plt.ylabel('$\\tau_{ign} = t([CH^*]_{max})/ms$')
plt.rcParams['figure.figsize'] = [10, 8]

plt.show
# Out:
# <function matplotlib.pyplot.show>
